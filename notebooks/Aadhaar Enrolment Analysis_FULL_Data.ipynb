# %% [markdown]
# # Aadhaar Enrolment Analysis – 2025

# %% [markdown]
# ## Problem Statement
#
# To analyze Aadhaar enrolment data to identify societal patterns, regional disparities, and age-group behaviour, and translate these findings into actionable insights that support inclusive and data-driven planning.

# %% [markdown]
# ## Dataset Overview
#
# The Aadhaar Enrolment dataset captures enrolment activity across India for the year 2025. The data is provided in three CSV files and includes location and age-group wise enrolment counts.
#
# Key Columns:
#
# date
#
# state
#
# district
#
# pincode
#
# age_0_5
#
# age_5_17
#
# age_18_greater

# %% [markdown]
# # Import Required Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import re

# %% [markdown]
# # Load and Merge Datasets

# %%
import pandas as pd

# Merge into single dataframe
df = pd.read_csv('http://localhost:8000/api/datasets/enrolment')
df.shape
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 import pandas as pd
#       3 # Merge into single dataframe
# ----> 4 df = pd.read_csv('/Users/bharathchilaka/Downloads/api_data_aadhar_enrolment/enrolment_full (1).csv')
#       5 df.shape
#
# File ~/Projects/uidai-data-sync/venv/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/Projects/uidai-data-sync/venv/lib/python3.9/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/Projects/uidai-data-sync/venv/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/Projects/uidai-data-sync/venv/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/Projects/uidai-data-sync/venv/lib/python3.9/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/bharathchilaka/Downloads/api_data_aadhar_enrolment/enrolment_full (1).csv'

# %%
df['state'].unique()
# Out:
# array(['Meghalaya', 'Karnataka', 'Uttar Pradesh', 'Bihar', 'Maharashtra',
#        'Haryana', 'Rajasthan', 'Punjab', 'Delhi', 'Madhya Pradesh',
#        'West Bengal', 'Assam', 'Uttarakhand', 'Gujarat', 'Andhra Pradesh',
#        'Tamil Nadu', 'Chhattisgarh', 'Jharkhand', 'Nagaland', 'Manipur',
#        'Telangana', 'Tripura', 'Mizoram', 'Jammu and Kashmir',
#        'Chandigarh', 'Sikkim', 'Odisha', 'Kerala',
#        'The Dadra And Nagar Haveli And Daman And Diu', 'Orissa',
#        'Pondicherry', 'Puducherry', 'Ladakh', 'Goa', 'Himachal Pradesh',
#        'Andaman & Nicobar Islands', 'Arunachal Pradesh', 'Lakshadweep',
#        '100000', 'Andaman and Nicobar Islands', 'WESTBENGAL',
#        'Dadra and Nagar Haveli',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Daman and Diu',
#        'Jammu & Kashmir', 'Daman & Diu', 'Dadra & Nagar Haveli',
#        'West Bangal', 'Westbengal', 'andhra pradesh', 'west Bengal',
#        'odisha', 'West bengal', 'Jammu And Kashmir', 'WEST BENGAL',
#        'West  Bengal', 'ODISHA'], dtype=object)

# %%
df['state'].nunique()
# Out:
# 57

# %%
df['district'].unique()
# Out:
# array(['East Khasi Hills', 'Bengaluru Urban', 'Kanpur Nagar', 'Aligarh',
#        'Sitamarhi', 'Bahraich', 'Firozabad', 'Purbi Champaran',
#        'Maharajganj', 'Aurangabad', 'Ghaziabad', 'Faridabad', 'Madhubani',
#        'Sikar', 'Bhagalpur', 'Amritsar', 'Gurugram',
#        'Gautam Buddha Nagar', 'West Delhi', 'Bhind', 'Gwalior', 'Katni',
#        'Coochbehar', 'Lucknow', 'Dinajpur Uttar', 'Marigaon', 'Kokrajhar',
#        'Agra', 'Haridwar', 'Nagaon', 'Parbhani', 'West Khasi Hills',
#        'North West Delhi', 'West Jaintia Hills', 'Unnao', 'Saharanpur',
#        'Dibrugarh', 'Udalguri', 'Chirang', 'Kamrup', 'Dhubri', 'Jaunpur',
#        'Thane', 'Dhemaji', 'Banas Kantha', 'Tinsukia', 'Spsr Nellore',
#        'Barpeta', 'Sonitpur', 'Baksa', 'Ludhiana', 'Patan', 'Kanchipuram',
#        'Patna', 'Lakhimpur', 'Bongaigaon', 'Vadodara', 'Nainital',
#        'Dehradun', 'Hojai', 'Dohad', 'Morbi', 'Raipur', 'Gorakhpur',
#        'Bulandshahr', 'Mathura', 'Pashchim Champaran', 'Bijapur',
#        'Deoghar', 'Muzaffarpur', 'Banda', 'Kachchh', 'Ri Bhoi', 'Darrang',
#        'Ashok Nagar', 'Darjeeling', 'North Cachar Hills', 'Ranchi',
#        'Surat', 'Nanded', 'Bengaluru', 'Jorhat', 'Gir Somnath',
#        'Kamrup Metro', 'Goalpara', 'Bhavnagar', 'Golaghat', 'Nagpur',
#        'Cooch Behar', 'Jalgaon', 'Hingoli', 'Ahmadnagar', 'Gandhinagar',
#        'North 24 Parganas', 'Munger', 'Kohima', 'Jalor', 'Kheda',
#        'Nalbari', 'Palghar', 'Jodhpur', 'Central Delhi', 'Gaya',
#        'Sabarkantha', 'Dimapur', 'Cachar', 'Banaskantha', 'Kheri',
#        'Rajkot', 'Satara', 'Betul', 'West Karbi Anglong', 'South Delhi',
#        'Raigad', 'Uttar Dinajpur', 'Guna', 'Kaimur (Bhabua)', 'Dholpur',
#        'Churachandpur', 'West Champaran', 'Bharuch', 'Jhargram',
#        'Khargone', 'Chhotaudepur', 'Mumbai Suburban', 'Hailakandi',
#        'Panchmahals', 'South Salmara Mankachar', 'Budaun', 'Kanpur Dehat',
#        'Porbandar', 'West Garo Hills', 'Kapurthala', 'South Garo Hills',
#        'Nagaur', 'Mysuru', 'Mahesana', 'Churu', 'Hyderabad',
#        'Kancheepuram', 'Varanasi', 'Lohardaga', 'North Garo Hills',
#        'Chhatarpur', 'Nadia', 'Purnia', 'Gurgaon', 'Charaideo', 'Jaipur',
#        'Saran', 'Morena', 'Dhar', 'Dahod', 'Devbhumi Dwarka',
#        'East Champaran', 'Tapi', 'Baghpat', 'Fatehpur',
#        'South West Khasi Hills', 'Yadgir', 'Nandurbar', 'Etawah',
#        'Jalpaiguri', 'Jabalpur', 'Shamli', 'Sibsagar', 'Barwani', 'Botad',
#        'Junagadh', 'Balrampur', 'Bara Banki', 'Shivpuri', 'Beed',
#        'Shahjahanpur', 'Jamnagar', 'Chandrapur', 'Durg',
#        'K.v. Rangareddy', 'Sirohi', 'Alipurduar', 'South West Delhi',
#        'Gonda', 'East Jaintia Hills', 'Bareilly', 'Bundi', 'Solapur',
#        'Sitapur', 'Dumka', 'Sultanpur', 'Karbi Anglong', 'Bikaner',
#        'Phek', 'Raisen', 'Shrawasti', 'East Delhi', 'Jhabua', 'Unakoti',
#        'Indore', 'Bhopal', 'Dungarpur', 'Chandauli', 'Bharatpur',
#        'Mainpuri', 'Godda', 'Muzaffarnagar', 'Siddharthnagar', 'Datia',
#        'West Tripura', 'Medchal-malkajgiri', 'Sagar', 'Sheopur',
#        'Arvalli', 'Surendra Nagar', 'Malda', 'Amreli', 'Alwar',
#        'Ambedkar Nagar', 'Madurai', 'Pilibhit', 'Champhai', 'Valsad',
#        'Pakur', 'Vaishali', 'Vidisha', 'Karimganj', 'Biswanath',
#        'Burhanpur', 'Kaushambi', 'Pune', 'Punch', 'Jehanabad', 'Jalaun',
#        'Etah', 'Meerut', 'Baran', 'Sangrur', 'Karauli', 'Anand',
#        'Longleng', 'Chandigarh', 'Jamui', 'South Sikkim', 'Panna',
#        'East Garo Hills', 'Jhalawar', 'Shahdara', 'Kalaburagi',
#        'Thanjavur', 'Peren', 'Tuensang', 'Mahisagar', 'Hoshiarpur',
#        'Noklak', 'Sukma', 'Khandwa', 'Ajmer', 'West Sikkim', 'Latur',
#        'Basti', 'Satna', 'Gurdaspur', 'Hazaribagh', 'Azamgarh', 'Udaipur',
#        'Kolkata', 'Rampur', 'The Dangs', 'East Singhbhum', 'Alirajpur',
#        'SAS Nagar (Mohali)', 'South West Garo Hills', 'Moradabad', 'Kota',
#        'Dewas', 'Navsari', 'Chumukedima', 'Ahmedabad', 'Nabarangapur',
#        'Pali', 'Amroha', 'Saiha', 'Dakshin Dinajpur', 'Bijnor',
#        'Pudukkottai', 'Bangalore Rural', 'Kalimpong', 'Deoria',
#        'Baramula', 'Gopalganj', 'Prayagraj', 'Lalitpur', 'Mewat', 'Hapur',
#        'Jammu', 'Bishnupur', 'Saharsa', 'Arwal', 'Hathras', 'Lawngtlai',
#        'Nashik', 'Yavatmal', 'Cuddalore', 'Kollam', 'Patiala', 'Katihar',
#        'Malappuram', 'Birbhum', 'Siwan', 'Dhule', 'Baloda Bazar',
#        'Washim', 'Coimbatore', 'Lunglei', 'Imphal West', 'Kushinagar',
#        'Thiruvananthapuram', 'Sangli', 'Ahmadabad', 'Lakhisarai',
#        'Bengaluru Rural', '24 Paraganas North', 'Dima Hasao', 'Banka',
#        'Salem', 'Dadra And Nagar Haveli', 'Dang', 'Kaithal', 'Vellore',
#        'Shravasti', 'Nalanda', 'Jaisalmer', 'Kallakurichi', 'Farrukhabad',
#        'Medinipur West', 'Araria', 'Sonipat', 'Chatra',
#        'Gaurella Pendra Marwahi', 'Visakhapatanam', 'Buldhana',
#        'Amravati', 'Hardoi', 'Dhalai', 'Ernakulam', 'New Delhi',
#        'Bhilwara', 'Ramanathapuram', 'Mon', 'Raichur', 'North Delhi',
#        'Rohtak', 'Gumla', 'Barmer', 'Kurukshetra', 'Nuh', 'Ashoknagar',
#        'Thrissur', 'S.A.S Nagar', 'North East Delhi', 'Purba Bardhaman',
#        'Ambala', 'Panipat', 'Darbhanga', 'Ayodhya', 'Khunti',
#        'Medchal Malkajgiri', 'Sivasagar', 'Hisar', 'Sivaganga',
#        'Siddharth Nagar', 'Senapati', 'Tamenglong', 'Ukhrul', 'Mamit',
#        'Mammit', 'Kiphire', 'Zunheboto', 'Angul', 'Balangir', 'Baleshwar',
#        'Baleswar', 'Bargarh', 'Bhadrak', 'Boudh', 'Cuttack', 'Dhenkanal',
#        'Gajapati', 'Ganjam', 'JAJPUR', 'Jagatsinghapur', 'Jajapur',
#        'Jharsuguda', 'Kalahandi', 'Kandhamal', 'Kendrapara', 'Kendujhar',
#        'Khorda', 'Khordha', 'Koraput', 'Malkangiri', 'Mayurbhanj',
#        'NUAPADA', 'Nayagarh', 'Puri', 'Rayagada', 'Sambalpur', 'Sonapur',
#        'Subarnapur', 'Sundargarh', 'Sundergarh', 'Anugul', 'Karaikal',
#        'Pondicherry', 'Puducherry', 'Barnala', 'Bathinda', 'Faridkot',
#        'Fatehgarh Sahib', 'Fazilka', 'Ferozepur', 'Firozpur', 'Jalandhar',
#        'Malerkotla', 'Mansa', 'Moga', 'Nawanshahr', 'Pathankot',
#        'Rupnagar', 'S.A.S Nagar(Mohali)', 'Shaheed Bhagat Singh Nagar',
#        'Sri Muktsar Sahib', 'Tarn Taran', 'Banswara', 'Chittaurgarh',
#        'Chittorgarh', 'Dausa', 'Ganganagar', 'Hanumangarh', 'Jhunjhunu',
#        'Jhunjhunun', 'Pratapgarh', 'Rajsamand', 'Sawai Madhopur', 'Tonk',
#        'North', 'South', 'Ariyalur', 'Chengalpattu', 'Chennai',
#        'Dharmapuri', 'Dindigul', 'Erode', 'Kanniyakumari', 'Kanyakumari',
#        'Karur', 'Krishnagiri', 'Mayiladuthurai', 'Nagapattinam',
#        'Namakkal', 'Perambalur', 'Ranipet', 'Tenkasi', 'The Nilgiris',
#        'Theni', 'Thiruvallur', 'Thiruvarur', 'Thoothukkudi',
#        'Tiruchirappalli', 'Tirunelveli', 'Tirupattur', 'Tiruppur',
#        'Tiruvallur', 'Tiruvannamalai', 'Villupuram', 'Viluppuram',
#        'Virudhunagar', 'Adilabad', 'Bhadradri Kothagudem', 'Hanumakonda',
#        'Jangoan', 'Jayashankar Bhupalpally', 'Jogulamba Gadwal',
#        'Kamareddy', 'Karimnagar', 'Khammam', 'Komaram Bheem',
#        'Mahabubabad', 'Mahabubnagar', 'Mancherial', 'Medak',
#        'Medchal−malkajgiri', 'Mulugu', 'Nagarkurnool', 'Nalgonda',
#        'Nirmal', 'Nizamabad', 'Chamrajnagar', 'Chickmagalur',
#        'Chikkaballapur', 'Chikkamagaluru', 'Chikmagalur', 'Chitradurga',
#        'Dakshina Kannada', 'Davanagere', 'Davangere', 'Dharwad', 'Gadag',
#        'Gulbarga', 'Hasan', 'Hassan', 'Haveri', 'Kolar', 'Koppal',
#        'Mandya', 'Mysore', 'Ramanagar', 'Shimoga', 'Shivamogga',
#        'Tumakuru', 'Tumkur', 'Udupi', 'Uttara Kannada', 'Vijayanagara',
#        'Vijayapura', 'yadgir', 'Alappuzha', 'Idukki', 'Kannur',
#        'Kasaragod', 'Kasargod', 'Kottayam', 'Kozhikode', 'Palakkad',
#        'Pathanamthitta', 'Wayanad', 'Kargil', 'Agar Malwa', 'Anuppur',
#        'Balaghat', 'Chhindwara', 'Damoh', 'East Nimar', 'Harda',
#        'Hoshangabad', 'Mandla', 'Mandsaur', 'Narmadapuram', 'Narsimhapur',
#        'Narsinghpur', 'Neemuch', 'Rajgarh', 'Ratlam', 'Rewa', 'Sehore',
#        'Seoni', 'Shahdol', 'Shajapur', 'Sidhi', 'Singrauli', 'Tikamgarh',
#        'Ujjain', 'West Nimar', 'Akola', 'Bhandara', 'Buldana',
#        'Chatrapati Sambhaji Nagar', 'Chhatrapati Sambhajinagar',
#        'Gadchiroli', 'Gondia', 'Gondiya', 'Kolhapur', 'Mumbai',
#        'Mumbai City', 'Osmanabad', 'Raigarh', 'Ratnagiri', 'Sindhudurg',
#        'Wardha', 'Buxar', 'Khagaria', 'Kishanganj', 'Madhepura', 'Nawada',
#        'Purba Champaran', 'Purnea', 'Rohtas', 'Samastipur', 'Sheikhpura',
#        'Sheohar', 'Supaul', 'Bastar', 'Bemetara', 'Bilaspur',
#        'Dakshin Bastar Dantewada', 'Dhamtari', 'Janjgir-champa',
#        'Jashpur', 'Kawardha', 'Kondagaon', 'Korba', 'Koriya',
#        'Mahasamund', 'Manendragarh–Chirmiri–Bharatpur',
#        'Mohalla-Manpur-Ambagarh Chowki', 'Mungeli', 'Rajnandgaon',
#        'Sakti', 'Surajpur', 'Uttar Bastar Kanker', 'North Goa',
#        'South Goa', 'Narmada', 'Sabar Kantha', 'Bhiwani', 'Charkhi Dadri',
#        'Fatehabad', 'Jhajjar', 'Jind', 'Karnal', 'Mahendragarh', 'Palwal',
#        'Panchkula', 'Rewari', 'Sirsa', 'Yamuna Nagar', 'Yamunanagar',
#        'Chamba', 'Hamirpur', 'Kangra', 'Kullu', 'Mandi', 'Shimla',
#        'Sirmaur', 'Solan', 'Una', 'Anantnag', 'Bandipore', 'Ganderbal',
#        'Kathua', 'Kishtwar', 'Rajouri', 'Ramban', 'Reasi', 'Samba',
#        'Srinagar', 'Udhampur', 'Bokaro', 'Dhanbad', 'Garhwa', 'Garhwa *',
#        'Giridih', 'Hazaribag', 'Jamtara', 'Koderma', 'Latehar', 'Palamau',
#        'Palamu', 'Purbi Singhbhum', 'Ramgarh', 'Sahebganj',
#        'Seraikela-Kharsawan', 'Simdega', 'West Singhbhum', 'Bagalkot',
#        'Ballari', 'Bangalore', 'Belagavi', 'Belgaum', 'Bellary', 'Bidar',
#        'Chamarajanagar', 'Chamrajanagar', 'South Andaman',
#        'Alluri Sitharama Raju', 'Anakapalli', 'Anantapur', 'Ananthapur',
#        'Ananthapuramu', 'Annamayya', 'Bapatla', 'Chittoor', 'Cuddapah',
#        'Dr. B. R. Ambedkar Konaseema', 'East Godavari', 'Eluru', 'Guntur',
#        'Kakinada', 'Karim Nagar', 'Krishna', 'Kurnool', 'Mahabub Nagar',
#        'Mahbubnagar', 'N. T. R', 'Nandyal', 'Nellore', 'Palnadu',
#        'Parvathipuram Manyam', 'Prakasam', 'Rangareddi',
#        'Sri Potti Sriramulu Nellore', 'Sri Sathya Sai', 'Srikakulam',
#        'Tirupati', 'Visakhapatnam', 'Vizianagaram', 'Warangal',
#        'West Godavari', 'Y. S. R', 'Anjaw', 'Changlang', 'Kra Daadi',
#        'Lohit', 'Lower Subansiri', 'Papum Pare', 'Siang', 'West Kameng',
#        'Begusarai', 'Bhojpur', 'Peddapalli', 'Rajanna Sircilla',
#        'Rangareddy', 'Sangareddy', 'Siddipet', 'Suryapet', 'Vikarabad',
#        'Wanaparthy', 'Warangal Rural', 'Warangal Urban', 'Yadadri.',
#        'Dhalai  *', 'Gomati', 'North Tripura', 'Sepahijala',
#        'South Tripura', 'Allahabad', 'Amethi', 'Auraiya', 'Ballia',
#        'Bhadohi', 'Chitrakoot', 'Faizabad', 'Ghazipur', 'Jhansi',
#        'Kannauj', 'Kasganj', 'Mahoba', 'Mau', 'Mirzapur', 'Rae Bareli',
#        'Sambhal', 'Sant Kabir Nagar', 'Sant Ravidas Nagar', 'Sonbhadra',
#        'Almora', 'Chamoli', 'Champawat', 'Pauri Garhwal', 'Pithoragarh',
#        'Tehri Garhwal', 'Udham Singh Nagar', 'Uttarkashi', 'Bankura',
#        'Barddhaman', 'Bardhaman', 'Darjiling', 'East Midnapore', 'Haora',
#        'Hooghly', 'Howrah', 'Koch Bihar', 'Maldah', 'Murshidabad',
#        'North Dinajpur', 'North Twenty Four Parganas',
#        'Paschim Bardhaman', 'Paschim Medinipur', 'Purba Medinipur',
#        'Purulia', 'Puruliya', 'South 24 Parganas', 'South Dinajpur',
#        'South Twenty Four Parganas', 'West Midnapore', 'Surguja',
#        'North East', 'Budgam', 'Doda', 'Kulgam', 'Kupwara', 'Pulwama',
#        'Chatra *', 'Kodarma', 'Seraikela-kharsawan', 'Bagalkot *',
#        'Kodagu', 'Lakshadweep', 'Dindori', 'Umaria', 'Ahmed Nagar', 'Bid',
#        'Dharashiv', 'Jalna', 'Mumbai( Sub Urban )', 'Washim *', 'Chandel',
#        'Debagarh', 'Jagatsinghpur', 'Nuapada', 'Yanam', 'Jagitial',
#        'Narayanpet', 'Sheikpura', 'Balod', 'Gariyaband', 'Kabeerdham',
#        'Kanker', '100000', 'Andamans', 'Nicobar', 'East Kameng',
#        'Kurung Kumey', 'Lower Dibang Valley', 'Namsai', 'Tawang',
#        'West Siang', 'Majuli', 'Aurangabad(bh)', 'Bhabua', 'Barabanki',
#        'Jyotiba Phule Nagar', 'Sant Ravidas Nagar Bhadohi', 'Bageshwar',
#        'Rudraprayag', 'HOOGHLY', 'Dadra and Nagar Haveli', 'Daman', 'Diu',
#        'Panch Mahals', 'Surendranagar', 'Leh', 'Shupiyan', 'Pakaur',
#        'Haveri *', 'Harda *', 'Nandurbar *', 'Imphal East', 'Jiribam',
#        'Aizawl', 'Kolasib', 'Muktsar', 'East Siang', 'Longding',
#        'Upper Siang', 'Upper Subansiri', 'Dantewada', 'Janjgir - Champa',
#        'Janjgir Champa', 'Mohla-Manpur-Ambagarh Chouki', 'Hugli', 'East',
#        'East Sikkim', 'North Sikkim', 'Gondiya *', 'Raigarh(MH)',
#        'Mokokchung', 'Wokha', 'Baudh', 'West', 'Khowai', 'Kinnaur',
#        'Badgam', 'Pashchimi Singhbhum', 'North And Middle Andaman',
#        'Kamle', 'Leparada', 'Shi-yomi', 'Tirap', 'Niwari',
#        'Dibang Valley', 'Sribhumi', 'Gaurela-pendra-marwahi',
#        'Narayanpur', 'Khawzawl', 'Serchhip', 'Chamarajanagar *',
#        'Thoubal', 'Mahrajganj', 'Jangaon', 'Bulandshahar', 'Sahibganj',
#        'Gadag *', 'Maihar', 'K.V.Rangareddy', 'Pakke Kessang', 'Monghyr',
#        'Samstipur', 'Dadra & Nagar Haveli', 'Eastern West Khasi Hills',
#        'Niuland', 'Jajpur', 'Dhaulpur', 'South East Delhi',
#        'Lahul & Spiti', 'Mauganj', 'Lower Siang', 'Lahaul and Spiti',
#        'Bijapur(KAR)', 'Hardwar', 'jajpur', 'Pandhurna',
#        'Khairagarh Chhuikhadan Gandai', 'chittoor', 'Kakching',
#        'Lahul and Spiti', 'Medinipur', 'Bengaluru South', 'Jaintia Hills',
#        'Saitual', 'Mohali', 'rangareddi', 'Aurangabad(BH)', 'Khordha  *',
#        'MALDA', 'East Midnapur', 'Bagpat', 'hooghly', 'Garhwal',
#        'Najafgarh', 'Khairthal-Tijara', 'Hnahthial', 'Tirupathur',
#        'NADIA', 'HOWRAH', 'Tamulpur District', 'Sarangarh-Bilaigarh',
#        'Rajauri', 'Ahmednagar', 'Jalore', '24 Paraganas South',
#        'Nabarangpur', 'Ramanagara', 'East Singhbum', 'Ranga Reddy',
#        'Dinajpur Dakshin', 'Shopian', 'Kushi Nagar', 'Bajali', 'Meluri',
#        'Shamator', 'Tuticorin', 'Warangal (urban)', 'Namchi', 'Nicobars',
#        'Jhajjar *', 'ANUGUL', 'Raebareli', 'Hawrah', 'Deeg\xa0',
#        'Medchal?malkajgiri', 'Tseminyu', 'Kushinagar *', 'Tiruvarur',
#        'nadia', 'Hingoli *', 'North East   *', 'Bardez', 'Namakkal   *',
#        'Hooghiy', 'Pherzawl', 'KOLKATA', 'West Medinipur', 'Burdwan',
#        'Bandipur', 'South 24 parganas', 'Leh (ladakh)', 'Bokaro *',
#        'South 24 Pargana', 'Deeg', 'Anugal', 'Udupi *', 'Mangan',
#        'Kendrapara *', 'ANGUL', 'Ahilyanagar', 'Didwana-Kuchaman',
#        'Salumbar', 'Beawar', 'Balotra', 'Kotputli-Behror'], dtype=object)

# %%
df['district'].nunique()
# Out:
# 989

# %% [markdown]
# # State Names Cleaning

# %%
STATE_STANDARD_MAP = {
    'andhra pradesh': 'Andhra Pradesh',
    'arunachal pradesh': 'Arunachal Pradesh',
    'assam': 'Assam',
    'bihar': 'Bihar',
    'chhattisgarh': 'Chhattisgarh',
    'goa': 'Goa',
    'gujarat': 'Gujarat',
    'haryana': 'Haryana',
    'himachal pradesh': 'Himachal Pradesh',
    'jharkhand': 'Jharkhand',
    'karnataka': 'Karnataka',
    'kerala': 'Kerala',
    'madhya pradesh': 'Madhya Pradesh',
    'maharashtra': 'Maharashtra',
    'manipur': 'Manipur',
    'meghalaya': 'Meghalaya',
    'mizoram': 'Mizoram',
    'nagaland': 'Nagaland',
    'odisha': 'Odisha',
    'orissa': 'Odisha',
    'punjab': 'Punjab',
    'rajasthan': 'Rajasthan',
    'sikkim': 'Sikkim',
    'tamil nadu': 'Tamil Nadu',
    'tamilnadu': 'Tamil Nadu',
    'telangana': 'Telangana',
    'tripura': 'Tripura',
    'uttar pradesh': 'Uttar Pradesh',
    'uttarakhand': 'Uttarakhand',
    'uttaranchal': 'Uttarakhand',
    'west bengal': 'West Bengal',
    'westbengal': 'West Bengal',

    # UTs
    'andaman and nicobar islands': 'Andaman and Nicobar Islands',
    'andaman nicobar islands': 'Andaman and Nicobar Islands',
    'chandigarh': 'Chandigarh',
    'dadra and nagar haveli and daman and diu': 'Dadra and Nagar Haveli and Daman and Diu',
    'dadra nagar haveli': 'Dadra and Nagar Haveli and Daman and Diu',
    'daman and diu': 'Dadra and Nagar Haveli and Daman and Diu',
    'delhi': 'Delhi',
    'new delhi': 'Delhi',
    'jammu and kashmir': 'Jammu and Kashmir',
    'jammu kashmir': 'Jammu and Kashmir',
    'jammu kashmir': 'Jammu and Kashmir',
    'ladakh': 'Ladakh',
    'lakshadweep': 'Lakshadweep',
    'puducherry': 'Puducherry',
    'pondicherry': 'Puducherry',

    # West Bengal variants
    'westbengal': 'West Bengal',
    'west bangal': 'West Bengal',

    # Tamil Nadu variants
    'tamilnadu': 'Tamil Nadu',

    # Andaman variants
    'andaman nicobar islands': 'Andaman and Nicobar Islands',

    # Daman variants
    'daman diu': 'Dadra and Nagar Haveli and Daman and Diu',

    # Dadra variants
    'dadra nagar haveli': 'Dadra and Nagar Haveli and Daman and Diu',
    'the dadra and nagar haveli and daman and diu': 'Dadra and Nagar Haveli and Daman and Diu',
    'dadra and nagar haveli': 'Dadra and Nagar Haveli and Daman and Diu',
    'chhatisgarh': 'Chhattisgarh'
}

# %%
import re
import pandas as pd

def normalize_text(x):
    if pd.isna(x):
        return x
    x = x.lower().strip()
    x = re.sub(r'[^a-z0-9 ]', ' ', x)
    x = re.sub(r'\s+', ' ', x)
    return x

df['state_norm'] = df['state'].apply(normalize_text)

# %%
df['state_norm'].nunique()
# Out:
# 48

# %%
df['state_clean'] = df['state_norm'].map(STATE_STANDARD_MAP)

# %%
df['state_clean'].isna().sum()
# Out:
# 30

# %%
df['state_clean'].unique()
# Out:
# array(['Meghalaya', 'Karnataka', 'Uttar Pradesh', 'Bihar', 'Maharashtra',
#        'Haryana', 'Rajasthan', 'Punjab', 'Delhi', 'Madhya Pradesh',
#        'West Bengal', 'Assam', 'Uttarakhand', 'Gujarat', 'Andhra Pradesh',
#        'Tamil Nadu', 'Chhattisgarh', 'Jharkhand', 'Nagaland', 'Manipur',
#        'Telangana', 'Tripura', 'Mizoram', 'Jammu and Kashmir',
#        'Chandigarh', 'Sikkim', 'Odisha', 'Kerala',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Puducherry', 'Ladakh',
#        'Goa', 'Himachal Pradesh', 'Andaman and Nicobar Islands',
#        'Arunachal Pradesh', 'Lakshadweep', nan], dtype=object)

# %%
df['state_clean'].nunique()
# Out:
# 36

# %%
unmapped_states = (
    df.loc[df['state_clean'].isna(), 'state_norm']
    .value_counts()
)

unmapped_states
# Out:
# state_norm
# 100000    30
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# date               0
# state              0
# district           0
# pincode            0
# age_0_5            0
# age_5_17           0
# age_18_greater     0
# state_norm         0
# state_clean       30
# dtype: int64

# %%
df.head()
# Out:
#          date          state          district  pincode  age_0_5  age_5_17  \
# 0  02-03-2025      Meghalaya  East Khasi Hills   793121       11        61
# 1  09-03-2025      Karnataka   Bengaluru Urban   560043       14        33
# 2  09-03-2025  Uttar Pradesh      Kanpur Nagar   208001       29        82
# 3  09-03-2025  Uttar Pradesh           Aligarh   202133       62        29
# 4  09-03-2025      Karnataka   Bengaluru Urban   560016       14        16
#
#    age_18_greater     state_norm    state_clean
# 0              37      meghalaya      Meghalaya
# 1              39      karnataka      Karnataka
# 2              12  uttar pradesh  Uttar Pradesh
# 3              15  uttar pradesh  Uttar Pradesh
# 4              21      karnataka      Karnataka

# %%
df_100000 = df[df['state_norm'] == '100000']
df_100000
# Out:
#                date   state district  pincode  age_0_5  age_5_17  \
# 7994     09-06-2025  100000   100000   100000        0         0
# 40577    11-06-2025  100000   100000   100000        0         0
# 62866    12-06-2025  100000   100000   100000        0         0
# 100377   16-06-2025  100000   100000   100000        0         0
# 129781   17-06-2025  100000   100000   100000        0         0
# 143724   18-06-2025  100000   100000   100000        0         0
# 150716   19-06-2025  100000   100000   100000        0         0
# 152420   19-06-2025  100000   100000   100000        0         0
# 184239   02-09-2025  100000   100000   100000        0         0
# 208077   03-09-2025  100000   100000   100000        0         0
# 258947   08-09-2025  100000   100000   100000        0         0
# 276929   09-09-2025  100000   100000   100000        0         0
# 314287   11-09-2025  100000   100000   100000        0         0
# 321326   12-09-2025  100000   100000   100000        0         0
# 422909   19-09-2025  100000   100000   100000        0         0
# 433862   20-09-2025  100000   100000   100000        0         0
# 632065   24-10-2025  100000   100000   100000        0         1
# 921189   15-11-2025  100000   100000   100000        0         0
# 941958   16-11-2025  100000   100000   100000        0         0
# 952752   17-11-2025  100000   100000   100000        0         0
# 983915   19-11-2025  100000   100000   100000        0         0
# 1021715  15-12-2025  100000   100000   100000        0         0
# 1076559  24-12-2025  100000   100000   100000        0         0
# 1090352  25-12-2025  100000   100000   100000        0         0
# 1108962  26-12-2025  100000   100000   100000        0         0
# 1120245  27-12-2025  100000   100000   100000        0         0
# 1130050  28-12-2025  100000   100000   100000        0         0
# 1137786  29-12-2025  100000   100000   100000        0         0
# 1150226  31-12-2025  100000   100000   100000        0         0
# 1199182  02-01-2026  100000   100000   100000        0         0
#
#          age_18_greater state_norm state_clean
# 7994                  3     100000         NaN
# 40577                 2     100000         NaN
# 62866                 3     100000         NaN
# 100377                1     100000         NaN
# 129781                1     100000         NaN
# 143724                1     100000         NaN
# 150716                3     100000         NaN
# 152420                3     100000         NaN
# 184239                3     100000         NaN
# 208077                1     100000         NaN
# 258947                1     100000         NaN
# 276929                1     100000         NaN
# 314287                2     100000         NaN
# 321326                2     100000         NaN
# 422909                1     100000         NaN
# 433862                1     100000         NaN
# 632065                0     100000         NaN
# 921189                3     100000         NaN
# 941958                2     100000         NaN
# 952752                4     100000         NaN
# 983915                2     100000         NaN
# 1021715             161     100000         NaN
# 1076559               1     100000         NaN
# 1090352               4     100000         NaN
# 1108962               3     100000         NaN
# 1120245               4     100000         NaN
# 1130050               5     100000         NaN
# 1137786               8     100000         NaN
# 1150226               4     100000         NaN
# 1199182               3     100000         NaN

# %%
df = df[df['state_norm'] != '100000']

# %%
df.drop(columns=['state', 'state_norm'], inplace=True)
df.rename(columns={'state_clean': 'state'}, inplace=True)

# %%
df.state.nunique()
# Out:
# 36

# %%
df['state'].unique()
# Out:
# array(['Meghalaya', 'Karnataka', 'Uttar Pradesh', 'Bihar', 'Maharashtra',
#        'Haryana', 'Rajasthan', 'Punjab', 'Delhi', 'Madhya Pradesh',
#        'West Bengal', 'Assam', 'Uttarakhand', 'Gujarat', 'Andhra Pradesh',
#        'Tamil Nadu', 'Chhattisgarh', 'Jharkhand', 'Nagaland', 'Manipur',
#        'Telangana', 'Tripura', 'Mizoram', 'Jammu and Kashmir',
#        'Chandigarh', 'Sikkim', 'Odisha', 'Kerala',
#        'Dadra and Nagar Haveli and Daman and Diu', 'Puducherry', 'Ladakh',
#        'Goa', 'Himachal Pradesh', 'Andaman and Nicobar Islands',
#        'Arunachal Pradesh', 'Lakshadweep'], dtype=object)

# %%
df.isnull().sum()
# Out:
# date              0
# district          0
# pincode           0
# age_0_5           0
# age_5_17          0
# age_18_greater    0
# state             0
# dtype: int64

# %% [markdown]
# # District Names Cleaning

# %%
def normalize_text(x):
    if pd.isna(x):
        return x
    x = x.lower().strip()
    x = re.sub(r'[^a-z0-9 \-\(\)\.]', ' ', x)  # keep basic separators
    x = re.sub(r'\s+', ' ', x)
    return x

# %%
df['district_norm'] = df['district'].apply(normalize_text)

# %%
df[['district', 'district_norm']].head()
# Out:
#            district     district_norm
# 0  East Khasi Hills  east khasi hills
# 1   Bengaluru Urban   bengaluru urban
# 2      Kanpur Nagar      kanpur nagar
# 3           Aligarh           aligarh
# 4   Bengaluru Urban   bengaluru urban

# %%
df['district_clean'] = (
    df['district_norm']
    .str.replace(r'\*', '', regex=True)
    .str.strip()
)

# %%
DISTRICT_ALIAS_MAP = {

    # Tamil Nadu
    'tuticorin': 'Thoothukkudi',

    # Karnataka
    'bangalore': 'Bengaluru',
    'belgaum': 'Belagavi',
    'shimoga': 'Shivamogga',
    'mysore': 'Mysuru',

    # Maharashtra / MP
    'gondia': 'Gondiya',
    'ahmadabad': 'Ahmedabad',
    'ahmed nagar': 'Ahilyanagar',
    'hoshangabad': 'Narmadapuram',

    # Uttarakhand
    'hardwar': 'Haridwar',

    # Uttar Pradesh
    'allahabad': 'Prayagraj',

    # Andhra Pradesh
    'ysr': 'Y.S.R. Kadapa',
    'y s r': 'Y.S.R. Kadapa',

    # Rangareddy variants
    'k v rangareddy': 'K.V. Rangareddy',
    'k v rangareddi': 'K.V. Rangareddy',

    # Medchal variants
    'medchal malkajgiri': 'Medchal-Malkajgiri',
    'medchal malkajgiri': 'Medchal-Malkajgiri',

    'Tumkur': 'Tumakuru',
    'Bellary': 'Ballari',
    'Burdwan': 'Bardhaman',
    'Hugli': 'Hooghly',
    'Hawrah': 'Howrah',
    'Ahmadnagar': 'Ahilyanagar',
    'Cuddapah': 'Y.S.R. Kadapa',
    'Y. S. R': 'Y.S.R. Kadapa',
    'K.V.Rangareddy': 'K.V. Rangareddy',

    'Barddhaman': 'Bardhaman',
    'Hooghiy': 'Hooghly',
    'Haora': 'Howrah',
    'Bellary': 'Ballari',
    'Cuddapah': 'Y.S.R. Kadapa',
    'Y.S.R.': 'Y.S.R. Kadapa',
    'Y. S. R': 'Y.S.R. Kadapa',
    'K.V.Rangareddy': 'K.V. Rangareddy',
    'Mumbai( Sub Urban )': 'Mumbai Suburban',
    'Warangal (Urban)': 'Warangal Urban',

    'Anantapur': 'Ananthapuramu',
    'Ananthapur': 'Ananthapuramu',

    'Karim Nagar': 'Karimnagar',

    'Banas Kantha': 'Banaskantha',

    'Lahul Spiti': 'Lahaul And Spiti',

    'K.V. Rangareddy': 'Rangareddy',

    

}

# %%
df['district_clean'] = (
    df['district_clean']
    .replace(DISTRICT_ALIAS_MAP)
    .str.title()
)

# %%
def district_key(x):
    if pd.isna(x):
        return x
    x = x.lower().strip()
    x = re.sub(r'[^a-z0-9]', '', x)
    return x

df['district_key'] = df['district_clean'].apply(district_key)

# %%
dup_districts = (
    df.groupby('district_key')['district_clean']
    .nunique()
    .sort_values(ascending=False)
)

dup_districts[dup_districts > 1].head(20)
# Out:
# district_key
# janjgirchampa     3
# mumbaisuburban    2
# raebareli         2
# coochbehar        2
# barabanki         2
# karimnagar        2
# sasnagarmohali    2
# siddharthnagar    2
# ashoknagar        2
# mahabubnagar      2
# panchmahals       2
# warangalurban     2
# sabarkantha       2
# surendranagar     2
# banaskantha       2
# kvrangareddy      2
# rangareddy        2
# yamunanagar       2
# kushinagar        2
# Name: district_clean, dtype: int64

# %%
print("Unique districts after cleaning:", df['district_clean'].nunique())
# Out:
# Unique districts after cleaning: 934

# %%
df.drop(columns=['district', 'district_norm', 'district_key'], inplace=True)
df.rename(columns={'district_clean': 'district'}, inplace=True)

# %%
df['district'].unique()
# Out:
# array(['East Khasi Hills', 'Bengaluru Urban', 'Kanpur Nagar', 'Aligarh',
#        'Sitamarhi', 'Bahraich', 'Firozabad', 'Purbi Champaran',
#        'Maharajganj', 'Aurangabad', 'Ghaziabad', 'Faridabad', 'Madhubani',
#        'Sikar', 'Bhagalpur', 'Amritsar', 'Gurugram',
#        'Gautam Buddha Nagar', 'West Delhi', 'Bhind', 'Gwalior', 'Katni',
#        'Coochbehar', 'Lucknow', 'Dinajpur Uttar', 'Marigaon', 'Kokrajhar',
#        'Agra', 'Haridwar', 'Nagaon', 'Parbhani', 'West Khasi Hills',
#        'North West Delhi', 'West Jaintia Hills', 'Unnao', 'Saharanpur',
#        'Dibrugarh', 'Udalguri', 'Chirang', 'Kamrup', 'Dhubri', 'Jaunpur',
#        'Thane', 'Dhemaji', 'Banas Kantha', 'Tinsukia', 'Spsr Nellore',
#        'Barpeta', 'Sonitpur', 'Baksa', 'Ludhiana', 'Patan', 'Kanchipuram',
#        'Patna', 'Lakhimpur', 'Bongaigaon', 'Vadodara', 'Nainital',
#        'Dehradun', 'Hojai', 'Dohad', 'Morbi', 'Raipur', 'Gorakhpur',
#        'Bulandshahr', 'Mathura', 'Pashchim Champaran', 'Bijapur',
#        'Deoghar', 'Muzaffarpur', 'Banda', 'Kachchh', 'Ri Bhoi', 'Darrang',
#        'Ashok Nagar', 'Darjeeling', 'North Cachar Hills', 'Ranchi',
#        'Surat', 'Nanded', 'Bengaluru', 'Jorhat', 'Gir Somnath',
#        'Kamrup Metro', 'Goalpara', 'Bhavnagar', 'Golaghat', 'Nagpur',
#        'Cooch Behar', 'Jalgaon', 'Hingoli', 'Ahmadnagar', 'Gandhinagar',
#        'North 24 Parganas', 'Munger', 'Kohima', 'Jalor', 'Kheda',
#        'Nalbari', 'Palghar', 'Jodhpur', 'Central Delhi', 'Gaya',
#        'Sabarkantha', 'Dimapur', 'Cachar', 'Banaskantha', 'Kheri',
#        'Rajkot', 'Satara', 'Betul', 'West Karbi Anglong', 'South Delhi',
#        'Raigad', 'Uttar Dinajpur', 'Guna', 'Kaimur (Bhabua)', 'Dholpur',
#        'Churachandpur', 'West Champaran', 'Bharuch', 'Jhargram',
#        'Khargone', 'Chhotaudepur', 'Mumbai Suburban', 'Hailakandi',
#        'Panchmahals', 'South Salmara Mankachar', 'Budaun', 'Kanpur Dehat',
#        'Porbandar', 'West Garo Hills', 'Kapurthala', 'South Garo Hills',
#        'Nagaur', 'Mysuru', 'Mahesana', 'Churu', 'Hyderabad',
#        'Kancheepuram', 'Varanasi', 'Lohardaga', 'North Garo Hills',
#        'Chhatarpur', 'Nadia', 'Purnia', 'Gurgaon', 'Charaideo', 'Jaipur',
#        'Saran', 'Morena', 'Dhar', 'Dahod', 'Devbhumi Dwarka',
#        'East Champaran', 'Tapi', 'Baghpat', 'Fatehpur',
#        'South West Khasi Hills', 'Yadgir', 'Nandurbar', 'Etawah',
#        'Jalpaiguri', 'Jabalpur', 'Shamli', 'Sibsagar', 'Barwani', 'Botad',
#        'Junagadh', 'Balrampur', 'Bara Banki', 'Shivpuri', 'Beed',
#        'Shahjahanpur', 'Jamnagar', 'Chandrapur', 'Durg',
#        'K.V. Rangareddy', 'Sirohi', 'Alipurduar', 'South West Delhi',
#        'Gonda', 'East Jaintia Hills', 'Bareilly', 'Bundi', 'Solapur',
#        'Sitapur', 'Dumka', 'Sultanpur', 'Karbi Anglong', 'Bikaner',
#        'Phek', 'Raisen', 'Shrawasti', 'East Delhi', 'Jhabua', 'Unakoti',
#        'Indore', 'Bhopal', 'Dungarpur', 'Chandauli', 'Bharatpur',
#        'Mainpuri', 'Godda', 'Muzaffarnagar', 'Siddharthnagar', 'Datia',
#        'West Tripura', 'Medchal-Malkajgiri', 'Sagar', 'Sheopur',
#        'Arvalli', 'Surendra Nagar', 'Malda', 'Amreli', 'Alwar',
#        'Ambedkar Nagar', 'Madurai', 'Pilibhit', 'Champhai', 'Valsad',
#        'Pakur', 'Vaishali', 'Vidisha', 'Karimganj', 'Biswanath',
#        'Burhanpur', 'Kaushambi', 'Pune', 'Punch', 'Jehanabad', 'Jalaun',
#        'Etah', 'Meerut', 'Baran', 'Sangrur', 'Karauli', 'Anand',
#        'Longleng', 'Chandigarh', 'Jamui', 'South Sikkim', 'Panna',
#        'East Garo Hills', 'Jhalawar', 'Shahdara', 'Kalaburagi',
#        'Thanjavur', 'Peren', 'Tuensang', 'Mahisagar', 'Hoshiarpur',
#        'Noklak', 'Sukma', 'Khandwa', 'Ajmer', 'West Sikkim', 'Latur',
#        'Basti', 'Satna', 'Gurdaspur', 'Hazaribagh', 'Azamgarh', 'Udaipur',
#        'Kolkata', 'Rampur', 'The Dangs', 'East Singhbhum', 'Alirajpur',
#        'Sas Nagar (Mohali)', 'South West Garo Hills', 'Moradabad', 'Kota',
#        'Dewas', 'Navsari', 'Chumukedima', 'Ahmedabad', 'Nabarangapur',
#        'Pali', 'Amroha', 'Saiha', 'Dakshin Dinajpur', 'Bijnor',
#        'Pudukkottai', 'Bangalore Rural', 'Kalimpong', 'Deoria',
#        'Baramula', 'Gopalganj', 'Prayagraj', 'Lalitpur', 'Mewat', 'Hapur',
#        'Jammu', 'Bishnupur', 'Saharsa', 'Arwal', 'Hathras', 'Lawngtlai',
#        'Nashik', 'Yavatmal', 'Cuddalore', 'Kollam', 'Patiala', 'Katihar',
#        'Malappuram', 'Birbhum', 'Siwan', 'Dhule', 'Baloda Bazar',
#        'Washim', 'Coimbatore', 'Lunglei', 'Imphal West', 'Kushinagar',
#        'Thiruvananthapuram', 'Sangli', 'Lakhisarai', 'Bengaluru Rural',
#        '24 Paraganas North', 'Dima Hasao', 'Banka', 'Salem',
#        'Dadra And Nagar Haveli', 'Dang', 'Kaithal', 'Vellore',
#        'Shravasti', 'Nalanda', 'Jaisalmer', 'Kallakurichi', 'Farrukhabad',
#        'Medinipur West', 'Araria', 'Sonipat', 'Chatra',
#        'Gaurella Pendra Marwahi', 'Visakhapatanam', 'Buldhana',
#        'Amravati', 'Hardoi', 'Dhalai', 'Ernakulam', 'New Delhi',
#        'Bhilwara', 'Ramanathapuram', 'Mon', 'Raichur', 'North Delhi',
#        'Rohtak', 'Gumla', 'Barmer', 'Kurukshetra', 'Nuh', 'Ashoknagar',
#        'Thrissur', 'S.A.S Nagar', 'North East Delhi', 'Purba Bardhaman',
#        'Ambala', 'Panipat', 'Darbhanga', 'Ayodhya', 'Khunti', 'Sivasagar',
#        'Hisar', 'Sivaganga', 'Siddharth Nagar', 'Senapati', 'Tamenglong',
#        'Ukhrul', 'Mamit', 'Mammit', 'Kiphire', 'Zunheboto', 'Angul',
#        'Balangir', 'Baleshwar', 'Baleswar', 'Bargarh', 'Bhadrak', 'Boudh',
#        'Cuttack', 'Dhenkanal', 'Gajapati', 'Ganjam', 'Jajpur',
#        'Jagatsinghapur', 'Jajapur', 'Jharsuguda', 'Kalahandi',
#        'Kandhamal', 'Kendrapara', 'Kendujhar', 'Khorda', 'Khordha',
#        'Koraput', 'Malkangiri', 'Mayurbhanj', 'Nuapada', 'Nayagarh',
#        'Puri', 'Rayagada', 'Sambalpur', 'Sonapur', 'Subarnapur',
#        'Sundargarh', 'Sundergarh', 'Anugul', 'Karaikal', 'Pondicherry',
#        'Puducherry', 'Barnala', 'Bathinda', 'Faridkot', 'Fatehgarh Sahib',
#        'Fazilka', 'Ferozepur', 'Firozpur', 'Jalandhar', 'Malerkotla',
#        'Mansa', 'Moga', 'Nawanshahr', 'Pathankot', 'Rupnagar',
#        'S.A.S Nagar(Mohali)', 'Shaheed Bhagat Singh Nagar',
#        'Sri Muktsar Sahib', 'Tarn Taran', 'Banswara', 'Chittaurgarh',
#        'Chittorgarh', 'Dausa', 'Ganganagar', 'Hanumangarh', 'Jhunjhunu',
#        'Jhunjhunun', 'Pratapgarh', 'Rajsamand', 'Sawai Madhopur', 'Tonk',
#        'North', 'South', 'Ariyalur', 'Chengalpattu', 'Chennai',
#        'Dharmapuri', 'Dindigul', 'Erode', 'Kanniyakumari', 'Kanyakumari',
#        'Karur', 'Krishnagiri', 'Mayiladuthurai', 'Nagapattinam',
#        'Namakkal', 'Perambalur', 'Ranipet', 'Tenkasi', 'The Nilgiris',
#        'Theni', 'Thiruvallur', 'Thiruvarur', 'Thoothukkudi',
#        'Tiruchirappalli', 'Tirunelveli', 'Tirupattur', 'Tiruppur',
#        'Tiruvallur', 'Tiruvannamalai', 'Villupuram', 'Viluppuram',
#        'Virudhunagar', 'Adilabad', 'Bhadradri Kothagudem', 'Hanumakonda',
#        'Jangoan', 'Jayashankar Bhupalpally', 'Jogulamba Gadwal',
#        'Kamareddy', 'Karimnagar', 'Khammam', 'Komaram Bheem',
#        'Mahabubabad', 'Mahabubnagar', 'Mancherial', 'Medak', 'Mulugu',
#        'Nagarkurnool', 'Nalgonda', 'Nirmal', 'Nizamabad', 'Chamrajnagar',
#        'Chickmagalur', 'Chikkaballapur', 'Chikkamagaluru', 'Chikmagalur',
#        'Chitradurga', 'Dakshina Kannada', 'Davanagere', 'Davangere',
#        'Dharwad', 'Gadag', 'Gulbarga', 'Hasan', 'Hassan', 'Haveri',
#        'Kolar', 'Koppal', 'Mandya', 'Ramanagar', 'Shivamogga', 'Tumakuru',
#        'Tumkur', 'Udupi', 'Uttara Kannada', 'Vijayanagara', 'Vijayapura',
#        'Alappuzha', 'Idukki', 'Kannur', 'Kasaragod', 'Kasargod',
#        'Kottayam', 'Kozhikode', 'Palakkad', 'Pathanamthitta', 'Wayanad',
#        'Kargil', 'Agar Malwa', 'Anuppur', 'Balaghat', 'Chhindwara',
#        'Damoh', 'East Nimar', 'Harda', 'Narmadapuram', 'Mandla',
#        'Mandsaur', 'Narsimhapur', 'Narsinghpur', 'Neemuch', 'Rajgarh',
#        'Ratlam', 'Rewa', 'Sehore', 'Seoni', 'Shahdol', 'Shajapur',
#        'Sidhi', 'Singrauli', 'Tikamgarh', 'Ujjain', 'West Nimar', 'Akola',
#        'Bhandara', 'Buldana', 'Chatrapati Sambhaji Nagar',
#        'Chhatrapati Sambhajinagar', 'Gadchiroli', 'Gondiya', 'Kolhapur',
#        'Mumbai', 'Mumbai City', 'Osmanabad', 'Raigarh', 'Ratnagiri',
#        'Sindhudurg', 'Wardha', 'Buxar', 'Khagaria', 'Kishanganj',
#        'Madhepura', 'Nawada', 'Purba Champaran', 'Purnea', 'Rohtas',
#        'Samastipur', 'Sheikhpura', 'Sheohar', 'Supaul', 'Bastar',
#        'Bemetara', 'Bilaspur', 'Dakshin Bastar Dantewada', 'Dhamtari',
#        'Janjgir-Champa', 'Jashpur', 'Kawardha', 'Kondagaon', 'Korba',
#        'Koriya', 'Mahasamund', 'Manendragarh Chirmiri Bharatpur',
#        'Mohalla-Manpur-Ambagarh Chowki', 'Mungeli', 'Rajnandgaon',
#        'Sakti', 'Surajpur', 'Uttar Bastar Kanker', 'North Goa',
#        'South Goa', 'Narmada', 'Sabar Kantha', 'Bhiwani', 'Charkhi Dadri',
#        'Fatehabad', 'Jhajjar', 'Jind', 'Karnal', 'Mahendragarh', 'Palwal',
#        'Panchkula', 'Rewari', 'Sirsa', 'Yamuna Nagar', 'Yamunanagar',
#        'Chamba', 'Hamirpur', 'Kangra', 'Kullu', 'Mandi', 'Shimla',
#        'Sirmaur', 'Solan', 'Una', 'Anantnag', 'Bandipore', 'Ganderbal',
#        'Kathua', 'Kishtwar', 'Rajouri', 'Ramban', 'Reasi', 'Samba',
#        'Srinagar', 'Udhampur', 'Bokaro', 'Dhanbad', 'Garhwa', 'Giridih',
#        'Hazaribag', 'Jamtara', 'Koderma', 'Latehar', 'Palamau', 'Palamu',
#        'Purbi Singhbhum', 'Ramgarh', 'Sahebganj', 'Seraikela-Kharsawan',
#        'Simdega', 'West Singhbhum', 'Bagalkot', 'Ballari', 'Belagavi',
#        'Bellary', 'Bidar', 'Chamarajanagar', 'Chamrajanagar',
#        'South Andaman', 'Alluri Sitharama Raju', 'Anakapalli',
#        'Anantapur', 'Ananthapur', 'Ananthapuramu', 'Annamayya', 'Bapatla',
#        'Chittoor', 'Cuddapah', 'Dr. B. R. Ambedkar Konaseema',
#        'East Godavari', 'Eluru', 'Guntur', 'Kakinada', 'Karim Nagar',
#        'Krishna', 'Kurnool', 'Mahabub Nagar', 'Mahbubnagar', 'N. T. R',
#        'Nandyal', 'Nellore', 'Palnadu', 'Parvathipuram Manyam',
#        'Prakasam', 'Rangareddi', 'Sri Potti Sriramulu Nellore',
#        'Sri Sathya Sai', 'Srikakulam', 'Tirupati', 'Visakhapatnam',
#        'Vizianagaram', 'Warangal', 'West Godavari', 'Y. S. R', 'Anjaw',
#        'Changlang', 'Kra Daadi', 'Lohit', 'Lower Subansiri', 'Papum Pare',
#        'Siang', 'West Kameng', 'Begusarai', 'Bhojpur', 'Peddapalli',
#        'Rajanna Sircilla', 'Rangareddy', 'Sangareddy', 'Siddipet',
#        'Suryapet', 'Vikarabad', 'Wanaparthy', 'Warangal Rural',
#        'Warangal Urban', 'Yadadri.', 'Gomati', 'North Tripura',
#        'Sepahijala', 'South Tripura', 'Amethi', 'Auraiya', 'Ballia',
#        'Bhadohi', 'Chitrakoot', 'Faizabad', 'Ghazipur', 'Jhansi',
#        'Kannauj', 'Kasganj', 'Mahoba', 'Mau', 'Mirzapur', 'Rae Bareli',
#        'Sambhal', 'Sant Kabir Nagar', 'Sant Ravidas Nagar', 'Sonbhadra',
#        'Almora', 'Chamoli', 'Champawat', 'Pauri Garhwal', 'Pithoragarh',
#        'Tehri Garhwal', 'Udham Singh Nagar', 'Uttarkashi', 'Bankura',
#        'Barddhaman', 'Bardhaman', 'Darjiling', 'East Midnapore', 'Haora',
#        'Hooghly', 'Howrah', 'Koch Bihar', 'Maldah', 'Murshidabad',
#        'North Dinajpur', 'North Twenty Four Parganas',
#        'Paschim Bardhaman', 'Paschim Medinipur', 'Purba Medinipur',
#        'Purulia', 'Puruliya', 'South 24 Parganas', 'South Dinajpur',
#        'South Twenty Four Parganas', 'West Midnapore', 'Surguja',
#        'North East', 'Budgam', 'Doda', 'Kulgam', 'Kupwara', 'Pulwama',
#        'Kodarma', 'Kodagu', 'Lakshadweep', 'Dindori', 'Umaria',
#        'Ahilyanagar', 'Bid', 'Dharashiv', 'Jalna', 'Mumbai( Sub Urban )',
#        'Chandel', 'Debagarh', 'Jagatsinghpur', 'Yanam', 'Jagitial',
#        'Narayanpet', 'Sheikpura', 'Balod', 'Gariyaband', 'Kabeerdham',
#        'Kanker', 'Andamans', 'Nicobar', 'East Kameng', 'Kurung Kumey',
#        'Lower Dibang Valley', 'Namsai', 'Tawang', 'West Siang', 'Majuli',
#        'Aurangabad(Bh)', 'Bhabua', 'Barabanki', 'Jyotiba Phule Nagar',
#        'Sant Ravidas Nagar Bhadohi', 'Bageshwar', 'Rudraprayag', 'Daman',
#        'Diu', 'Panch Mahals', 'Surendranagar', 'Leh', 'Shupiyan',
#        'Pakaur', 'Imphal East', 'Jiribam', 'Aizawl', 'Kolasib', 'Muktsar',
#        'East Siang', 'Longding', 'Upper Siang', 'Upper Subansiri',
#        'Dantewada', 'Janjgir - Champa', 'Janjgir Champa',
#        'Mohla-Manpur-Ambagarh Chouki', 'Hugli', 'East', 'East Sikkim',
#        'North Sikkim', 'Raigarh(Mh)', 'Mokokchung', 'Wokha', 'Baudh',
#        'West', 'Khowai', 'Kinnaur', 'Badgam', 'Pashchimi Singhbhum',
#        'North And Middle Andaman', 'Kamle', 'Leparada', 'Shi-Yomi',
#        'Tirap', 'Niwari', 'Dibang Valley', 'Sribhumi',
#        'Gaurela-Pendra-Marwahi', 'Narayanpur', 'Khawzawl', 'Serchhip',
#        'Thoubal', 'Mahrajganj', 'Jangaon', 'Bulandshahar', 'Sahibganj',
#        'Maihar', 'K.V.Rangareddy', 'Pakke Kessang', 'Monghyr',
#        'Samstipur', 'Dadra Nagar Haveli', 'Eastern West Khasi Hills',
#        'Niuland', 'Dhaulpur', 'South East Delhi', 'Lahul Spiti',
#        'Mauganj', 'Lower Siang', 'Lahaul And Spiti', 'Bijapur(Kar)',
#        'Pandhurna', 'Khairagarh Chhuikhadan Gandai', 'Kakching',
#        'Lahul And Spiti', 'Medinipur', 'Bengaluru South', 'Jaintia Hills',
#        'Saitual', 'Mohali', 'East Midnapur', 'Bagpat', 'Garhwal',
#        'Najafgarh', 'Khairthal-Tijara', 'Hnahthial', 'Tirupathur',
#        'Tamulpur District', 'Sarangarh-Bilaigarh', 'Rajauri',
#        'Ahmednagar', 'Jalore', '24 Paraganas South', 'Nabarangpur',
#        'Ramanagara', 'East Singhbum', 'Ranga Reddy', 'Dinajpur Dakshin',
#        'Shopian', 'Kushi Nagar', 'Bajali', 'Meluri', 'Shamator',
#        'Warangal (Urban)', 'Namchi', 'Nicobars', 'Raebareli', 'Hawrah',
#        'Deeg', 'Tseminyu', 'Tiruvarur', 'Bardez', 'Hooghiy', 'Pherzawl',
#        'West Medinipur', 'Burdwan', 'Bandipur', 'Leh (Ladakh)',
#        'South 24 Pargana', 'Anugal', 'Mangan', 'Didwana-Kuchaman',
#        'Salumbar', 'Beawar', 'Balotra', 'Kotputli-Behror'], dtype=object)

# %%
df['district'] = df['district'].apply(normalize_text)

# %%
FINAL_DISTRICT_CLEAN_MAP = {

    # Telangana / Andhra Pradesh
    'mahabub nagar': 'Mahabubnagar',
    'mahbubnagar': 'Mahabubnagar',
    'ranga reddy': 'Rangareddy',
    'rangareddi': 'Rangareddy',
    'spsr nellore': 'Sri Potti Sriramulu Nellore',
    'ysr kadapa': 'Y.S.R. Kadapa',

    # Karnataka
    'bengaluru urban': 'Bengaluru',
    'bangalore urban': 'Bengaluru',

    # West Bengal
    'coochbehar': 'Cooch Behar',
    'dinajpur uttar': 'Uttar Dinajpur',
    'dinajpur dakshin': 'Dakshin Dinajpur',
    'purbi champaran': 'Purba Champaran',
    'medinipur west': 'Paschim Medinipur',
    'medinipur east': 'Purba Medinipur',

    # Maharashtra
    'ahmednagar': 'Ahilyanagar',
    'aurangabad(bh)': 'Aurangabad',

    # Gujarat
    'sabar kantha': 'Sabarkantha',
    'surendra nagar': 'Surendranagar',

    # Uttar Pradesh
    'shravasti': 'Shrawasti',
    'siddharth nagar': 'Siddharthnagar',

    # Assam / NE
    'north cachar hills': 'Dima Hasao',
    'karbi anglong west': 'West Karbi Anglong',

    # Odisha
    'sonapur': 'Subarnapur'
}

# %%
df['district'].nunique()
# Out:
# 934

# %%
df['district'].unique()
# Out:
# array(['east khasi hills', 'bengaluru urban', 'kanpur nagar', 'aligarh',
#        'sitamarhi', 'bahraich', 'firozabad', 'purbi champaran',
#        'maharajganj', 'aurangabad', 'ghaziabad', 'faridabad', 'madhubani',
#        'sikar', 'bhagalpur', 'amritsar', 'gurugram',
#        'gautam buddha nagar', 'west delhi', 'bhind', 'gwalior', 'katni',
#        'coochbehar', 'lucknow', 'dinajpur uttar', 'marigaon', 'kokrajhar',
#        'agra', 'haridwar', 'nagaon', 'parbhani', 'west khasi hills',
#        'north west delhi', 'west jaintia hills', 'unnao', 'saharanpur',
#        'dibrugarh', 'udalguri', 'chirang', 'kamrup', 'dhubri', 'jaunpur',
#        'thane', 'dhemaji', 'banas kantha', 'tinsukia', 'spsr nellore',
#        'barpeta', 'sonitpur', 'baksa', 'ludhiana', 'patan', 'kanchipuram',
#        'patna', 'lakhimpur', 'bongaigaon', 'vadodara', 'nainital',
#        'dehradun', 'hojai', 'dohad', 'morbi', 'raipur', 'gorakhpur',
#        'bulandshahr', 'mathura', 'pashchim champaran', 'bijapur',
#        'deoghar', 'muzaffarpur', 'banda', 'kachchh', 'ri bhoi', 'darrang',
#        'ashok nagar', 'darjeeling', 'north cachar hills', 'ranchi',
#        'surat', 'nanded', 'bengaluru', 'jorhat', 'gir somnath',
#        'kamrup metro', 'goalpara', 'bhavnagar', 'golaghat', 'nagpur',
#        'cooch behar', 'jalgaon', 'hingoli', 'ahmadnagar', 'gandhinagar',
#        'north 24 parganas', 'munger', 'kohima', 'jalor', 'kheda',
#        'nalbari', 'palghar', 'jodhpur', 'central delhi', 'gaya',
#        'sabarkantha', 'dimapur', 'cachar', 'banaskantha', 'kheri',
#        'rajkot', 'satara', 'betul', 'west karbi anglong', 'south delhi',
#        'raigad', 'uttar dinajpur', 'guna', 'kaimur (bhabua)', 'dholpur',
#        'churachandpur', 'west champaran', 'bharuch', 'jhargram',
#        'khargone', 'chhotaudepur', 'mumbai suburban', 'hailakandi',
#        'panchmahals', 'south salmara mankachar', 'budaun', 'kanpur dehat',
#        'porbandar', 'west garo hills', 'kapurthala', 'south garo hills',
#        'nagaur', 'mysuru', 'mahesana', 'churu', 'hyderabad',
#        'kancheepuram', 'varanasi', 'lohardaga', 'north garo hills',
#        'chhatarpur', 'nadia', 'purnia', 'gurgaon', 'charaideo', 'jaipur',
#        'saran', 'morena', 'dhar', 'dahod', 'devbhumi dwarka',
#        'east champaran', 'tapi', 'baghpat', 'fatehpur',
#        'south west khasi hills', 'yadgir', 'nandurbar', 'etawah',
#        'jalpaiguri', 'jabalpur', 'shamli', 'sibsagar', 'barwani', 'botad',
#        'junagadh', 'balrampur', 'bara banki', 'shivpuri', 'beed',
#        'shahjahanpur', 'jamnagar', 'chandrapur', 'durg',
#        'k.v. rangareddy', 'sirohi', 'alipurduar', 'south west delhi',
#        'gonda', 'east jaintia hills', 'bareilly', 'bundi', 'solapur',
#        'sitapur', 'dumka', 'sultanpur', 'karbi anglong', 'bikaner',
#        'phek', 'raisen', 'shrawasti', 'east delhi', 'jhabua', 'unakoti',
#        'indore', 'bhopal', 'dungarpur', 'chandauli', 'bharatpur',
#        'mainpuri', 'godda', 'muzaffarnagar', 'siddharthnagar', 'datia',
#        'west tripura', 'medchal-malkajgiri', 'sagar', 'sheopur',
#        'arvalli', 'surendra nagar', 'malda', 'amreli', 'alwar',
#        'ambedkar nagar', 'madurai', 'pilibhit', 'champhai', 'valsad',
#        'pakur', 'vaishali', 'vidisha', 'karimganj', 'biswanath',
#        'burhanpur', 'kaushambi', 'pune', 'punch', 'jehanabad', 'jalaun',
#        'etah', 'meerut', 'baran', 'sangrur', 'karauli', 'anand',
#        'longleng', 'chandigarh', 'jamui', 'south sikkim', 'panna',
#        'east garo hills', 'jhalawar', 'shahdara', 'kalaburagi',
#        'thanjavur', 'peren', 'tuensang', 'mahisagar', 'hoshiarpur',
#        'noklak', 'sukma', 'khandwa', 'ajmer', 'west sikkim', 'latur',
#        'basti', 'satna', 'gurdaspur', 'hazaribagh', 'azamgarh', 'udaipur',
#        'kolkata', 'rampur', 'the dangs', 'east singhbhum', 'alirajpur',
#        'sas nagar (mohali)', 'south west garo hills', 'moradabad', 'kota',
#        'dewas', 'navsari', 'chumukedima', 'ahmedabad', 'nabarangapur',
#        'pali', 'amroha', 'saiha', 'dakshin dinajpur', 'bijnor',
#        'pudukkottai', 'bangalore rural', 'kalimpong', 'deoria',
#        'baramula', 'gopalganj', 'prayagraj', 'lalitpur', 'mewat', 'hapur',
#        'jammu', 'bishnupur', 'saharsa', 'arwal', 'hathras', 'lawngtlai',
#        'nashik', 'yavatmal', 'cuddalore', 'kollam', 'patiala', 'katihar',
#        'malappuram', 'birbhum', 'siwan', 'dhule', 'baloda bazar',
#        'washim', 'coimbatore', 'lunglei', 'imphal west', 'kushinagar',
#        'thiruvananthapuram', 'sangli', 'lakhisarai', 'bengaluru rural',
#        '24 paraganas north', 'dima hasao', 'banka', 'salem',
#        'dadra and nagar haveli', 'dang', 'kaithal', 'vellore',
#        'shravasti', 'nalanda', 'jaisalmer', 'kallakurichi', 'farrukhabad',
#        'medinipur west', 'araria', 'sonipat', 'chatra',
#        'gaurella pendra marwahi', 'visakhapatanam', 'buldhana',
#        'amravati', 'hardoi', 'dhalai', 'ernakulam', 'new delhi',
#        'bhilwara', 'ramanathapuram', 'mon', 'raichur', 'north delhi',
#        'rohtak', 'gumla', 'barmer', 'kurukshetra', 'nuh', 'ashoknagar',
#        'thrissur', 's.a.s nagar', 'north east delhi', 'purba bardhaman',
#        'ambala', 'panipat', 'darbhanga', 'ayodhya', 'khunti', 'sivasagar',
#        'hisar', 'sivaganga', 'siddharth nagar', 'senapati', 'tamenglong',
#        'ukhrul', 'mamit', 'mammit', 'kiphire', 'zunheboto', 'angul',
#        'balangir', 'baleshwar', 'baleswar', 'bargarh', 'bhadrak', 'boudh',
#        'cuttack', 'dhenkanal', 'gajapati', 'ganjam', 'jajpur',
#        'jagatsinghapur', 'jajapur', 'jharsuguda', 'kalahandi',
#        'kandhamal', 'kendrapara', 'kendujhar', 'khorda', 'khordha',
#        'koraput', 'malkangiri', 'mayurbhanj', 'nuapada', 'nayagarh',
#        'puri', 'rayagada', 'sambalpur', 'sonapur', 'subarnapur',
#        'sundargarh', 'sundergarh', 'anugul', 'karaikal', 'pondicherry',
#        'puducherry', 'barnala', 'bathinda', 'faridkot', 'fatehgarh sahib',
#        'fazilka', 'ferozepur', 'firozpur', 'jalandhar', 'malerkotla',
#        'mansa', 'moga', 'nawanshahr', 'pathankot', 'rupnagar',
#        's.a.s nagar(mohali)', 'shaheed bhagat singh nagar',
#        'sri muktsar sahib', 'tarn taran', 'banswara', 'chittaurgarh',
#        'chittorgarh', 'dausa', 'ganganagar', 'hanumangarh', 'jhunjhunu',
#        'jhunjhunun', 'pratapgarh', 'rajsamand', 'sawai madhopur', 'tonk',
#        'north', 'south', 'ariyalur', 'chengalpattu', 'chennai',
#        'dharmapuri', 'dindigul', 'erode', 'kanniyakumari', 'kanyakumari',
#        'karur', 'krishnagiri', 'mayiladuthurai', 'nagapattinam',
#        'namakkal', 'perambalur', 'ranipet', 'tenkasi', 'the nilgiris',
#        'theni', 'thiruvallur', 'thiruvarur', 'thoothukkudi',
#        'tiruchirappalli', 'tirunelveli', 'tirupattur', 'tiruppur',
#        'tiruvallur', 'tiruvannamalai', 'villupuram', 'viluppuram',
#        'virudhunagar', 'adilabad', 'bhadradri kothagudem', 'hanumakonda',
#        'jangoan', 'jayashankar bhupalpally', 'jogulamba gadwal',
#        'kamareddy', 'karimnagar', 'khammam', 'komaram bheem',
#        'mahabubabad', 'mahabubnagar', 'mancherial', 'medak', 'mulugu',
#        'nagarkurnool', 'nalgonda', 'nirmal', 'nizamabad', 'chamrajnagar',
#        'chickmagalur', 'chikkaballapur', 'chikkamagaluru', 'chikmagalur',
#        'chitradurga', 'dakshina kannada', 'davanagere', 'davangere',
#        'dharwad', 'gadag', 'gulbarga', 'hasan', 'hassan', 'haveri',
#        'kolar', 'koppal', 'mandya', 'ramanagar', 'shivamogga', 'tumakuru',
#        'tumkur', 'udupi', 'uttara kannada', 'vijayanagara', 'vijayapura',
#        'alappuzha', 'idukki', 'kannur', 'kasaragod', 'kasargod',
#        'kottayam', 'kozhikode', 'palakkad', 'pathanamthitta', 'wayanad',
#        'kargil', 'agar malwa', 'anuppur', 'balaghat', 'chhindwara',
#        'damoh', 'east nimar', 'harda', 'narmadapuram', 'mandla',
#        'mandsaur', 'narsimhapur', 'narsinghpur', 'neemuch', 'rajgarh',
#        'ratlam', 'rewa', 'sehore', 'seoni', 'shahdol', 'shajapur',
#        'sidhi', 'singrauli', 'tikamgarh', 'ujjain', 'west nimar', 'akola',
#        'bhandara', 'buldana', 'chatrapati sambhaji nagar',
#        'chhatrapati sambhajinagar', 'gadchiroli', 'gondiya', 'kolhapur',
#        'mumbai', 'mumbai city', 'osmanabad', 'raigarh', 'ratnagiri',
#        'sindhudurg', 'wardha', 'buxar', 'khagaria', 'kishanganj',
#        'madhepura', 'nawada', 'purba champaran', 'purnea', 'rohtas',
#        'samastipur', 'sheikhpura', 'sheohar', 'supaul', 'bastar',
#        'bemetara', 'bilaspur', 'dakshin bastar dantewada', 'dhamtari',
#        'janjgir-champa', 'jashpur', 'kawardha', 'kondagaon', 'korba',
#        'koriya', 'mahasamund', 'manendragarh chirmiri bharatpur',
#        'mohalla-manpur-ambagarh chowki', 'mungeli', 'rajnandgaon',
#        'sakti', 'surajpur', 'uttar bastar kanker', 'north goa',
#        'south goa', 'narmada', 'sabar kantha', 'bhiwani', 'charkhi dadri',
#        'fatehabad', 'jhajjar', 'jind', 'karnal', 'mahendragarh', 'palwal',
#        'panchkula', 'rewari', 'sirsa', 'yamuna nagar', 'yamunanagar',
#        'chamba', 'hamirpur', 'kangra', 'kullu', 'mandi', 'shimla',
#        'sirmaur', 'solan', 'una', 'anantnag', 'bandipore', 'ganderbal',
#        'kathua', 'kishtwar', 'rajouri', 'ramban', 'reasi', 'samba',
#        'srinagar', 'udhampur', 'bokaro', 'dhanbad', 'garhwa', 'giridih',
#        'hazaribag', 'jamtara', 'koderma', 'latehar', 'palamau', 'palamu',
#        'purbi singhbhum', 'ramgarh', 'sahebganj', 'seraikela-kharsawan',
#        'simdega', 'west singhbhum', 'bagalkot', 'ballari', 'belagavi',
#        'bellary', 'bidar', 'chamarajanagar', 'chamrajanagar',
#        'south andaman', 'alluri sitharama raju', 'anakapalli',
#        'anantapur', 'ananthapur', 'ananthapuramu', 'annamayya', 'bapatla',
#        'chittoor', 'cuddapah', 'dr. b. r. ambedkar konaseema',
#        'east godavari', 'eluru', 'guntur', 'kakinada', 'karim nagar',
#        'krishna', 'kurnool', 'mahabub nagar', 'mahbubnagar', 'n. t. r',
#        'nandyal', 'nellore', 'palnadu', 'parvathipuram manyam',
#        'prakasam', 'rangareddi', 'sri potti sriramulu nellore',
#        'sri sathya sai', 'srikakulam', 'tirupati', 'visakhapatnam',
#        'vizianagaram', 'warangal', 'west godavari', 'y. s. r', 'anjaw',
#        'changlang', 'kra daadi', 'lohit', 'lower subansiri', 'papum pare',
#        'siang', 'west kameng', 'begusarai', 'bhojpur', 'peddapalli',
#        'rajanna sircilla', 'rangareddy', 'sangareddy', 'siddipet',
#        'suryapet', 'vikarabad', 'wanaparthy', 'warangal rural',
#        'warangal urban', 'yadadri.', 'gomati', 'north tripura',
#        'sepahijala', 'south tripura', 'amethi', 'auraiya', 'ballia',
#        'bhadohi', 'chitrakoot', 'faizabad', 'ghazipur', 'jhansi',
#        'kannauj', 'kasganj', 'mahoba', 'mau', 'mirzapur', 'rae bareli',
#        'sambhal', 'sant kabir nagar', 'sant ravidas nagar', 'sonbhadra',
#        'almora', 'chamoli', 'champawat', 'pauri garhwal', 'pithoragarh',
#        'tehri garhwal', 'udham singh nagar', 'uttarkashi', 'bankura',
#        'barddhaman', 'bardhaman', 'darjiling', 'east midnapore', 'haora',
#        'hooghly', 'howrah', 'koch bihar', 'maldah', 'murshidabad',
#        'north dinajpur', 'north twenty four parganas',
#        'paschim bardhaman', 'paschim medinipur', 'purba medinipur',
#        'purulia', 'puruliya', 'south 24 parganas', 'south dinajpur',
#        'south twenty four parganas', 'west midnapore', 'surguja',
#        'north east', 'budgam', 'doda', 'kulgam', 'kupwara', 'pulwama',
#        'kodarma', 'kodagu', 'lakshadweep', 'dindori', 'umaria',
#        'ahilyanagar', 'bid', 'dharashiv', 'jalna', 'mumbai( sub urban )',
#        'chandel', 'debagarh', 'jagatsinghpur', 'yanam', 'jagitial',
#        'narayanpet', 'sheikpura', 'balod', 'gariyaband', 'kabeerdham',
#        'kanker', 'andamans', 'nicobar', 'east kameng', 'kurung kumey',
#        'lower dibang valley', 'namsai', 'tawang', 'west siang', 'majuli',
#        'aurangabad(bh)', 'bhabua', 'barabanki', 'jyotiba phule nagar',
#        'sant ravidas nagar bhadohi', 'bageshwar', 'rudraprayag', 'daman',
#        'diu', 'panch mahals', 'surendranagar', 'leh', 'shupiyan',
#        'pakaur', 'imphal east', 'jiribam', 'aizawl', 'kolasib', 'muktsar',
#        'east siang', 'longding', 'upper siang', 'upper subansiri',
#        'dantewada', 'janjgir - champa', 'janjgir champa',
#        'mohla-manpur-ambagarh chouki', 'hugli', 'east', 'east sikkim',
#        'north sikkim', 'raigarh(mh)', 'mokokchung', 'wokha', 'baudh',
#        'west', 'khowai', 'kinnaur', 'badgam', 'pashchimi singhbhum',
#        'north and middle andaman', 'kamle', 'leparada', 'shi-yomi',
#        'tirap', 'niwari', 'dibang valley', 'sribhumi',
#        'gaurela-pendra-marwahi', 'narayanpur', 'khawzawl', 'serchhip',
#        'thoubal', 'mahrajganj', 'jangaon', 'bulandshahar', 'sahibganj',
#        'maihar', 'k.v.rangareddy', 'pakke kessang', 'monghyr',
#        'samstipur', 'dadra nagar haveli', 'eastern west khasi hills',
#        'niuland', 'dhaulpur', 'south east delhi', 'lahul spiti',
#        'mauganj', 'lower siang', 'lahaul and spiti', 'bijapur(kar)',
#        'pandhurna', 'khairagarh chhuikhadan gandai', 'kakching',
#        'lahul and spiti', 'medinipur', 'bengaluru south', 'jaintia hills',
#        'saitual', 'mohali', 'east midnapur', 'bagpat', 'garhwal',
#        'najafgarh', 'khairthal-tijara', 'hnahthial', 'tirupathur',
#        'tamulpur district', 'sarangarh-bilaigarh', 'rajauri',
#        'ahmednagar', 'jalore', '24 paraganas south', 'nabarangpur',
#        'ramanagara', 'east singhbum', 'ranga reddy', 'dinajpur dakshin',
#        'shopian', 'kushi nagar', 'bajali', 'meluri', 'shamator',
#        'warangal (urban)', 'namchi', 'nicobars', 'raebareli', 'hawrah',
#        'deeg', 'tseminyu', 'tiruvarur', 'bardez', 'hooghiy', 'pherzawl',
#        'west medinipur', 'burdwan', 'bandipur', 'leh (ladakh)',
#        'south 24 pargana', 'anugal', 'mangan', 'didwana-kuchaman',
#        'salumbar', 'beawar', 'balotra', 'kotputli-behror'], dtype=object)

# %%
DISTRICT_FINAL_MAP = {

    # -------------------------
    # BIHAR / UTTAR PRADESH
    # -------------------------
    'bara banki': 'Barabanki',
    'purnea': 'Purnia',
    'purba champaran': 'Purba Champaran',
    'pashchim champaran': 'Pashchim Champaran',
    'pashchim champaran': 'Pashchim Champaran',
    'kushi nagar': 'Kushinagar',
    'rae bareli': 'Rae Bareli',
    'raebareli': 'Rae Bareli',
    'siddharth nagar': 'Siddharthnagar',

    # -------------------------
    # WEST BENGAL (CRITICAL)
    # -------------------------
    'cooch behar': 'Cooch Behar',

    'north twenty four parganas': 'North 24 Parganas',
    '24 paraganas north': 'North 24 Parganas',
    'north 24 parganas': 'North 24 Parganas',

    'south twenty four parganas': 'South 24 Parganas',
    'south 24 pargana': 'South 24 Parganas',
    'south 24 parganas': 'South 24 Parganas',

    'east midnapore': 'Purba Medinipur',
    'east midnapur': 'Purba Medinipur',

    'west midnapore': 'Paschim Medinipur',
    'medinipur': 'Paschim Medinipur',

    'puruliya': 'Purulia',

    # -------------------------
    # TELANGANA / ANDHRA PRADESH
    # -------------------------
    'mahabub nagar': 'Mahabubnagar',
    'mahabubnagar': 'Mahabubnagar',

    'k.v. rangareddy': 'Rangareddy',
    'ranga reddy': 'Rangareddy',
    'rangareddi': 'Rangareddy',

    'n. t. r': 'N. T. R',
    'yadadri.': 'Yadadri Bhuvanagiri',

    'spsr nellore': 'Sri Potti Sriramulu Nellore',

    # -------------------------
    # KARNATAKA
    # -------------------------
    'bangalore rural': 'Bengaluru Rural',

    'chamrajnagar': 'Chamarajanagar',
    'chamrajanagar': 'Chamarajanagar',

    'chickmagalur': 'Chikkamagaluru',
    'chikmagalur': 'Chikkamagaluru',

    'davangere': 'Davanagere',

    # -------------------------
    # MAHARASHTRA
    # -------------------------
    'chatrapati sambhaji nagar': 'Chhatrapati Sambhajinagar',

    'osmanabad': 'Dharashiv',

    # -------------------------
    # PUNJAB
    # -------------------------
    'sas nagar (mohali)': 'S.A.S Nagar (Mohali)',
    's.a.s nagar': 'S.A.S Nagar (Mohali)',
    's.a.s nagar(mohali)': 'S.A.S Nagar (Mohali)',

    # -------------------------
    # NORTH EAST / HILL STATES
    # -------------------------
    'lahul and spiti': 'Lahaul And Spiti',

    # -------------------------
    # COMMON TYPO FIXES
    # -------------------------
    'visakhapatanam': 'Visakhapatnam',
    'kasargod': 'Kasaragod',
}

# %%
df['district'] = (
    df['district']
    .str.lower()
    .str.strip()
    .replace(DISTRICT_FINAL_MAP)
    .str.title()
)

# %%
INVALID_DISTRICTS = ['east', 'west', 'north', 'south', None]

df.loc[df['district'].isin(INVALID_DISTRICTS), 'district'] = None

# %%
df['district'].nunique()
# Out:
# 902

# %%
df['district'].unique()
# Out:
# array(['East Khasi Hills', 'Bengaluru Urban', 'Kanpur Nagar', 'Aligarh',
#        'Sitamarhi', 'Bahraich', 'Firozabad', 'Purbi Champaran',
#        'Maharajganj', 'Aurangabad', 'Ghaziabad', 'Faridabad', 'Madhubani',
#        'Sikar', 'Bhagalpur', 'Amritsar', 'Gurugram',
#        'Gautam Buddha Nagar', 'West Delhi', 'Bhind', 'Gwalior', 'Katni',
#        'Coochbehar', 'Lucknow', 'Dinajpur Uttar', 'Marigaon', 'Kokrajhar',
#        'Agra', 'Haridwar', 'Nagaon', 'Parbhani', 'West Khasi Hills',
#        'North West Delhi', 'West Jaintia Hills', 'Unnao', 'Saharanpur',
#        'Dibrugarh', 'Udalguri', 'Chirang', 'Kamrup', 'Dhubri', 'Jaunpur',
#        'Thane', 'Dhemaji', 'Banas Kantha', 'Tinsukia',
#        'Sri Potti Sriramulu Nellore', 'Barpeta', 'Sonitpur', 'Baksa',
#        'Ludhiana', 'Patan', 'Kanchipuram', 'Patna', 'Lakhimpur',
#        'Bongaigaon', 'Vadodara', 'Nainital', 'Dehradun', 'Hojai', 'Dohad',
#        'Morbi', 'Raipur', 'Gorakhpur', 'Bulandshahr', 'Mathura',
#        'Pashchim Champaran', 'Bijapur', 'Deoghar', 'Muzaffarpur', 'Banda',
#        'Kachchh', 'Ri Bhoi', 'Darrang', 'Ashok Nagar', 'Darjeeling',
#        'North Cachar Hills', 'Ranchi', 'Surat', 'Nanded', 'Bengaluru',
#        'Jorhat', 'Gir Somnath', 'Kamrup Metro', 'Goalpara', 'Bhavnagar',
#        'Golaghat', 'Nagpur', 'Cooch Behar', 'Jalgaon', 'Hingoli',
#        'Ahmadnagar', 'Gandhinagar', 'North 24 Parganas', 'Munger',
#        'Kohima', 'Jalor', 'Kheda', 'Nalbari', 'Palghar', 'Jodhpur',
#        'Central Delhi', 'Gaya', 'Sabarkantha', 'Dimapur', 'Cachar',
#        'Banaskantha', 'Kheri', 'Rajkot', 'Satara', 'Betul',
#        'West Karbi Anglong', 'South Delhi', 'Raigad', 'Uttar Dinajpur',
#        'Guna', 'Kaimur (Bhabua)', 'Dholpur', 'Churachandpur',
#        'West Champaran', 'Bharuch', 'Jhargram', 'Khargone',
#        'Chhotaudepur', 'Mumbai Suburban', 'Hailakandi', 'Panchmahals',
#        'South Salmara Mankachar', 'Budaun', 'Kanpur Dehat', 'Porbandar',
#        'West Garo Hills', 'Kapurthala', 'South Garo Hills', 'Nagaur',
#        'Mysuru', 'Mahesana', 'Churu', 'Hyderabad', 'Kancheepuram',
#        'Varanasi', 'Lohardaga', 'North Garo Hills', 'Chhatarpur', 'Nadia',
#        'Purnia', 'Gurgaon', 'Charaideo', 'Jaipur', 'Saran', 'Morena',
#        'Dhar', 'Dahod', 'Devbhumi Dwarka', 'East Champaran', 'Tapi',
#        'Baghpat', 'Fatehpur', 'South West Khasi Hills', 'Yadgir',
#        'Nandurbar', 'Etawah', 'Jalpaiguri', 'Jabalpur', 'Shamli',
#        'Sibsagar', 'Barwani', 'Botad', 'Junagadh', 'Balrampur',
#        'Barabanki', 'Shivpuri', 'Beed', 'Shahjahanpur', 'Jamnagar',
#        'Chandrapur', 'Durg', 'Rangareddy', 'Sirohi', 'Alipurduar',
#        'South West Delhi', 'Gonda', 'East Jaintia Hills', 'Bareilly',
#        'Bundi', 'Solapur', 'Sitapur', 'Dumka', 'Sultanpur',
#        'Karbi Anglong', 'Bikaner', 'Phek', 'Raisen', 'Shrawasti',
#        'East Delhi', 'Jhabua', 'Unakoti', 'Indore', 'Bhopal', 'Dungarpur',
#        'Chandauli', 'Bharatpur', 'Mainpuri', 'Godda', 'Muzaffarnagar',
#        'Siddharthnagar', 'Datia', 'West Tripura', 'Medchal-Malkajgiri',
#        'Sagar', 'Sheopur', 'Arvalli', 'Surendra Nagar', 'Malda', 'Amreli',
#        'Alwar', 'Ambedkar Nagar', 'Madurai', 'Pilibhit', 'Champhai',
#        'Valsad', 'Pakur', 'Vaishali', 'Vidisha', 'Karimganj', 'Biswanath',
#        'Burhanpur', 'Kaushambi', 'Pune', 'Punch', 'Jehanabad', 'Jalaun',
#        'Etah', 'Meerut', 'Baran', 'Sangrur', 'Karauli', 'Anand',
#        'Longleng', 'Chandigarh', 'Jamui', 'South Sikkim', 'Panna',
#        'East Garo Hills', 'Jhalawar', 'Shahdara', 'Kalaburagi',
#        'Thanjavur', 'Peren', 'Tuensang', 'Mahisagar', 'Hoshiarpur',
#        'Noklak', 'Sukma', 'Khandwa', 'Ajmer', 'West Sikkim', 'Latur',
#        'Basti', 'Satna', 'Gurdaspur', 'Hazaribagh', 'Azamgarh', 'Udaipur',
#        'Kolkata', 'Rampur', 'The Dangs', 'East Singhbhum', 'Alirajpur',
#        'S.A.S Nagar (Mohali)', 'South West Garo Hills', 'Moradabad',
#        'Kota', 'Dewas', 'Navsari', 'Chumukedima', 'Ahmedabad',
#        'Nabarangapur', 'Pali', 'Amroha', 'Saiha', 'Dakshin Dinajpur',
#        'Bijnor', 'Pudukkottai', 'Bengaluru Rural', 'Kalimpong', 'Deoria',
#        'Baramula', 'Gopalganj', 'Prayagraj', 'Lalitpur', 'Mewat', 'Hapur',
#        'Jammu', 'Bishnupur', 'Saharsa', 'Arwal', 'Hathras', 'Lawngtlai',
#        'Nashik', 'Yavatmal', 'Cuddalore', 'Kollam', 'Patiala', 'Katihar',
#        'Malappuram', 'Birbhum', 'Siwan', 'Dhule', 'Baloda Bazar',
#        'Washim', 'Coimbatore', 'Lunglei', 'Imphal West', 'Kushinagar',
#        'Thiruvananthapuram', 'Sangli', 'Lakhisarai', 'Dima Hasao',
#        'Banka', 'Salem', 'Dadra And Nagar Haveli', 'Dang', 'Kaithal',
#        'Vellore', 'Shravasti', 'Nalanda', 'Jaisalmer', 'Kallakurichi',
#        'Farrukhabad', 'Medinipur West', 'Araria', 'Sonipat', 'Chatra',
#        'Gaurella Pendra Marwahi', 'Visakhapatnam', 'Buldhana', 'Amravati',
#        'Hardoi', 'Dhalai', 'Ernakulam', 'New Delhi', 'Bhilwara',
#        'Ramanathapuram', 'Mon', 'Raichur', 'North Delhi', 'Rohtak',
#        'Gumla', 'Barmer', 'Kurukshetra', 'Nuh', 'Ashoknagar', 'Thrissur',
#        'North East Delhi', 'Purba Bardhaman', 'Ambala', 'Panipat',
#        'Darbhanga', 'Ayodhya', 'Khunti', 'Sivasagar', 'Hisar',
#        'Sivaganga', 'Senapati', 'Tamenglong', 'Ukhrul', 'Mamit', 'Mammit',
#        'Kiphire', 'Zunheboto', 'Angul', 'Balangir', 'Baleshwar',
#        'Baleswar', 'Bargarh', 'Bhadrak', 'Boudh', 'Cuttack', 'Dhenkanal',
#        'Gajapati', 'Ganjam', 'Jajpur', 'Jagatsinghapur', 'Jajapur',
#        'Jharsuguda', 'Kalahandi', 'Kandhamal', 'Kendrapara', 'Kendujhar',
#        'Khorda', 'Khordha', 'Koraput', 'Malkangiri', 'Mayurbhanj',
#        'Nuapada', 'Nayagarh', 'Puri', 'Rayagada', 'Sambalpur', 'Sonapur',
#        'Subarnapur', 'Sundargarh', 'Sundergarh', 'Anugul', 'Karaikal',
#        'Pondicherry', 'Puducherry', 'Barnala', 'Bathinda', 'Faridkot',
#        'Fatehgarh Sahib', 'Fazilka', 'Ferozepur', 'Firozpur', 'Jalandhar',
#        'Malerkotla', 'Mansa', 'Moga', 'Nawanshahr', 'Pathankot',
#        'Rupnagar', 'Shaheed Bhagat Singh Nagar', 'Sri Muktsar Sahib',
#        'Tarn Taran', 'Banswara', 'Chittaurgarh', 'Chittorgarh', 'Dausa',
#        'Ganganagar', 'Hanumangarh', 'Jhunjhunu', 'Jhunjhunun',
#        'Pratapgarh', 'Rajsamand', 'Sawai Madhopur', 'Tonk', 'North',
#        'South', 'Ariyalur', 'Chengalpattu', 'Chennai', 'Dharmapuri',
#        'Dindigul', 'Erode', 'Kanniyakumari', 'Kanyakumari', 'Karur',
#        'Krishnagiri', 'Mayiladuthurai', 'Nagapattinam', 'Namakkal',
#        'Perambalur', 'Ranipet', 'Tenkasi', 'The Nilgiris', 'Theni',
#        'Thiruvallur', 'Thiruvarur', 'Thoothukkudi', 'Tiruchirappalli',
#        'Tirunelveli', 'Tirupattur', 'Tiruppur', 'Tiruvallur',
#        'Tiruvannamalai', 'Villupuram', 'Viluppuram', 'Virudhunagar',
#        'Adilabad', 'Bhadradri Kothagudem', 'Hanumakonda', 'Jangoan',
#        'Jayashankar Bhupalpally', 'Jogulamba Gadwal', 'Kamareddy',
#        'Karimnagar', 'Khammam', 'Komaram Bheem', 'Mahabubabad',
#        'Mahabubnagar', 'Mancherial', 'Medak', 'Mulugu', 'Nagarkurnool',
#        'Nalgonda', 'Nirmal', 'Nizamabad', 'Chamarajanagar',
#        'Chikkamagaluru', 'Chikkaballapur', 'Chitradurga',
#        'Dakshina Kannada', 'Davanagere', 'Dharwad', 'Gadag', 'Gulbarga',
#        'Hasan', 'Hassan', 'Haveri', 'Kolar', 'Koppal', 'Mandya',
#        'Ramanagar', 'Shivamogga', 'Tumakuru', 'Tumkur', 'Udupi',
#        'Uttara Kannada', 'Vijayanagara', 'Vijayapura', 'Alappuzha',
#        'Idukki', 'Kannur', 'Kasaragod', 'Kottayam', 'Kozhikode',
#        'Palakkad', 'Pathanamthitta', 'Wayanad', 'Kargil', 'Agar Malwa',
#        'Anuppur', 'Balaghat', 'Chhindwara', 'Damoh', 'East Nimar',
#        'Harda', 'Narmadapuram', 'Mandla', 'Mandsaur', 'Narsimhapur',
#        'Narsinghpur', 'Neemuch', 'Rajgarh', 'Ratlam', 'Rewa', 'Sehore',
#        'Seoni', 'Shahdol', 'Shajapur', 'Sidhi', 'Singrauli', 'Tikamgarh',
#        'Ujjain', 'West Nimar', 'Akola', 'Bhandara', 'Buldana',
#        'Chhatrapati Sambhajinagar', 'Gadchiroli', 'Gondiya', 'Kolhapur',
#        'Mumbai', 'Mumbai City', 'Dharashiv', 'Raigarh', 'Ratnagiri',
#        'Sindhudurg', 'Wardha', 'Buxar', 'Khagaria', 'Kishanganj',
#        'Madhepura', 'Nawada', 'Purba Champaran', 'Rohtas', 'Samastipur',
#        'Sheikhpura', 'Sheohar', 'Supaul', 'Bastar', 'Bemetara',
#        'Bilaspur', 'Dakshin Bastar Dantewada', 'Dhamtari',
#        'Janjgir-Champa', 'Jashpur', 'Kawardha', 'Kondagaon', 'Korba',
#        'Koriya', 'Mahasamund', 'Manendragarh Chirmiri Bharatpur',
#        'Mohalla-Manpur-Ambagarh Chowki', 'Mungeli', 'Rajnandgaon',
#        'Sakti', 'Surajpur', 'Uttar Bastar Kanker', 'North Goa',
#        'South Goa', 'Narmada', 'Sabar Kantha', 'Bhiwani', 'Charkhi Dadri',
#        'Fatehabad', 'Jhajjar', 'Jind', 'Karnal', 'Mahendragarh', 'Palwal',
#        'Panchkula', 'Rewari', 'Sirsa', 'Yamuna Nagar', 'Yamunanagar',
#        'Chamba', 'Hamirpur', 'Kangra', 'Kullu', 'Mandi', 'Shimla',
#        'Sirmaur', 'Solan', 'Una', 'Anantnag', 'Bandipore', 'Ganderbal',
#        'Kathua', 'Kishtwar', 'Rajouri', 'Ramban', 'Reasi', 'Samba',
#        'Srinagar', 'Udhampur', 'Bokaro', 'Dhanbad', 'Garhwa', 'Giridih',
#        'Hazaribag', 'Jamtara', 'Koderma', 'Latehar', 'Palamau', 'Palamu',
#        'Purbi Singhbhum', 'Ramgarh', 'Sahebganj', 'Seraikela-Kharsawan',
#        'Simdega', 'West Singhbhum', 'Bagalkot', 'Ballari', 'Belagavi',
#        'Bellary', 'Bidar', 'South Andaman', 'Alluri Sitharama Raju',
#        'Anakapalli', 'Anantapur', 'Ananthapur', 'Ananthapuramu',
#        'Annamayya', 'Bapatla', 'Chittoor', 'Cuddapah',
#        'Dr. B. R. Ambedkar Konaseema', 'East Godavari', 'Eluru', 'Guntur',
#        'Kakinada', 'Karim Nagar', 'Krishna', 'Kurnool', 'Mahbubnagar',
#        'N. T. R', 'Nandyal', 'Nellore', 'Palnadu', 'Parvathipuram Manyam',
#        'Prakasam', 'Sri Sathya Sai', 'Srikakulam', 'Tirupati',
#        'Vizianagaram', 'Warangal', 'West Godavari', 'Y. S. R', 'Anjaw',
#        'Changlang', 'Kra Daadi', 'Lohit', 'Lower Subansiri', 'Papum Pare',
#        'Siang', 'West Kameng', 'Begusarai', 'Bhojpur', 'Peddapalli',
#        'Rajanna Sircilla', 'Sangareddy', 'Siddipet', 'Suryapet',
#        'Vikarabad', 'Wanaparthy', 'Warangal Rural', 'Warangal Urban',
#        'Yadadri Bhuvanagiri', 'Gomati', 'North Tripura', 'Sepahijala',
#        'South Tripura', 'Amethi', 'Auraiya', 'Ballia', 'Bhadohi',
#        'Chitrakoot', 'Faizabad', 'Ghazipur', 'Jhansi', 'Kannauj',
#        'Kasganj', 'Mahoba', 'Mau', 'Mirzapur', 'Rae Bareli', 'Sambhal',
#        'Sant Kabir Nagar', 'Sant Ravidas Nagar', 'Sonbhadra', 'Almora',
#        'Chamoli', 'Champawat', 'Pauri Garhwal', 'Pithoragarh',
#        'Tehri Garhwal', 'Udham Singh Nagar', 'Uttarkashi', 'Bankura',
#        'Barddhaman', 'Bardhaman', 'Darjiling', 'Purba Medinipur', 'Haora',
#        'Hooghly', 'Howrah', 'Koch Bihar', 'Maldah', 'Murshidabad',
#        'North Dinajpur', 'Paschim Bardhaman', 'Paschim Medinipur',
#        'Purulia', 'South 24 Parganas', 'South Dinajpur', 'Surguja',
#        'North East', 'Budgam', 'Doda', 'Kulgam', 'Kupwara', 'Pulwama',
#        'Kodarma', 'Kodagu', 'Lakshadweep', 'Dindori', 'Umaria',
#        'Ahilyanagar', 'Bid', 'Jalna', 'Mumbai( Sub Urban )', 'Chandel',
#        'Debagarh', 'Jagatsinghpur', 'Yanam', 'Jagitial', 'Narayanpet',
#        'Sheikpura', 'Balod', 'Gariyaband', 'Kabeerdham', 'Kanker',
#        'Andamans', 'Nicobar', 'East Kameng', 'Kurung Kumey',
#        'Lower Dibang Valley', 'Namsai', 'Tawang', 'West Siang', 'Majuli',
#        'Aurangabad(Bh)', 'Bhabua', 'Jyotiba Phule Nagar',
#        'Sant Ravidas Nagar Bhadohi', 'Bageshwar', 'Rudraprayag', 'Daman',
#        'Diu', 'Panch Mahals', 'Surendranagar', 'Leh', 'Shupiyan',
#        'Pakaur', 'Imphal East', 'Jiribam', 'Aizawl', 'Kolasib', 'Muktsar',
#        'East Siang', 'Longding', 'Upper Siang', 'Upper Subansiri',
#        'Dantewada', 'Janjgir - Champa', 'Janjgir Champa',
#        'Mohla-Manpur-Ambagarh Chouki', 'Hugli', 'East', 'East Sikkim',
#        'North Sikkim', 'Raigarh(Mh)', 'Mokokchung', 'Wokha', 'Baudh',
#        'West', 'Khowai', 'Kinnaur', 'Badgam', 'Pashchimi Singhbhum',
#        'North And Middle Andaman', 'Kamle', 'Leparada', 'Shi-Yomi',
#        'Tirap', 'Niwari', 'Dibang Valley', 'Sribhumi',
#        'Gaurela-Pendra-Marwahi', 'Narayanpur', 'Khawzawl', 'Serchhip',
#        'Thoubal', 'Mahrajganj', 'Jangaon', 'Bulandshahar', 'Sahibganj',
#        'Maihar', 'K.V.Rangareddy', 'Pakke Kessang', 'Monghyr',
#        'Samstipur', 'Dadra Nagar Haveli', 'Eastern West Khasi Hills',
#        'Niuland', 'Dhaulpur', 'South East Delhi', 'Lahul Spiti',
#        'Mauganj', 'Lower Siang', 'Lahaul And Spiti', 'Bijapur(Kar)',
#        'Pandhurna', 'Khairagarh Chhuikhadan Gandai', 'Kakching',
#        'Bengaluru South', 'Jaintia Hills', 'Saitual', 'Mohali', 'Bagpat',
#        'Garhwal', 'Najafgarh', 'Khairthal-Tijara', 'Hnahthial',
#        'Tirupathur', 'Tamulpur District', 'Sarangarh-Bilaigarh',
#        'Rajauri', 'Ahmednagar', 'Jalore', '24 Paraganas South',
#        'Nabarangpur', 'Ramanagara', 'East Singhbum', 'Dinajpur Dakshin',
#        'Shopian', 'Bajali', 'Meluri', 'Shamator', 'Warangal (Urban)',
#        'Namchi', 'Nicobars', 'Hawrah', 'Deeg', 'Tseminyu', 'Tiruvarur',
#        'Bardez', 'Hooghiy', 'Pherzawl', 'West Medinipur', 'Burdwan',
#        'Bandipur', 'Leh (Ladakh)', 'Anugal', 'Mangan', 'Didwana-Kuchaman',
#        'Salumbar', 'Beawar', 'Balotra', 'Kotputli-Behror'], dtype=object)

# %%
df.groupby('district')['state'].nunique().sort_values(ascending=False)
# Out:
# district
# Mahabubnagar    2
# Kargil          2
# Aurangabad      2
# Pratapgarh      2
# Warangal        2
#                ..
# Hassan          1
# Hathras         1
# Haveri          1
# Hawrah          1
# Zunheboto       1
# Name: state, Length: 902, dtype: int64

# %%
df['district'].isna().sum()
# Out:
# 0

# %% [markdown]
# ## Pincode–District reference

# %%
pincode_district_map = (
    df[df['district'].notna()]
    .groupby('pincode')['district']
    .agg(lambda x: x.value_counts().idxmax())
)

# %%
df['district'] = df['district'].fillna(df['pincode'].map(pincode_district_map))

# %%
df['district'].isna().sum()
# Out:
# 0

# %%
df['district'].nunique()
# Out:
# 902

# %%
df['district'].unique()
# Out:
# array(['East Khasi Hills', 'Bengaluru Urban', 'Kanpur Nagar', 'Aligarh',
#        'Sitamarhi', 'Bahraich', 'Firozabad', 'Purbi Champaran',
#        'Maharajganj', 'Aurangabad', 'Ghaziabad', 'Faridabad', 'Madhubani',
#        'Sikar', 'Bhagalpur', 'Amritsar', 'Gurugram',
#        'Gautam Buddha Nagar', 'West Delhi', 'Bhind', 'Gwalior', 'Katni',
#        'Coochbehar', 'Lucknow', 'Dinajpur Uttar', 'Marigaon', 'Kokrajhar',
#        'Agra', 'Haridwar', 'Nagaon', 'Parbhani', 'West Khasi Hills',
#        'North West Delhi', 'West Jaintia Hills', 'Unnao', 'Saharanpur',
#        'Dibrugarh', 'Udalguri', 'Chirang', 'Kamrup', 'Dhubri', 'Jaunpur',
#        'Thane', 'Dhemaji', 'Banas Kantha', 'Tinsukia',
#        'Sri Potti Sriramulu Nellore', 'Barpeta', 'Sonitpur', 'Baksa',
#        'Ludhiana', 'Patan', 'Kanchipuram', 'Patna', 'Lakhimpur',
#        'Bongaigaon', 'Vadodara', 'Nainital', 'Dehradun', 'Hojai', 'Dohad',
#        'Morbi', 'Raipur', 'Gorakhpur', 'Bulandshahr', 'Mathura',
#        'Pashchim Champaran', 'Bijapur', 'Deoghar', 'Muzaffarpur', 'Banda',
#        'Kachchh', 'Ri Bhoi', 'Darrang', 'Ashok Nagar', 'Darjeeling',
#        'North Cachar Hills', 'Ranchi', 'Surat', 'Nanded', 'Bengaluru',
#        'Jorhat', 'Gir Somnath', 'Kamrup Metro', 'Goalpara', 'Bhavnagar',
#        'Golaghat', 'Nagpur', 'Cooch Behar', 'Jalgaon', 'Hingoli',
#        'Ahmadnagar', 'Gandhinagar', 'North 24 Parganas', 'Munger',
#        'Kohima', 'Jalor', 'Kheda', 'Nalbari', 'Palghar', 'Jodhpur',
#        'Central Delhi', 'Gaya', 'Sabarkantha', 'Dimapur', 'Cachar',
#        'Banaskantha', 'Kheri', 'Rajkot', 'Satara', 'Betul',
#        'West Karbi Anglong', 'South Delhi', 'Raigad', 'Uttar Dinajpur',
#        'Guna', 'Kaimur (Bhabua)', 'Dholpur', 'Churachandpur',
#        'West Champaran', 'Bharuch', 'Jhargram', 'Khargone',
#        'Chhotaudepur', 'Mumbai Suburban', 'Hailakandi', 'Panchmahals',
#        'South Salmara Mankachar', 'Budaun', 'Kanpur Dehat', 'Porbandar',
#        'West Garo Hills', 'Kapurthala', 'South Garo Hills', 'Nagaur',
#        'Mysuru', 'Mahesana', 'Churu', 'Hyderabad', 'Kancheepuram',
#        'Varanasi', 'Lohardaga', 'North Garo Hills', 'Chhatarpur', 'Nadia',
#        'Purnia', 'Gurgaon', 'Charaideo', 'Jaipur', 'Saran', 'Morena',
#        'Dhar', 'Dahod', 'Devbhumi Dwarka', 'East Champaran', 'Tapi',
#        'Baghpat', 'Fatehpur', 'South West Khasi Hills', 'Yadgir',
#        'Nandurbar', 'Etawah', 'Jalpaiguri', 'Jabalpur', 'Shamli',
#        'Sibsagar', 'Barwani', 'Botad', 'Junagadh', 'Balrampur',
#        'Barabanki', 'Shivpuri', 'Beed', 'Shahjahanpur', 'Jamnagar',
#        'Chandrapur', 'Durg', 'Rangareddy', 'Sirohi', 'Alipurduar',
#        'South West Delhi', 'Gonda', 'East Jaintia Hills', 'Bareilly',
#        'Bundi', 'Solapur', 'Sitapur', 'Dumka', 'Sultanpur',
#        'Karbi Anglong', 'Bikaner', 'Phek', 'Raisen', 'Shrawasti',
#        'East Delhi', 'Jhabua', 'Unakoti', 'Indore', 'Bhopal', 'Dungarpur',
#        'Chandauli', 'Bharatpur', 'Mainpuri', 'Godda', 'Muzaffarnagar',
#        'Siddharthnagar', 'Datia', 'West Tripura', 'Medchal-Malkajgiri',
#        'Sagar', 'Sheopur', 'Arvalli', 'Surendra Nagar', 'Malda', 'Amreli',
#        'Alwar', 'Ambedkar Nagar', 'Madurai', 'Pilibhit', 'Champhai',
#        'Valsad', 'Pakur', 'Vaishali', 'Vidisha', 'Karimganj', 'Biswanath',
#        'Burhanpur', 'Kaushambi', 'Pune', 'Punch', 'Jehanabad', 'Jalaun',
#        'Etah', 'Meerut', 'Baran', 'Sangrur', 'Karauli', 'Anand',
#        'Longleng', 'Chandigarh', 'Jamui', 'South Sikkim', 'Panna',
#        'East Garo Hills', 'Jhalawar', 'Shahdara', 'Kalaburagi',
#        'Thanjavur', 'Peren', 'Tuensang', 'Mahisagar', 'Hoshiarpur',
#        'Noklak', 'Sukma', 'Khandwa', 'Ajmer', 'West Sikkim', 'Latur',
#        'Basti', 'Satna', 'Gurdaspur', 'Hazaribagh', 'Azamgarh', 'Udaipur',
#        'Kolkata', 'Rampur', 'The Dangs', 'East Singhbhum', 'Alirajpur',
#        'S.A.S Nagar (Mohali)', 'South West Garo Hills', 'Moradabad',
#        'Kota', 'Dewas', 'Navsari', 'Chumukedima', 'Ahmedabad',
#        'Nabarangapur', 'Pali', 'Amroha', 'Saiha', 'Dakshin Dinajpur',
#        'Bijnor', 'Pudukkottai', 'Bengaluru Rural', 'Kalimpong', 'Deoria',
#        'Baramula', 'Gopalganj', 'Prayagraj', 'Lalitpur', 'Mewat', 'Hapur',
#        'Jammu', 'Bishnupur', 'Saharsa', 'Arwal', 'Hathras', 'Lawngtlai',
#        'Nashik', 'Yavatmal', 'Cuddalore', 'Kollam', 'Patiala', 'Katihar',
#        'Malappuram', 'Birbhum', 'Siwan', 'Dhule', 'Baloda Bazar',
#        'Washim', 'Coimbatore', 'Lunglei', 'Imphal West', 'Kushinagar',
#        'Thiruvananthapuram', 'Sangli', 'Lakhisarai', 'Dima Hasao',
#        'Banka', 'Salem', 'Dadra And Nagar Haveli', 'Dang', 'Kaithal',
#        'Vellore', 'Shravasti', 'Nalanda', 'Jaisalmer', 'Kallakurichi',
#        'Farrukhabad', 'Medinipur West', 'Araria', 'Sonipat', 'Chatra',
#        'Gaurella Pendra Marwahi', 'Visakhapatnam', 'Buldhana', 'Amravati',
#        'Hardoi', 'Dhalai', 'Ernakulam', 'New Delhi', 'Bhilwara',
#        'Ramanathapuram', 'Mon', 'Raichur', 'North Delhi', 'Rohtak',
#        'Gumla', 'Barmer', 'Kurukshetra', 'Nuh', 'Ashoknagar', 'Thrissur',
#        'North East Delhi', 'Purba Bardhaman', 'Ambala', 'Panipat',
#        'Darbhanga', 'Ayodhya', 'Khunti', 'Sivasagar', 'Hisar',
#        'Sivaganga', 'Senapati', 'Tamenglong', 'Ukhrul', 'Mamit', 'Mammit',
#        'Kiphire', 'Zunheboto', 'Angul', 'Balangir', 'Baleshwar',
#        'Baleswar', 'Bargarh', 'Bhadrak', 'Boudh', 'Cuttack', 'Dhenkanal',
#        'Gajapati', 'Ganjam', 'Jajpur', 'Jagatsinghapur', 'Jajapur',
#        'Jharsuguda', 'Kalahandi', 'Kandhamal', 'Kendrapara', 'Kendujhar',
#        'Khorda', 'Khordha', 'Koraput', 'Malkangiri', 'Mayurbhanj',
#        'Nuapada', 'Nayagarh', 'Puri', 'Rayagada', 'Sambalpur', 'Sonapur',
#        'Subarnapur', 'Sundargarh', 'Sundergarh', 'Anugul', 'Karaikal',
#        'Pondicherry', 'Puducherry', 'Barnala', 'Bathinda', 'Faridkot',
#        'Fatehgarh Sahib', 'Fazilka', 'Ferozepur', 'Firozpur', 'Jalandhar',
#        'Malerkotla', 'Mansa', 'Moga', 'Nawanshahr', 'Pathankot',
#        'Rupnagar', 'Shaheed Bhagat Singh Nagar', 'Sri Muktsar Sahib',
#        'Tarn Taran', 'Banswara', 'Chittaurgarh', 'Chittorgarh', 'Dausa',
#        'Ganganagar', 'Hanumangarh', 'Jhunjhunu', 'Jhunjhunun',
#        'Pratapgarh', 'Rajsamand', 'Sawai Madhopur', 'Tonk', 'North',
#        'South', 'Ariyalur', 'Chengalpattu', 'Chennai', 'Dharmapuri',
#        'Dindigul', 'Erode', 'Kanniyakumari', 'Kanyakumari', 'Karur',
#        'Krishnagiri', 'Mayiladuthurai', 'Nagapattinam', 'Namakkal',
#        'Perambalur', 'Ranipet', 'Tenkasi', 'The Nilgiris', 'Theni',
#        'Thiruvallur', 'Thiruvarur', 'Thoothukkudi', 'Tiruchirappalli',
#        'Tirunelveli', 'Tirupattur', 'Tiruppur', 'Tiruvallur',
#        'Tiruvannamalai', 'Villupuram', 'Viluppuram', 'Virudhunagar',
#        'Adilabad', 'Bhadradri Kothagudem', 'Hanumakonda', 'Jangoan',
#        'Jayashankar Bhupalpally', 'Jogulamba Gadwal', 'Kamareddy',
#        'Karimnagar', 'Khammam', 'Komaram Bheem', 'Mahabubabad',
#        'Mahabubnagar', 'Mancherial', 'Medak', 'Mulugu', 'Nagarkurnool',
#        'Nalgonda', 'Nirmal', 'Nizamabad', 'Chamarajanagar',
#        'Chikkamagaluru', 'Chikkaballapur', 'Chitradurga',
#        'Dakshina Kannada', 'Davanagere', 'Dharwad', 'Gadag', 'Gulbarga',
#        'Hasan', 'Hassan', 'Haveri', 'Kolar', 'Koppal', 'Mandya',
#        'Ramanagar', 'Shivamogga', 'Tumakuru', 'Tumkur', 'Udupi',
#        'Uttara Kannada', 'Vijayanagara', 'Vijayapura', 'Alappuzha',
#        'Idukki', 'Kannur', 'Kasaragod', 'Kottayam', 'Kozhikode',
#        'Palakkad', 'Pathanamthitta', 'Wayanad', 'Kargil', 'Agar Malwa',
#        'Anuppur', 'Balaghat', 'Chhindwara', 'Damoh', 'East Nimar',
#        'Harda', 'Narmadapuram', 'Mandla', 'Mandsaur', 'Narsimhapur',
#        'Narsinghpur', 'Neemuch', 'Rajgarh', 'Ratlam', 'Rewa', 'Sehore',
#        'Seoni', 'Shahdol', 'Shajapur', 'Sidhi', 'Singrauli', 'Tikamgarh',
#        'Ujjain', 'West Nimar', 'Akola', 'Bhandara', 'Buldana',
#        'Chhatrapati Sambhajinagar', 'Gadchiroli', 'Gondiya', 'Kolhapur',
#        'Mumbai', 'Mumbai City', 'Dharashiv', 'Raigarh', 'Ratnagiri',
#        'Sindhudurg', 'Wardha', 'Buxar', 'Khagaria', 'Kishanganj',
#        'Madhepura', 'Nawada', 'Purba Champaran', 'Rohtas', 'Samastipur',
#        'Sheikhpura', 'Sheohar', 'Supaul', 'Bastar', 'Bemetara',
#        'Bilaspur', 'Dakshin Bastar Dantewada', 'Dhamtari',
#        'Janjgir-Champa', 'Jashpur', 'Kawardha', 'Kondagaon', 'Korba',
#        'Koriya', 'Mahasamund', 'Manendragarh Chirmiri Bharatpur',
#        'Mohalla-Manpur-Ambagarh Chowki', 'Mungeli', 'Rajnandgaon',
#        'Sakti', 'Surajpur', 'Uttar Bastar Kanker', 'North Goa',
#        'South Goa', 'Narmada', 'Sabar Kantha', 'Bhiwani', 'Charkhi Dadri',
#        'Fatehabad', 'Jhajjar', 'Jind', 'Karnal', 'Mahendragarh', 'Palwal',
#        'Panchkula', 'Rewari', 'Sirsa', 'Yamuna Nagar', 'Yamunanagar',
#        'Chamba', 'Hamirpur', 'Kangra', 'Kullu', 'Mandi', 'Shimla',
#        'Sirmaur', 'Solan', 'Una', 'Anantnag', 'Bandipore', 'Ganderbal',
#        'Kathua', 'Kishtwar', 'Rajouri', 'Ramban', 'Reasi', 'Samba',
#        'Srinagar', 'Udhampur', 'Bokaro', 'Dhanbad', 'Garhwa', 'Giridih',
#        'Hazaribag', 'Jamtara', 'Koderma', 'Latehar', 'Palamau', 'Palamu',
#        'Purbi Singhbhum', 'Ramgarh', 'Sahebganj', 'Seraikela-Kharsawan',
#        'Simdega', 'West Singhbhum', 'Bagalkot', 'Ballari', 'Belagavi',
#        'Bellary', 'Bidar', 'South Andaman', 'Alluri Sitharama Raju',
#        'Anakapalli', 'Anantapur', 'Ananthapur', 'Ananthapuramu',
#        'Annamayya', 'Bapatla', 'Chittoor', 'Cuddapah',
#        'Dr. B. R. Ambedkar Konaseema', 'East Godavari', 'Eluru', 'Guntur',
#        'Kakinada', 'Karim Nagar', 'Krishna', 'Kurnool', 'Mahbubnagar',
#        'N. T. R', 'Nandyal', 'Nellore', 'Palnadu', 'Parvathipuram Manyam',
#        'Prakasam', 'Sri Sathya Sai', 'Srikakulam', 'Tirupati',
#        'Vizianagaram', 'Warangal', 'West Godavari', 'Y. S. R', 'Anjaw',
#        'Changlang', 'Kra Daadi', 'Lohit', 'Lower Subansiri', 'Papum Pare',
#        'Siang', 'West Kameng', 'Begusarai', 'Bhojpur', 'Peddapalli',
#        'Rajanna Sircilla', 'Sangareddy', 'Siddipet', 'Suryapet',
#        'Vikarabad', 'Wanaparthy', 'Warangal Rural', 'Warangal Urban',
#        'Yadadri Bhuvanagiri', 'Gomati', 'North Tripura', 'Sepahijala',
#        'South Tripura', 'Amethi', 'Auraiya', 'Ballia', 'Bhadohi',
#        'Chitrakoot', 'Faizabad', 'Ghazipur', 'Jhansi', 'Kannauj',
#        'Kasganj', 'Mahoba', 'Mau', 'Mirzapur', 'Rae Bareli', 'Sambhal',
#        'Sant Kabir Nagar', 'Sant Ravidas Nagar', 'Sonbhadra', 'Almora',
#        'Chamoli', 'Champawat', 'Pauri Garhwal', 'Pithoragarh',
#        'Tehri Garhwal', 'Udham Singh Nagar', 'Uttarkashi', 'Bankura',
#        'Barddhaman', 'Bardhaman', 'Darjiling', 'Purba Medinipur', 'Haora',
#        'Hooghly', 'Howrah', 'Koch Bihar', 'Maldah', 'Murshidabad',
#        'North Dinajpur', 'Paschim Bardhaman', 'Paschim Medinipur',
#        'Purulia', 'South 24 Parganas', 'South Dinajpur', 'Surguja',
#        'North East', 'Budgam', 'Doda', 'Kulgam', 'Kupwara', 'Pulwama',
#        'Kodarma', 'Kodagu', 'Lakshadweep', 'Dindori', 'Umaria',
#        'Ahilyanagar', 'Bid', 'Jalna', 'Mumbai( Sub Urban )', 'Chandel',
#        'Debagarh', 'Jagatsinghpur', 'Yanam', 'Jagitial', 'Narayanpet',
#        'Sheikpura', 'Balod', 'Gariyaband', 'Kabeerdham', 'Kanker',
#        'Andamans', 'Nicobar', 'East Kameng', 'Kurung Kumey',
#        'Lower Dibang Valley', 'Namsai', 'Tawang', 'West Siang', 'Majuli',
#        'Aurangabad(Bh)', 'Bhabua', 'Jyotiba Phule Nagar',
#        'Sant Ravidas Nagar Bhadohi', 'Bageshwar', 'Rudraprayag', 'Daman',
#        'Diu', 'Panch Mahals', 'Surendranagar', 'Leh', 'Shupiyan',
#        'Pakaur', 'Imphal East', 'Jiribam', 'Aizawl', 'Kolasib', 'Muktsar',
#        'East Siang', 'Longding', 'Upper Siang', 'Upper Subansiri',
#        'Dantewada', 'Janjgir - Champa', 'Janjgir Champa',
#        'Mohla-Manpur-Ambagarh Chouki', 'Hugli', 'East', 'East Sikkim',
#        'North Sikkim', 'Raigarh(Mh)', 'Mokokchung', 'Wokha', 'Baudh',
#        'West', 'Khowai', 'Kinnaur', 'Badgam', 'Pashchimi Singhbhum',
#        'North And Middle Andaman', 'Kamle', 'Leparada', 'Shi-Yomi',
#        'Tirap', 'Niwari', 'Dibang Valley', 'Sribhumi',
#        'Gaurela-Pendra-Marwahi', 'Narayanpur', 'Khawzawl', 'Serchhip',
#        'Thoubal', 'Mahrajganj', 'Jangaon', 'Bulandshahar', 'Sahibganj',
#        'Maihar', 'K.V.Rangareddy', 'Pakke Kessang', 'Monghyr',
#        'Samstipur', 'Dadra Nagar Haveli', 'Eastern West Khasi Hills',
#        'Niuland', 'Dhaulpur', 'South East Delhi', 'Lahul Spiti',
#        'Mauganj', 'Lower Siang', 'Lahaul And Spiti', 'Bijapur(Kar)',
#        'Pandhurna', 'Khairagarh Chhuikhadan Gandai', 'Kakching',
#        'Bengaluru South', 'Jaintia Hills', 'Saitual', 'Mohali', 'Bagpat',
#        'Garhwal', 'Najafgarh', 'Khairthal-Tijara', 'Hnahthial',
#        'Tirupathur', 'Tamulpur District', 'Sarangarh-Bilaigarh',
#        'Rajauri', 'Ahmednagar', 'Jalore', '24 Paraganas South',
#        'Nabarangpur', 'Ramanagara', 'East Singhbum', 'Dinajpur Dakshin',
#        'Shopian', 'Bajali', 'Meluri', 'Shamator', 'Warangal (Urban)',
#        'Namchi', 'Nicobars', 'Hawrah', 'Deeg', 'Tseminyu', 'Tiruvarur',
#        'Bardez', 'Hooghiy', 'Pherzawl', 'West Medinipur', 'Burdwan',
#        'Bandipur', 'Leh (Ladakh)', 'Anugal', 'Mangan', 'Didwana-Kuchaman',
#        'Salumbar', 'Beawar', 'Balotra', 'Kotputli-Behror'], dtype=object)

# %% [markdown]
# Missing district values were intelligently recovered using pincode-level majority mapping, ensuring maximum data retention and geographic accuracy instead of naive row deletion.”

# %%
df[df['district'].isna()][['pincode']].value_counts().head(10)
# Out:
# Series([], Name: count, dtype: int64)

# %%
df['district'].nunique()
# Out:
# 902

# %%
df['district'].unique()
# Out:
# array(['East Khasi Hills', 'Bengaluru Urban', 'Kanpur Nagar', 'Aligarh',
#        'Sitamarhi', 'Bahraich', 'Firozabad', 'Purbi Champaran',
#        'Maharajganj', 'Aurangabad', 'Ghaziabad', 'Faridabad', 'Madhubani',
#        'Sikar', 'Bhagalpur', 'Amritsar', 'Gurugram',
#        'Gautam Buddha Nagar', 'West Delhi', 'Bhind', 'Gwalior', 'Katni',
#        'Coochbehar', 'Lucknow', 'Dinajpur Uttar', 'Marigaon', 'Kokrajhar',
#        'Agra', 'Haridwar', 'Nagaon', 'Parbhani', 'West Khasi Hills',
#        'North West Delhi', 'West Jaintia Hills', 'Unnao', 'Saharanpur',
#        'Dibrugarh', 'Udalguri', 'Chirang', 'Kamrup', 'Dhubri', 'Jaunpur',
#        'Thane', 'Dhemaji', 'Banas Kantha', 'Tinsukia',
#        'Sri Potti Sriramulu Nellore', 'Barpeta', 'Sonitpur', 'Baksa',
#        'Ludhiana', 'Patan', 'Kanchipuram', 'Patna', 'Lakhimpur',
#        'Bongaigaon', 'Vadodara', 'Nainital', 'Dehradun', 'Hojai', 'Dohad',
#        'Morbi', 'Raipur', 'Gorakhpur', 'Bulandshahr', 'Mathura',
#        'Pashchim Champaran', 'Bijapur', 'Deoghar', 'Muzaffarpur', 'Banda',
#        'Kachchh', 'Ri Bhoi', 'Darrang', 'Ashok Nagar', 'Darjeeling',
#        'North Cachar Hills', 'Ranchi', 'Surat', 'Nanded', 'Bengaluru',
#        'Jorhat', 'Gir Somnath', 'Kamrup Metro', 'Goalpara', 'Bhavnagar',
#        'Golaghat', 'Nagpur', 'Cooch Behar', 'Jalgaon', 'Hingoli',
#        'Ahmadnagar', 'Gandhinagar', 'North 24 Parganas', 'Munger',
#        'Kohima', 'Jalor', 'Kheda', 'Nalbari', 'Palghar', 'Jodhpur',
#        'Central Delhi', 'Gaya', 'Sabarkantha', 'Dimapur', 'Cachar',
#        'Banaskantha', 'Kheri', 'Rajkot', 'Satara', 'Betul',
#        'West Karbi Anglong', 'South Delhi', 'Raigad', 'Uttar Dinajpur',
#        'Guna', 'Kaimur (Bhabua)', 'Dholpur', 'Churachandpur',
#        'West Champaran', 'Bharuch', 'Jhargram', 'Khargone',
#        'Chhotaudepur', 'Mumbai Suburban', 'Hailakandi', 'Panchmahals',
#        'South Salmara Mankachar', 'Budaun', 'Kanpur Dehat', 'Porbandar',
#        'West Garo Hills', 'Kapurthala', 'South Garo Hills', 'Nagaur',
#        'Mysuru', 'Mahesana', 'Churu', 'Hyderabad', 'Kancheepuram',
#        'Varanasi', 'Lohardaga', 'North Garo Hills', 'Chhatarpur', 'Nadia',
#        'Purnia', 'Gurgaon', 'Charaideo', 'Jaipur', 'Saran', 'Morena',
#        'Dhar', 'Dahod', 'Devbhumi Dwarka', 'East Champaran', 'Tapi',
#        'Baghpat', 'Fatehpur', 'South West Khasi Hills', 'Yadgir',
#        'Nandurbar', 'Etawah', 'Jalpaiguri', 'Jabalpur', 'Shamli',
#        'Sibsagar', 'Barwani', 'Botad', 'Junagadh', 'Balrampur',
#        'Barabanki', 'Shivpuri', 'Beed', 'Shahjahanpur', 'Jamnagar',
#        'Chandrapur', 'Durg', 'Rangareddy', 'Sirohi', 'Alipurduar',
#        'South West Delhi', 'Gonda', 'East Jaintia Hills', 'Bareilly',
#        'Bundi', 'Solapur', 'Sitapur', 'Dumka', 'Sultanpur',
#        'Karbi Anglong', 'Bikaner', 'Phek', 'Raisen', 'Shrawasti',
#        'East Delhi', 'Jhabua', 'Unakoti', 'Indore', 'Bhopal', 'Dungarpur',
#        'Chandauli', 'Bharatpur', 'Mainpuri', 'Godda', 'Muzaffarnagar',
#        'Siddharthnagar', 'Datia', 'West Tripura', 'Medchal-Malkajgiri',
#        'Sagar', 'Sheopur', 'Arvalli', 'Surendra Nagar', 'Malda', 'Amreli',
#        'Alwar', 'Ambedkar Nagar', 'Madurai', 'Pilibhit', 'Champhai',
#        'Valsad', 'Pakur', 'Vaishali', 'Vidisha', 'Karimganj', 'Biswanath',
#        'Burhanpur', 'Kaushambi', 'Pune', 'Punch', 'Jehanabad', 'Jalaun',
#        'Etah', 'Meerut', 'Baran', 'Sangrur', 'Karauli', 'Anand',
#        'Longleng', 'Chandigarh', 'Jamui', 'South Sikkim', 'Panna',
#        'East Garo Hills', 'Jhalawar', 'Shahdara', 'Kalaburagi',
#        'Thanjavur', 'Peren', 'Tuensang', 'Mahisagar', 'Hoshiarpur',
#        'Noklak', 'Sukma', 'Khandwa', 'Ajmer', 'West Sikkim', 'Latur',
#        'Basti', 'Satna', 'Gurdaspur', 'Hazaribagh', 'Azamgarh', 'Udaipur',
#        'Kolkata', 'Rampur', 'The Dangs', 'East Singhbhum', 'Alirajpur',
#        'S.A.S Nagar (Mohali)', 'South West Garo Hills', 'Moradabad',
#        'Kota', 'Dewas', 'Navsari', 'Chumukedima', 'Ahmedabad',
#        'Nabarangapur', 'Pali', 'Amroha', 'Saiha', 'Dakshin Dinajpur',
#        'Bijnor', 'Pudukkottai', 'Bengaluru Rural', 'Kalimpong', 'Deoria',
#        'Baramula', 'Gopalganj', 'Prayagraj', 'Lalitpur', 'Mewat', 'Hapur',
#        'Jammu', 'Bishnupur', 'Saharsa', 'Arwal', 'Hathras', 'Lawngtlai',
#        'Nashik', 'Yavatmal', 'Cuddalore', 'Kollam', 'Patiala', 'Katihar',
#        'Malappuram', 'Birbhum', 'Siwan', 'Dhule', 'Baloda Bazar',
#        'Washim', 'Coimbatore', 'Lunglei', 'Imphal West', 'Kushinagar',
#        'Thiruvananthapuram', 'Sangli', 'Lakhisarai', 'Dima Hasao',
#        'Banka', 'Salem', 'Dadra And Nagar Haveli', 'Dang', 'Kaithal',
#        'Vellore', 'Shravasti', 'Nalanda', 'Jaisalmer', 'Kallakurichi',
#        'Farrukhabad', 'Medinipur West', 'Araria', 'Sonipat', 'Chatra',
#        'Gaurella Pendra Marwahi', 'Visakhapatnam', 'Buldhana', 'Amravati',
#        'Hardoi', 'Dhalai', 'Ernakulam', 'New Delhi', 'Bhilwara',
#        'Ramanathapuram', 'Mon', 'Raichur', 'North Delhi', 'Rohtak',
#        'Gumla', 'Barmer', 'Kurukshetra', 'Nuh', 'Ashoknagar', 'Thrissur',
#        'North East Delhi', 'Purba Bardhaman', 'Ambala', 'Panipat',
#        'Darbhanga', 'Ayodhya', 'Khunti', 'Sivasagar', 'Hisar',
#        'Sivaganga', 'Senapati', 'Tamenglong', 'Ukhrul', 'Mamit', 'Mammit',
#        'Kiphire', 'Zunheboto', 'Angul', 'Balangir', 'Baleshwar',
#        'Baleswar', 'Bargarh', 'Bhadrak', 'Boudh', 'Cuttack', 'Dhenkanal',
#        'Gajapati', 'Ganjam', 'Jajpur', 'Jagatsinghapur', 'Jajapur',
#        'Jharsuguda', 'Kalahandi', 'Kandhamal', 'Kendrapara', 'Kendujhar',
#        'Khorda', 'Khordha', 'Koraput', 'Malkangiri', 'Mayurbhanj',
#        'Nuapada', 'Nayagarh', 'Puri', 'Rayagada', 'Sambalpur', 'Sonapur',
#        'Subarnapur', 'Sundargarh', 'Sundergarh', 'Anugul', 'Karaikal',
#        'Pondicherry', 'Puducherry', 'Barnala', 'Bathinda', 'Faridkot',
#        'Fatehgarh Sahib', 'Fazilka', 'Ferozepur', 'Firozpur', 'Jalandhar',
#        'Malerkotla', 'Mansa', 'Moga', 'Nawanshahr', 'Pathankot',
#        'Rupnagar', 'Shaheed Bhagat Singh Nagar', 'Sri Muktsar Sahib',
#        'Tarn Taran', 'Banswara', 'Chittaurgarh', 'Chittorgarh', 'Dausa',
#        'Ganganagar', 'Hanumangarh', 'Jhunjhunu', 'Jhunjhunun',
#        'Pratapgarh', 'Rajsamand', 'Sawai Madhopur', 'Tonk', 'North',
#        'South', 'Ariyalur', 'Chengalpattu', 'Chennai', 'Dharmapuri',
#        'Dindigul', 'Erode', 'Kanniyakumari', 'Kanyakumari', 'Karur',
#        'Krishnagiri', 'Mayiladuthurai', 'Nagapattinam', 'Namakkal',
#        'Perambalur', 'Ranipet', 'Tenkasi', 'The Nilgiris', 'Theni',
#        'Thiruvallur', 'Thiruvarur', 'Thoothukkudi', 'Tiruchirappalli',
#        'Tirunelveli', 'Tirupattur', 'Tiruppur', 'Tiruvallur',
#        'Tiruvannamalai', 'Villupuram', 'Viluppuram', 'Virudhunagar',
#        'Adilabad', 'Bhadradri Kothagudem', 'Hanumakonda', 'Jangoan',
#        'Jayashankar Bhupalpally', 'Jogulamba Gadwal', 'Kamareddy',
#        'Karimnagar', 'Khammam', 'Komaram Bheem', 'Mahabubabad',
#        'Mahabubnagar', 'Mancherial', 'Medak', 'Mulugu', 'Nagarkurnool',
#        'Nalgonda', 'Nirmal', 'Nizamabad', 'Chamarajanagar',
#        'Chikkamagaluru', 'Chikkaballapur', 'Chitradurga',
#        'Dakshina Kannada', 'Davanagere', 'Dharwad', 'Gadag', 'Gulbarga',
#        'Hasan', 'Hassan', 'Haveri', 'Kolar', 'Koppal', 'Mandya',
#        'Ramanagar', 'Shivamogga', 'Tumakuru', 'Tumkur', 'Udupi',
#        'Uttara Kannada', 'Vijayanagara', 'Vijayapura', 'Alappuzha',
#        'Idukki', 'Kannur', 'Kasaragod', 'Kottayam', 'Kozhikode',
#        'Palakkad', 'Pathanamthitta', 'Wayanad', 'Kargil', 'Agar Malwa',
#        'Anuppur', 'Balaghat', 'Chhindwara', 'Damoh', 'East Nimar',
#        'Harda', 'Narmadapuram', 'Mandla', 'Mandsaur', 'Narsimhapur',
#        'Narsinghpur', 'Neemuch', 'Rajgarh', 'Ratlam', 'Rewa', 'Sehore',
#        'Seoni', 'Shahdol', 'Shajapur', 'Sidhi', 'Singrauli', 'Tikamgarh',
#        'Ujjain', 'West Nimar', 'Akola', 'Bhandara', 'Buldana',
#        'Chhatrapati Sambhajinagar', 'Gadchiroli', 'Gondiya', 'Kolhapur',
#        'Mumbai', 'Mumbai City', 'Dharashiv', 'Raigarh', 'Ratnagiri',
#        'Sindhudurg', 'Wardha', 'Buxar', 'Khagaria', 'Kishanganj',
#        'Madhepura', 'Nawada', 'Purba Champaran', 'Rohtas', 'Samastipur',
#        'Sheikhpura', 'Sheohar', 'Supaul', 'Bastar', 'Bemetara',
#        'Bilaspur', 'Dakshin Bastar Dantewada', 'Dhamtari',
#        'Janjgir-Champa', 'Jashpur', 'Kawardha', 'Kondagaon', 'Korba',
#        'Koriya', 'Mahasamund', 'Manendragarh Chirmiri Bharatpur',
#        'Mohalla-Manpur-Ambagarh Chowki', 'Mungeli', 'Rajnandgaon',
#        'Sakti', 'Surajpur', 'Uttar Bastar Kanker', 'North Goa',
#        'South Goa', 'Narmada', 'Sabar Kantha', 'Bhiwani', 'Charkhi Dadri',
#        'Fatehabad', 'Jhajjar', 'Jind', 'Karnal', 'Mahendragarh', 'Palwal',
#        'Panchkula', 'Rewari', 'Sirsa', 'Yamuna Nagar', 'Yamunanagar',
#        'Chamba', 'Hamirpur', 'Kangra', 'Kullu', 'Mandi', 'Shimla',
#        'Sirmaur', 'Solan', 'Una', 'Anantnag', 'Bandipore', 'Ganderbal',
#        'Kathua', 'Kishtwar', 'Rajouri', 'Ramban', 'Reasi', 'Samba',
#        'Srinagar', 'Udhampur', 'Bokaro', 'Dhanbad', 'Garhwa', 'Giridih',
#        'Hazaribag', 'Jamtara', 'Koderma', 'Latehar', 'Palamau', 'Palamu',
#        'Purbi Singhbhum', 'Ramgarh', 'Sahebganj', 'Seraikela-Kharsawan',
#        'Simdega', 'West Singhbhum', 'Bagalkot', 'Ballari', 'Belagavi',
#        'Bellary', 'Bidar', 'South Andaman', 'Alluri Sitharama Raju',
#        'Anakapalli', 'Anantapur', 'Ananthapur', 'Ananthapuramu',
#        'Annamayya', 'Bapatla', 'Chittoor', 'Cuddapah',
#        'Dr. B. R. Ambedkar Konaseema', 'East Godavari', 'Eluru', 'Guntur',
#        'Kakinada', 'Karim Nagar', 'Krishna', 'Kurnool', 'Mahbubnagar',
#        'N. T. R', 'Nandyal', 'Nellore', 'Palnadu', 'Parvathipuram Manyam',
#        'Prakasam', 'Sri Sathya Sai', 'Srikakulam', 'Tirupati',
#        'Vizianagaram', 'Warangal', 'West Godavari', 'Y. S. R', 'Anjaw',
#        'Changlang', 'Kra Daadi', 'Lohit', 'Lower Subansiri', 'Papum Pare',
#        'Siang', 'West Kameng', 'Begusarai', 'Bhojpur', 'Peddapalli',
#        'Rajanna Sircilla', 'Sangareddy', 'Siddipet', 'Suryapet',
#        'Vikarabad', 'Wanaparthy', 'Warangal Rural', 'Warangal Urban',
#        'Yadadri Bhuvanagiri', 'Gomati', 'North Tripura', 'Sepahijala',
#        'South Tripura', 'Amethi', 'Auraiya', 'Ballia', 'Bhadohi',
#        'Chitrakoot', 'Faizabad', 'Ghazipur', 'Jhansi', 'Kannauj',
#        'Kasganj', 'Mahoba', 'Mau', 'Mirzapur', 'Rae Bareli', 'Sambhal',
#        'Sant Kabir Nagar', 'Sant Ravidas Nagar', 'Sonbhadra', 'Almora',
#        'Chamoli', 'Champawat', 'Pauri Garhwal', 'Pithoragarh',
#        'Tehri Garhwal', 'Udham Singh Nagar', 'Uttarkashi', 'Bankura',
#        'Barddhaman', 'Bardhaman', 'Darjiling', 'Purba Medinipur', 'Haora',
#        'Hooghly', 'Howrah', 'Koch Bihar', 'Maldah', 'Murshidabad',
#        'North Dinajpur', 'Paschim Bardhaman', 'Paschim Medinipur',
#        'Purulia', 'South 24 Parganas', 'South Dinajpur', 'Surguja',
#        'North East', 'Budgam', 'Doda', 'Kulgam', 'Kupwara', 'Pulwama',
#        'Kodarma', 'Kodagu', 'Lakshadweep', 'Dindori', 'Umaria',
#        'Ahilyanagar', 'Bid', 'Jalna', 'Mumbai( Sub Urban )', 'Chandel',
#        'Debagarh', 'Jagatsinghpur', 'Yanam', 'Jagitial', 'Narayanpet',
#        'Sheikpura', 'Balod', 'Gariyaband', 'Kabeerdham', 'Kanker',
#        'Andamans', 'Nicobar', 'East Kameng', 'Kurung Kumey',
#        'Lower Dibang Valley', 'Namsai', 'Tawang', 'West Siang', 'Majuli',
#        'Aurangabad(Bh)', 'Bhabua', 'Jyotiba Phule Nagar',
#        'Sant Ravidas Nagar Bhadohi', 'Bageshwar', 'Rudraprayag', 'Daman',
#        'Diu', 'Panch Mahals', 'Surendranagar', 'Leh', 'Shupiyan',
#        'Pakaur', 'Imphal East', 'Jiribam', 'Aizawl', 'Kolasib', 'Muktsar',
#        'East Siang', 'Longding', 'Upper Siang', 'Upper Subansiri',
#        'Dantewada', 'Janjgir - Champa', 'Janjgir Champa',
#        'Mohla-Manpur-Ambagarh Chouki', 'Hugli', 'East', 'East Sikkim',
#        'North Sikkim', 'Raigarh(Mh)', 'Mokokchung', 'Wokha', 'Baudh',
#        'West', 'Khowai', 'Kinnaur', 'Badgam', 'Pashchimi Singhbhum',
#        'North And Middle Andaman', 'Kamle', 'Leparada', 'Shi-Yomi',
#        'Tirap', 'Niwari', 'Dibang Valley', 'Sribhumi',
#        'Gaurela-Pendra-Marwahi', 'Narayanpur', 'Khawzawl', 'Serchhip',
#        'Thoubal', 'Mahrajganj', 'Jangaon', 'Bulandshahar', 'Sahibganj',
#        'Maihar', 'K.V.Rangareddy', 'Pakke Kessang', 'Monghyr',
#        'Samstipur', 'Dadra Nagar Haveli', 'Eastern West Khasi Hills',
#        'Niuland', 'Dhaulpur', 'South East Delhi', 'Lahul Spiti',
#        'Mauganj', 'Lower Siang', 'Lahaul And Spiti', 'Bijapur(Kar)',
#        'Pandhurna', 'Khairagarh Chhuikhadan Gandai', 'Kakching',
#        'Bengaluru South', 'Jaintia Hills', 'Saitual', 'Mohali', 'Bagpat',
#        'Garhwal', 'Najafgarh', 'Khairthal-Tijara', 'Hnahthial',
#        'Tirupathur', 'Tamulpur District', 'Sarangarh-Bilaigarh',
#        'Rajauri', 'Ahmednagar', 'Jalore', '24 Paraganas South',
#        'Nabarangpur', 'Ramanagara', 'East Singhbum', 'Dinajpur Dakshin',
#        'Shopian', 'Bajali', 'Meluri', 'Shamator', 'Warangal (Urban)',
#        'Namchi', 'Nicobars', 'Hawrah', 'Deeg', 'Tseminyu', 'Tiruvarur',
#        'Bardez', 'Hooghiy', 'Pherzawl', 'West Medinipur', 'Burdwan',
#        'Bandipur', 'Leh (Ladakh)', 'Anugal', 'Mangan', 'Didwana-Kuchaman',
#        'Salumbar', 'Beawar', 'Balotra', 'Kotputli-Behror'], dtype=object)

# %%
FINAL_DISTRICT_MERGE = {
    'Mahbubnagar': 'Mahabubnagar',

    'Anantapur': 'Ananthapuramu',
    'Ananthapur': 'Ananthapuramu',

    'Coochbehar': 'Cooch Behar',

    'Barddhaman': 'Bardhaman',
    'Burdwan': 'Bardhaman',

    'Haora': 'Howrah',
    'Hawrah': 'Howrah',

    'Hugli': 'Hooghly',
    'Hooghiy': 'Hooghly',

    'Tumkur': 'Tumakuru',

    'Bellary': 'Ballari',

    'Ahmadnagar': 'Ahilyanagar',
    'Ahmednagar': 'Ahilyanagar',

    'Karim Nagar': 'Karimnagar',

    'K.V.Rangareddy': 'Rangareddy',

    'Nellore': 'Sri Potti Sriramulu Nellore',

    'Cuddapah': 'Y.S.R. Kadapa',
    'Y. S. R': 'Y.S.R. Kadapa'
}

df['district'] = df['district'].replace(FINAL_DISTRICT_MERGE)

# %%
invalid = ['East', 'West', 'North', 'South', 'North East']
df.loc[df['district'].isin(invalid), 'district'] = None

# %%
df['district'].nunique()
# Out:
# 879

# %%
df['district'].unique()
# Out:
# array(['East Khasi Hills', 'Bengaluru Urban', 'Kanpur Nagar', 'Aligarh',
#        'Sitamarhi', 'Bahraich', 'Firozabad', 'Purbi Champaran',
#        'Maharajganj', 'Aurangabad', 'Ghaziabad', 'Faridabad', 'Madhubani',
#        'Sikar', 'Bhagalpur', 'Amritsar', 'Gurugram',
#        'Gautam Buddha Nagar', 'West Delhi', 'Bhind', 'Gwalior', 'Katni',
#        'Cooch Behar', 'Lucknow', 'Dinajpur Uttar', 'Marigaon',
#        'Kokrajhar', 'Agra', 'Haridwar', 'Nagaon', 'Parbhani',
#        'West Khasi Hills', 'North West Delhi', 'West Jaintia Hills',
#        'Unnao', 'Saharanpur', 'Dibrugarh', 'Udalguri', 'Chirang',
#        'Kamrup', 'Dhubri', 'Jaunpur', 'Thane', 'Dhemaji', 'Banas Kantha',
#        'Tinsukia', 'Sri Potti Sriramulu Nellore', 'Barpeta', 'Sonitpur',
#        'Baksa', 'Ludhiana', 'Patan', 'Kanchipuram', 'Patna', 'Lakhimpur',
#        'Bongaigaon', 'Vadodara', 'Nainital', 'Dehradun', 'Hojai', 'Dohad',
#        'Morbi', 'Raipur', 'Gorakhpur', 'Bulandshahr', 'Mathura',
#        'Pashchim Champaran', 'Bijapur', 'Deoghar', 'Muzaffarpur', 'Banda',
#        'Kachchh', 'Ri Bhoi', 'Darrang', 'Ashok Nagar', 'Darjeeling',
#        'North Cachar Hills', 'Ranchi', 'Surat', 'Nanded', 'Bengaluru',
#        'Jorhat', 'Gir Somnath', 'Kamrup Metro', 'Goalpara', 'Bhavnagar',
#        'Golaghat', 'Nagpur', 'Jalgaon', 'Hingoli', 'Ahilyanagar',
#        'Gandhinagar', 'North 24 Parganas', 'Munger', 'Kohima', 'Jalor',
#        'Kheda', 'Nalbari', 'Palghar', 'Jodhpur', 'Central Delhi', 'Gaya',
#        'Sabarkantha', 'Dimapur', 'Cachar', 'Banaskantha', 'Kheri',
#        'Rajkot', 'Satara', 'Betul', 'West Karbi Anglong', 'South Delhi',
#        'Raigad', 'Uttar Dinajpur', 'Guna', 'Kaimur (Bhabua)', 'Dholpur',
#        'Churachandpur', 'West Champaran', 'Bharuch', 'Jhargram',
#        'Khargone', 'Chhotaudepur', 'Mumbai Suburban', 'Hailakandi',
#        'Panchmahals', 'South Salmara Mankachar', 'Budaun', 'Kanpur Dehat',
#        'Porbandar', 'West Garo Hills', 'Kapurthala', 'South Garo Hills',
#        'Nagaur', 'Mysuru', 'Mahesana', 'Churu', 'Hyderabad',
#        'Kancheepuram', 'Varanasi', 'Lohardaga', 'North Garo Hills',
#        'Chhatarpur', 'Nadia', 'Purnia', 'Gurgaon', 'Charaideo', 'Jaipur',
#        'Saran', 'Morena', 'Dhar', 'Dahod', 'Devbhumi Dwarka',
#        'East Champaran', 'Tapi', 'Baghpat', 'Fatehpur',
#        'South West Khasi Hills', 'Yadgir', 'Nandurbar', 'Etawah',
#        'Jalpaiguri', 'Jabalpur', 'Shamli', 'Sibsagar', 'Barwani', 'Botad',
#        'Junagadh', 'Balrampur', 'Barabanki', 'Shivpuri', 'Beed',
#        'Shahjahanpur', 'Jamnagar', 'Chandrapur', 'Durg', 'Rangareddy',
#        'Sirohi', 'Alipurduar', 'South West Delhi', 'Gonda',
#        'East Jaintia Hills', 'Bareilly', 'Bundi', 'Solapur', 'Sitapur',
#        'Dumka', 'Sultanpur', 'Karbi Anglong', 'Bikaner', 'Phek', 'Raisen',
#        'Shrawasti', 'East Delhi', 'Jhabua', 'Unakoti', 'Indore', 'Bhopal',
#        'Dungarpur', 'Chandauli', 'Bharatpur', 'Mainpuri', 'Godda',
#        'Muzaffarnagar', 'Siddharthnagar', 'Datia', 'West Tripura',
#        'Medchal-Malkajgiri', 'Sagar', 'Sheopur', 'Arvalli',
#        'Surendra Nagar', 'Malda', 'Amreli', 'Alwar', 'Ambedkar Nagar',
#        'Madurai', 'Pilibhit', 'Champhai', 'Valsad', 'Pakur', 'Vaishali',
#        'Vidisha', 'Karimganj', 'Biswanath', 'Burhanpur', 'Kaushambi',
#        'Pune', 'Punch', 'Jehanabad', 'Jalaun', 'Etah', 'Meerut', 'Baran',
#        'Sangrur', 'Karauli', 'Anand', 'Longleng', 'Chandigarh', 'Jamui',
#        'South Sikkim', 'Panna', 'East Garo Hills', 'Jhalawar', 'Shahdara',
#        'Kalaburagi', 'Thanjavur', 'Peren', 'Tuensang', 'Mahisagar',
#        'Hoshiarpur', 'Noklak', 'Sukma', 'Khandwa', 'Ajmer', 'West Sikkim',
#        'Latur', 'Basti', 'Satna', 'Gurdaspur', 'Hazaribagh', 'Azamgarh',
#        'Udaipur', 'Kolkata', 'Rampur', 'The Dangs', 'East Singhbhum',
#        'Alirajpur', 'S.A.S Nagar (Mohali)', 'South West Garo Hills',
#        'Moradabad', 'Kota', 'Dewas', 'Navsari', 'Chumukedima',
#        'Ahmedabad', 'Nabarangapur', 'Pali', 'Amroha', 'Saiha',
#        'Dakshin Dinajpur', 'Bijnor', 'Pudukkottai', 'Bengaluru Rural',
#        'Kalimpong', 'Deoria', 'Baramula', 'Gopalganj', 'Prayagraj',
#        'Lalitpur', 'Mewat', 'Hapur', 'Jammu', 'Bishnupur', 'Saharsa',
#        'Arwal', 'Hathras', 'Lawngtlai', 'Nashik', 'Yavatmal', 'Cuddalore',
#        'Kollam', 'Patiala', 'Katihar', 'Malappuram', 'Birbhum', 'Siwan',
#        'Dhule', 'Baloda Bazar', 'Washim', 'Coimbatore', 'Lunglei',
#        'Imphal West', 'Kushinagar', 'Thiruvananthapuram', 'Sangli',
#        'Lakhisarai', 'Dima Hasao', 'Banka', 'Salem',
#        'Dadra And Nagar Haveli', 'Dang', 'Kaithal', 'Vellore',
#        'Shravasti', 'Nalanda', 'Jaisalmer', 'Kallakurichi', 'Farrukhabad',
#        'Medinipur West', 'Araria', 'Sonipat', 'Chatra',
#        'Gaurella Pendra Marwahi', 'Visakhapatnam', 'Buldhana', 'Amravati',
#        'Hardoi', 'Dhalai', 'Ernakulam', 'New Delhi', 'Bhilwara',
#        'Ramanathapuram', 'Mon', 'Raichur', 'North Delhi', 'Rohtak',
#        'Gumla', 'Barmer', 'Kurukshetra', 'Nuh', 'Ashoknagar', 'Thrissur',
#        'North East Delhi', 'Purba Bardhaman', 'Ambala', 'Panipat',
#        'Darbhanga', 'Ayodhya', 'Khunti', 'Sivasagar', 'Hisar',
#        'Sivaganga', 'Senapati', 'Tamenglong', 'Ukhrul', 'Mamit', 'Mammit',
#        'Kiphire', 'Zunheboto', 'Angul', 'Balangir', 'Baleshwar',
#        'Baleswar', 'Bargarh', 'Bhadrak', 'Boudh', 'Cuttack', 'Dhenkanal',
#        'Gajapati', 'Ganjam', 'Jajpur', 'Jagatsinghapur', 'Jajapur',
#        'Jharsuguda', 'Kalahandi', 'Kandhamal', 'Kendrapara', 'Kendujhar',
#        'Khorda', 'Khordha', 'Koraput', 'Malkangiri', 'Mayurbhanj',
#        'Nuapada', 'Nayagarh', 'Puri', 'Rayagada', 'Sambalpur', 'Sonapur',
#        'Subarnapur', 'Sundargarh', 'Sundergarh', 'Anugul', 'Karaikal',
#        'Pondicherry', 'Puducherry', 'Barnala', 'Bathinda', 'Faridkot',
#        'Fatehgarh Sahib', 'Fazilka', 'Ferozepur', 'Firozpur', 'Jalandhar',
#        'Malerkotla', 'Mansa', 'Moga', 'Nawanshahr', 'Pathankot',
#        'Rupnagar', 'Shaheed Bhagat Singh Nagar', 'Sri Muktsar Sahib',
#        'Tarn Taran', 'Banswara', 'Chittaurgarh', 'Chittorgarh', 'Dausa',
#        'Ganganagar', 'Hanumangarh', 'Jhunjhunu', 'Jhunjhunun',
#        'Pratapgarh', 'Rajsamand', 'Sawai Madhopur', 'Tonk', None,
#        'Ariyalur', 'Chengalpattu', 'Chennai', 'Dharmapuri', 'Dindigul',
#        'Erode', 'Kanniyakumari', 'Kanyakumari', 'Karur', 'Krishnagiri',
#        'Mayiladuthurai', 'Nagapattinam', 'Namakkal', 'Perambalur',
#        'Ranipet', 'Tenkasi', 'The Nilgiris', 'Theni', 'Thiruvallur',
#        'Thiruvarur', 'Thoothukkudi', 'Tiruchirappalli', 'Tirunelveli',
#        'Tirupattur', 'Tiruppur', 'Tiruvallur', 'Tiruvannamalai',
#        'Villupuram', 'Viluppuram', 'Virudhunagar', 'Adilabad',
#        'Bhadradri Kothagudem', 'Hanumakonda', 'Jangoan',
#        'Jayashankar Bhupalpally', 'Jogulamba Gadwal', 'Kamareddy',
#        'Karimnagar', 'Khammam', 'Komaram Bheem', 'Mahabubabad',
#        'Mahabubnagar', 'Mancherial', 'Medak', 'Mulugu', 'Nagarkurnool',
#        'Nalgonda', 'Nirmal', 'Nizamabad', 'Chamarajanagar',
#        'Chikkamagaluru', 'Chikkaballapur', 'Chitradurga',
#        'Dakshina Kannada', 'Davanagere', 'Dharwad', 'Gadag', 'Gulbarga',
#        'Hasan', 'Hassan', 'Haveri', 'Kolar', 'Koppal', 'Mandya',
#        'Ramanagar', 'Shivamogga', 'Tumakuru', 'Udupi', 'Uttara Kannada',
#        'Vijayanagara', 'Vijayapura', 'Alappuzha', 'Idukki', 'Kannur',
#        'Kasaragod', 'Kottayam', 'Kozhikode', 'Palakkad', 'Pathanamthitta',
#        'Wayanad', 'Kargil', 'Agar Malwa', 'Anuppur', 'Balaghat',
#        'Chhindwara', 'Damoh', 'East Nimar', 'Harda', 'Narmadapuram',
#        'Mandla', 'Mandsaur', 'Narsimhapur', 'Narsinghpur', 'Neemuch',
#        'Rajgarh', 'Ratlam', 'Rewa', 'Sehore', 'Seoni', 'Shahdol',
#        'Shajapur', 'Sidhi', 'Singrauli', 'Tikamgarh', 'Ujjain',
#        'West Nimar', 'Akola', 'Bhandara', 'Buldana',
#        'Chhatrapati Sambhajinagar', 'Gadchiroli', 'Gondiya', 'Kolhapur',
#        'Mumbai', 'Mumbai City', 'Dharashiv', 'Raigarh', 'Ratnagiri',
#        'Sindhudurg', 'Wardha', 'Buxar', 'Khagaria', 'Kishanganj',
#        'Madhepura', 'Nawada', 'Purba Champaran', 'Rohtas', 'Samastipur',
#        'Sheikhpura', 'Sheohar', 'Supaul', 'Bastar', 'Bemetara',
#        'Bilaspur', 'Dakshin Bastar Dantewada', 'Dhamtari',
#        'Janjgir-Champa', 'Jashpur', 'Kawardha', 'Kondagaon', 'Korba',
#        'Koriya', 'Mahasamund', 'Manendragarh Chirmiri Bharatpur',
#        'Mohalla-Manpur-Ambagarh Chowki', 'Mungeli', 'Rajnandgaon',
#        'Sakti', 'Surajpur', 'Uttar Bastar Kanker', 'North Goa',
#        'South Goa', 'Narmada', 'Sabar Kantha', 'Bhiwani', 'Charkhi Dadri',
#        'Fatehabad', 'Jhajjar', 'Jind', 'Karnal', 'Mahendragarh', 'Palwal',
#        'Panchkula', 'Rewari', 'Sirsa', 'Yamuna Nagar', 'Yamunanagar',
#        'Chamba', 'Hamirpur', 'Kangra', 'Kullu', 'Mandi', 'Shimla',
#        'Sirmaur', 'Solan', 'Una', 'Anantnag', 'Bandipore', 'Ganderbal',
#        'Kathua', 'Kishtwar', 'Rajouri', 'Ramban', 'Reasi', 'Samba',
#        'Srinagar', 'Udhampur', 'Bokaro', 'Dhanbad', 'Garhwa', 'Giridih',
#        'Hazaribag', 'Jamtara', 'Koderma', 'Latehar', 'Palamau', 'Palamu',
#        'Purbi Singhbhum', 'Ramgarh', 'Sahebganj', 'Seraikela-Kharsawan',
#        'Simdega', 'West Singhbhum', 'Bagalkot', 'Ballari', 'Belagavi',
#        'Bidar', 'South Andaman', 'Alluri Sitharama Raju', 'Anakapalli',
#        'Ananthapuramu', 'Annamayya', 'Bapatla', 'Chittoor',
#        'Y.S.R. Kadapa', 'Dr. B. R. Ambedkar Konaseema', 'East Godavari',
#        'Eluru', 'Guntur', 'Kakinada', 'Krishna', 'Kurnool', 'N. T. R',
#        'Nandyal', 'Palnadu', 'Parvathipuram Manyam', 'Prakasam',
#        'Sri Sathya Sai', 'Srikakulam', 'Tirupati', 'Vizianagaram',
#        'Warangal', 'West Godavari', 'Anjaw', 'Changlang', 'Kra Daadi',
#        'Lohit', 'Lower Subansiri', 'Papum Pare', 'Siang', 'West Kameng',
#        'Begusarai', 'Bhojpur', 'Peddapalli', 'Rajanna Sircilla',
#        'Sangareddy', 'Siddipet', 'Suryapet', 'Vikarabad', 'Wanaparthy',
#        'Warangal Rural', 'Warangal Urban', 'Yadadri Bhuvanagiri',
#        'Gomati', 'North Tripura', 'Sepahijala', 'South Tripura', 'Amethi',
#        'Auraiya', 'Ballia', 'Bhadohi', 'Chitrakoot', 'Faizabad',
#        'Ghazipur', 'Jhansi', 'Kannauj', 'Kasganj', 'Mahoba', 'Mau',
#        'Mirzapur', 'Rae Bareli', 'Sambhal', 'Sant Kabir Nagar',
#        'Sant Ravidas Nagar', 'Sonbhadra', 'Almora', 'Chamoli',
#        'Champawat', 'Pauri Garhwal', 'Pithoragarh', 'Tehri Garhwal',
#        'Udham Singh Nagar', 'Uttarkashi', 'Bankura', 'Bardhaman',
#        'Darjiling', 'Purba Medinipur', 'Howrah', 'Hooghly', 'Koch Bihar',
#        'Maldah', 'Murshidabad', 'North Dinajpur', 'Paschim Bardhaman',
#        'Paschim Medinipur', 'Purulia', 'South 24 Parganas',
#        'South Dinajpur', 'Surguja', 'Budgam', 'Doda', 'Kulgam', 'Kupwara',
#        'Pulwama', 'Kodarma', 'Kodagu', 'Lakshadweep', 'Dindori', 'Umaria',
#        'Bid', 'Jalna', 'Mumbai( Sub Urban )', 'Chandel', 'Debagarh',
#        'Jagatsinghpur', 'Yanam', 'Jagitial', 'Narayanpet', 'Sheikpura',
#        'Balod', 'Gariyaband', 'Kabeerdham', 'Kanker', 'Andamans',
#        'Nicobar', 'East Kameng', 'Kurung Kumey', 'Lower Dibang Valley',
#        'Namsai', 'Tawang', 'West Siang', 'Majuli', 'Aurangabad(Bh)',
#        'Bhabua', 'Jyotiba Phule Nagar', 'Sant Ravidas Nagar Bhadohi',
#        'Bageshwar', 'Rudraprayag', 'Daman', 'Diu', 'Panch Mahals',
#        'Surendranagar', 'Leh', 'Shupiyan', 'Pakaur', 'Imphal East',
#        'Jiribam', 'Aizawl', 'Kolasib', 'Muktsar', 'East Siang',
#        'Longding', 'Upper Siang', 'Upper Subansiri', 'Dantewada',
#        'Janjgir - Champa', 'Janjgir Champa',
#        'Mohla-Manpur-Ambagarh Chouki', 'East Sikkim', 'North Sikkim',
#        'Raigarh(Mh)', 'Mokokchung', 'Wokha', 'Baudh', 'Khowai', 'Kinnaur',
#        'Badgam', 'Pashchimi Singhbhum', 'North And Middle Andaman',
#        'Kamle', 'Leparada', 'Shi-Yomi', 'Tirap', 'Niwari',
#        'Dibang Valley', 'Sribhumi', 'Gaurela-Pendra-Marwahi',
#        'Narayanpur', 'Khawzawl', 'Serchhip', 'Thoubal', 'Mahrajganj',
#        'Jangaon', 'Bulandshahar', 'Sahibganj', 'Maihar', 'Pakke Kessang',
#        'Monghyr', 'Samstipur', 'Dadra Nagar Haveli',
#        'Eastern West Khasi Hills', 'Niuland', 'Dhaulpur',
#        'South East Delhi', 'Lahul Spiti', 'Mauganj', 'Lower Siang',
#        'Lahaul And Spiti', 'Bijapur(Kar)', 'Pandhurna',
#        'Khairagarh Chhuikhadan Gandai', 'Kakching', 'Bengaluru South',
#        'Jaintia Hills', 'Saitual', 'Mohali', 'Bagpat', 'Garhwal',
#        'Najafgarh', 'Khairthal-Tijara', 'Hnahthial', 'Tirupathur',
#        'Tamulpur District', 'Sarangarh-Bilaigarh', 'Rajauri', 'Jalore',
#        '24 Paraganas South', 'Nabarangpur', 'Ramanagara', 'East Singhbum',
#        'Dinajpur Dakshin', 'Shopian', 'Bajali', 'Meluri', 'Shamator',
#        'Warangal (Urban)', 'Namchi', 'Nicobars', 'Deeg', 'Tseminyu',
#        'Tiruvarur', 'Bardez', 'Pherzawl', 'West Medinipur', 'Bandipur',
#        'Leh (Ladakh)', 'Anugal', 'Mangan', 'Didwana-Kuchaman', 'Salumbar',
#        'Beawar', 'Balotra', 'Kotputli-Behror'], dtype=object)

# %%
OPTIONAL_FINAL_MERGE = {
    'Banas Kantha': 'Banaskantha',
    'Sabar Kantha': 'Sabarkantha',
    'Surendra Nagar': 'Surendranagar',
    'Medinipur West': 'Paschim Medinipur',
    'Lahul Spiti': 'Lahaul And Spiti',
    'Aurangabad(Bh)': 'Aurangabad',
    'Mumbai( Sub Urban )': 'Mumbai Suburban',
    'Warangal (Urban)': 'Warangal Urban'
}

df['district'] = df['district'].replace(OPTIONAL_FINAL_MERGE)

# %%
df['district'].unique()
# Out:
# array(['East Khasi Hills', 'Bengaluru Urban', 'Kanpur Nagar', 'Aligarh',
#        'Sitamarhi', 'Bahraich', 'Firozabad', 'Purbi Champaran',
#        'Maharajganj', 'Aurangabad', 'Ghaziabad', 'Faridabad', 'Madhubani',
#        'Sikar', 'Bhagalpur', 'Amritsar', 'Gurugram',
#        'Gautam Buddha Nagar', 'West Delhi', 'Bhind', 'Gwalior', 'Katni',
#        'Cooch Behar', 'Lucknow', 'Dinajpur Uttar', 'Marigaon',
#        'Kokrajhar', 'Agra', 'Haridwar', 'Nagaon', 'Parbhani',
#        'West Khasi Hills', 'North West Delhi', 'West Jaintia Hills',
#        'Unnao', 'Saharanpur', 'Dibrugarh', 'Udalguri', 'Chirang',
#        'Kamrup', 'Dhubri', 'Jaunpur', 'Thane', 'Dhemaji', 'Banaskantha',
#        'Tinsukia', 'Sri Potti Sriramulu Nellore', 'Barpeta', 'Sonitpur',
#        'Baksa', 'Ludhiana', 'Patan', 'Kanchipuram', 'Patna', 'Lakhimpur',
#        'Bongaigaon', 'Vadodara', 'Nainital', 'Dehradun', 'Hojai', 'Dohad',
#        'Morbi', 'Raipur', 'Gorakhpur', 'Bulandshahr', 'Mathura',
#        'Pashchim Champaran', 'Bijapur', 'Deoghar', 'Muzaffarpur', 'Banda',
#        'Kachchh', 'Ri Bhoi', 'Darrang', 'Ashok Nagar', 'Darjeeling',
#        'North Cachar Hills', 'Ranchi', 'Surat', 'Nanded', 'Bengaluru',
#        'Jorhat', 'Gir Somnath', 'Kamrup Metro', 'Goalpara', 'Bhavnagar',
#        'Golaghat', 'Nagpur', 'Jalgaon', 'Hingoli', 'Ahilyanagar',
#        'Gandhinagar', 'North 24 Parganas', 'Munger', 'Kohima', 'Jalor',
#        'Kheda', 'Nalbari', 'Palghar', 'Jodhpur', 'Central Delhi', 'Gaya',
#        'Sabarkantha', 'Dimapur', 'Cachar', 'Kheri', 'Rajkot', 'Satara',
#        'Betul', 'West Karbi Anglong', 'South Delhi', 'Raigad',
#        'Uttar Dinajpur', 'Guna', 'Kaimur (Bhabua)', 'Dholpur',
#        'Churachandpur', 'West Champaran', 'Bharuch', 'Jhargram',
#        'Khargone', 'Chhotaudepur', 'Mumbai Suburban', 'Hailakandi',
#        'Panchmahals', 'South Salmara Mankachar', 'Budaun', 'Kanpur Dehat',
#        'Porbandar', 'West Garo Hills', 'Kapurthala', 'South Garo Hills',
#        'Nagaur', 'Mysuru', 'Mahesana', 'Churu', 'Hyderabad',
#        'Kancheepuram', 'Varanasi', 'Lohardaga', 'North Garo Hills',
#        'Chhatarpur', 'Nadia', 'Purnia', 'Gurgaon', 'Charaideo', 'Jaipur',
#        'Saran', 'Morena', 'Dhar', 'Dahod', 'Devbhumi Dwarka',
#        'East Champaran', 'Tapi', 'Baghpat', 'Fatehpur',
#        'South West Khasi Hills', 'Yadgir', 'Nandurbar', 'Etawah',
#        'Jalpaiguri', 'Jabalpur', 'Shamli', 'Sibsagar', 'Barwani', 'Botad',
#        'Junagadh', 'Balrampur', 'Barabanki', 'Shivpuri', 'Beed',
#        'Shahjahanpur', 'Jamnagar', 'Chandrapur', 'Durg', 'Rangareddy',
#        'Sirohi', 'Alipurduar', 'South West Delhi', 'Gonda',
#        'East Jaintia Hills', 'Bareilly', 'Bundi', 'Solapur', 'Sitapur',
#        'Dumka', 'Sultanpur', 'Karbi Anglong', 'Bikaner', 'Phek', 'Raisen',
#        'Shrawasti', 'East Delhi', 'Jhabua', 'Unakoti', 'Indore', 'Bhopal',
#        'Dungarpur', 'Chandauli', 'Bharatpur', 'Mainpuri', 'Godda',
#        'Muzaffarnagar', 'Siddharthnagar', 'Datia', 'West Tripura',
#        'Medchal-Malkajgiri', 'Sagar', 'Sheopur', 'Arvalli',
#        'Surendranagar', 'Malda', 'Amreli', 'Alwar', 'Ambedkar Nagar',
#        'Madurai', 'Pilibhit', 'Champhai', 'Valsad', 'Pakur', 'Vaishali',
#        'Vidisha', 'Karimganj', 'Biswanath', 'Burhanpur', 'Kaushambi',
#        'Pune', 'Punch', 'Jehanabad', 'Jalaun', 'Etah', 'Meerut', 'Baran',
#        'Sangrur', 'Karauli', 'Anand', 'Longleng', 'Chandigarh', 'Jamui',
#        'South Sikkim', 'Panna', 'East Garo Hills', 'Jhalawar', 'Shahdara',
#        'Kalaburagi', 'Thanjavur', 'Peren', 'Tuensang', 'Mahisagar',
#        'Hoshiarpur', 'Noklak', 'Sukma', 'Khandwa', 'Ajmer', 'West Sikkim',
#        'Latur', 'Basti', 'Satna', 'Gurdaspur', 'Hazaribagh', 'Azamgarh',
#        'Udaipur', 'Kolkata', 'Rampur', 'The Dangs', 'East Singhbhum',
#        'Alirajpur', 'S.A.S Nagar (Mohali)', 'South West Garo Hills',
#        'Moradabad', 'Kota', 'Dewas', 'Navsari', 'Chumukedima',
#        'Ahmedabad', 'Nabarangapur', 'Pali', 'Amroha', 'Saiha',
#        'Dakshin Dinajpur', 'Bijnor', 'Pudukkottai', 'Bengaluru Rural',
#        'Kalimpong', 'Deoria', 'Baramula', 'Gopalganj', 'Prayagraj',
#        'Lalitpur', 'Mewat', 'Hapur', 'Jammu', 'Bishnupur', 'Saharsa',
#        'Arwal', 'Hathras', 'Lawngtlai', 'Nashik', 'Yavatmal', 'Cuddalore',
#        'Kollam', 'Patiala', 'Katihar', 'Malappuram', 'Birbhum', 'Siwan',
#        'Dhule', 'Baloda Bazar', 'Washim', 'Coimbatore', 'Lunglei',
#        'Imphal West', 'Kushinagar', 'Thiruvananthapuram', 'Sangli',
#        'Lakhisarai', 'Dima Hasao', 'Banka', 'Salem',
#        'Dadra And Nagar Haveli', 'Dang', 'Kaithal', 'Vellore',
#        'Shravasti', 'Nalanda', 'Jaisalmer', 'Kallakurichi', 'Farrukhabad',
#        'Paschim Medinipur', 'Araria', 'Sonipat', 'Chatra',
#        'Gaurella Pendra Marwahi', 'Visakhapatnam', 'Buldhana', 'Amravati',
#        'Hardoi', 'Dhalai', 'Ernakulam', 'New Delhi', 'Bhilwara',
#        'Ramanathapuram', 'Mon', 'Raichur', 'North Delhi', 'Rohtak',
#        'Gumla', 'Barmer', 'Kurukshetra', 'Nuh', 'Ashoknagar', 'Thrissur',
#        'North East Delhi', 'Purba Bardhaman', 'Ambala', 'Panipat',
#        'Darbhanga', 'Ayodhya', 'Khunti', 'Sivasagar', 'Hisar',
#        'Sivaganga', 'Senapati', 'Tamenglong', 'Ukhrul', 'Mamit', 'Mammit',
#        'Kiphire', 'Zunheboto', 'Angul', 'Balangir', 'Baleshwar',
#        'Baleswar', 'Bargarh', 'Bhadrak', 'Boudh', 'Cuttack', 'Dhenkanal',
#        'Gajapati', 'Ganjam', 'Jajpur', 'Jagatsinghapur', 'Jajapur',
#        'Jharsuguda', 'Kalahandi', 'Kandhamal', 'Kendrapara', 'Kendujhar',
#        'Khorda', 'Khordha', 'Koraput', 'Malkangiri', 'Mayurbhanj',
#        'Nuapada', 'Nayagarh', 'Puri', 'Rayagada', 'Sambalpur', 'Sonapur',
#        'Subarnapur', 'Sundargarh', 'Sundergarh', 'Anugul', 'Karaikal',
#        'Pondicherry', 'Puducherry', 'Barnala', 'Bathinda', 'Faridkot',
#        'Fatehgarh Sahib', 'Fazilka', 'Ferozepur', 'Firozpur', 'Jalandhar',
#        'Malerkotla', 'Mansa', 'Moga', 'Nawanshahr', 'Pathankot',
#        'Rupnagar', 'Shaheed Bhagat Singh Nagar', 'Sri Muktsar Sahib',
#        'Tarn Taran', 'Banswara', 'Chittaurgarh', 'Chittorgarh', 'Dausa',
#        'Ganganagar', 'Hanumangarh', 'Jhunjhunu', 'Jhunjhunun',
#        'Pratapgarh', 'Rajsamand', 'Sawai Madhopur', 'Tonk', None,
#        'Ariyalur', 'Chengalpattu', 'Chennai', 'Dharmapuri', 'Dindigul',
#        'Erode', 'Kanniyakumari', 'Kanyakumari', 'Karur', 'Krishnagiri',
#        'Mayiladuthurai', 'Nagapattinam', 'Namakkal', 'Perambalur',
#        'Ranipet', 'Tenkasi', 'The Nilgiris', 'Theni', 'Thiruvallur',
#        'Thiruvarur', 'Thoothukkudi', 'Tiruchirappalli', 'Tirunelveli',
#        'Tirupattur', 'Tiruppur', 'Tiruvallur', 'Tiruvannamalai',
#        'Villupuram', 'Viluppuram', 'Virudhunagar', 'Adilabad',
#        'Bhadradri Kothagudem', 'Hanumakonda', 'Jangoan',
#        'Jayashankar Bhupalpally', 'Jogulamba Gadwal', 'Kamareddy',
#        'Karimnagar', 'Khammam', 'Komaram Bheem', 'Mahabubabad',
#        'Mahabubnagar', 'Mancherial', 'Medak', 'Mulugu', 'Nagarkurnool',
#        'Nalgonda', 'Nirmal', 'Nizamabad', 'Chamarajanagar',
#        'Chikkamagaluru', 'Chikkaballapur', 'Chitradurga',
#        'Dakshina Kannada', 'Davanagere', 'Dharwad', 'Gadag', 'Gulbarga',
#        'Hasan', 'Hassan', 'Haveri', 'Kolar', 'Koppal', 'Mandya',
#        'Ramanagar', 'Shivamogga', 'Tumakuru', 'Udupi', 'Uttara Kannada',
#        'Vijayanagara', 'Vijayapura', 'Alappuzha', 'Idukki', 'Kannur',
#        'Kasaragod', 'Kottayam', 'Kozhikode', 'Palakkad', 'Pathanamthitta',
#        'Wayanad', 'Kargil', 'Agar Malwa', 'Anuppur', 'Balaghat',
#        'Chhindwara', 'Damoh', 'East Nimar', 'Harda', 'Narmadapuram',
#        'Mandla', 'Mandsaur', 'Narsimhapur', 'Narsinghpur', 'Neemuch',
#        'Rajgarh', 'Ratlam', 'Rewa', 'Sehore', 'Seoni', 'Shahdol',
#        'Shajapur', 'Sidhi', 'Singrauli', 'Tikamgarh', 'Ujjain',
#        'West Nimar', 'Akola', 'Bhandara', 'Buldana',
#        'Chhatrapati Sambhajinagar', 'Gadchiroli', 'Gondiya', 'Kolhapur',
#        'Mumbai', 'Mumbai City', 'Dharashiv', 'Raigarh', 'Ratnagiri',
#        'Sindhudurg', 'Wardha', 'Buxar', 'Khagaria', 'Kishanganj',
#        'Madhepura', 'Nawada', 'Purba Champaran', 'Rohtas', 'Samastipur',
#        'Sheikhpura', 'Sheohar', 'Supaul', 'Bastar', 'Bemetara',
#        'Bilaspur', 'Dakshin Bastar Dantewada', 'Dhamtari',
#        'Janjgir-Champa', 'Jashpur', 'Kawardha', 'Kondagaon', 'Korba',
#        'Koriya', 'Mahasamund', 'Manendragarh Chirmiri Bharatpur',
#        'Mohalla-Manpur-Ambagarh Chowki', 'Mungeli', 'Rajnandgaon',
#        'Sakti', 'Surajpur', 'Uttar Bastar Kanker', 'North Goa',
#        'South Goa', 'Narmada', 'Bhiwani', 'Charkhi Dadri', 'Fatehabad',
#        'Jhajjar', 'Jind', 'Karnal', 'Mahendragarh', 'Palwal', 'Panchkula',
#        'Rewari', 'Sirsa', 'Yamuna Nagar', 'Yamunanagar', 'Chamba',
#        'Hamirpur', 'Kangra', 'Kullu', 'Mandi', 'Shimla', 'Sirmaur',
#        'Solan', 'Una', 'Anantnag', 'Bandipore', 'Ganderbal', 'Kathua',
#        'Kishtwar', 'Rajouri', 'Ramban', 'Reasi', 'Samba', 'Srinagar',
#        'Udhampur', 'Bokaro', 'Dhanbad', 'Garhwa', 'Giridih', 'Hazaribag',
#        'Jamtara', 'Koderma', 'Latehar', 'Palamau', 'Palamu',
#        'Purbi Singhbhum', 'Ramgarh', 'Sahebganj', 'Seraikela-Kharsawan',
#        'Simdega', 'West Singhbhum', 'Bagalkot', 'Ballari', 'Belagavi',
#        'Bidar', 'South Andaman', 'Alluri Sitharama Raju', 'Anakapalli',
#        'Ananthapuramu', 'Annamayya', 'Bapatla', 'Chittoor',
#        'Y.S.R. Kadapa', 'Dr. B. R. Ambedkar Konaseema', 'East Godavari',
#        'Eluru', 'Guntur', 'Kakinada', 'Krishna', 'Kurnool', 'N. T. R',
#        'Nandyal', 'Palnadu', 'Parvathipuram Manyam', 'Prakasam',
#        'Sri Sathya Sai', 'Srikakulam', 'Tirupati', 'Vizianagaram',
#        'Warangal', 'West Godavari', 'Anjaw', 'Changlang', 'Kra Daadi',
#        'Lohit', 'Lower Subansiri', 'Papum Pare', 'Siang', 'West Kameng',
#        'Begusarai', 'Bhojpur', 'Peddapalli', 'Rajanna Sircilla',
#        'Sangareddy', 'Siddipet', 'Suryapet', 'Vikarabad', 'Wanaparthy',
#        'Warangal Rural', 'Warangal Urban', 'Yadadri Bhuvanagiri',
#        'Gomati', 'North Tripura', 'Sepahijala', 'South Tripura', 'Amethi',
#        'Auraiya', 'Ballia', 'Bhadohi', 'Chitrakoot', 'Faizabad',
#        'Ghazipur', 'Jhansi', 'Kannauj', 'Kasganj', 'Mahoba', 'Mau',
#        'Mirzapur', 'Rae Bareli', 'Sambhal', 'Sant Kabir Nagar',
#        'Sant Ravidas Nagar', 'Sonbhadra', 'Almora', 'Chamoli',
#        'Champawat', 'Pauri Garhwal', 'Pithoragarh', 'Tehri Garhwal',
#        'Udham Singh Nagar', 'Uttarkashi', 'Bankura', 'Bardhaman',
#        'Darjiling', 'Purba Medinipur', 'Howrah', 'Hooghly', 'Koch Bihar',
#        'Maldah', 'Murshidabad', 'North Dinajpur', 'Paschim Bardhaman',
#        'Purulia', 'South 24 Parganas', 'South Dinajpur', 'Surguja',
#        'Budgam', 'Doda', 'Kulgam', 'Kupwara', 'Pulwama', 'Kodarma',
#        'Kodagu', 'Lakshadweep', 'Dindori', 'Umaria', 'Bid', 'Jalna',
#        'Chandel', 'Debagarh', 'Jagatsinghpur', 'Yanam', 'Jagitial',
#        'Narayanpet', 'Sheikpura', 'Balod', 'Gariyaband', 'Kabeerdham',
#        'Kanker', 'Andamans', 'Nicobar', 'East Kameng', 'Kurung Kumey',
#        'Lower Dibang Valley', 'Namsai', 'Tawang', 'West Siang', 'Majuli',
#        'Bhabua', 'Jyotiba Phule Nagar', 'Sant Ravidas Nagar Bhadohi',
#        'Bageshwar', 'Rudraprayag', 'Daman', 'Diu', 'Panch Mahals', 'Leh',
#        'Shupiyan', 'Pakaur', 'Imphal East', 'Jiribam', 'Aizawl',
#        'Kolasib', 'Muktsar', 'East Siang', 'Longding', 'Upper Siang',
#        'Upper Subansiri', 'Dantewada', 'Janjgir - Champa',
#        'Janjgir Champa', 'Mohla-Manpur-Ambagarh Chouki', 'East Sikkim',
#        'North Sikkim', 'Raigarh(Mh)', 'Mokokchung', 'Wokha', 'Baudh',
#        'Khowai', 'Kinnaur', 'Badgam', 'Pashchimi Singhbhum',
#        'North And Middle Andaman', 'Kamle', 'Leparada', 'Shi-Yomi',
#        'Tirap', 'Niwari', 'Dibang Valley', 'Sribhumi',
#        'Gaurela-Pendra-Marwahi', 'Narayanpur', 'Khawzawl', 'Serchhip',
#        'Thoubal', 'Mahrajganj', 'Jangaon', 'Bulandshahar', 'Sahibganj',
#        'Maihar', 'Pakke Kessang', 'Monghyr', 'Samstipur',
#        'Dadra Nagar Haveli', 'Eastern West Khasi Hills', 'Niuland',
#        'Dhaulpur', 'South East Delhi', 'Lahaul And Spiti', 'Mauganj',
#        'Lower Siang', 'Bijapur(Kar)', 'Pandhurna',
#        'Khairagarh Chhuikhadan Gandai', 'Kakching', 'Bengaluru South',
#        'Jaintia Hills', 'Saitual', 'Mohali', 'Bagpat', 'Garhwal',
#        'Najafgarh', 'Khairthal-Tijara', 'Hnahthial', 'Tirupathur',
#        'Tamulpur District', 'Sarangarh-Bilaigarh', 'Rajauri', 'Jalore',
#        '24 Paraganas South', 'Nabarangpur', 'Ramanagara', 'East Singhbum',
#        'Dinajpur Dakshin', 'Shopian', 'Bajali', 'Meluri', 'Shamator',
#        'Namchi', 'Nicobars', 'Deeg', 'Tseminyu', 'Tiruvarur', 'Bardez',
#        'Pherzawl', 'West Medinipur', 'Bandipur', 'Leh (Ladakh)', 'Anugal',
#        'Mangan', 'Didwana-Kuchaman', 'Salumbar', 'Beawar', 'Balotra',
#        'Kotputli-Behror'], dtype=object)

# %%
df['district'].nunique()
# Out:
# 871

# %%
df = df[df['district'].notna()]

# %%
final_fixes = {
    "Hugli": "Hooghly",
    "Burdwan": "Bardhaman",
    "Davangere": "Davanagere",
    "Chamrajanagar": "Chamarajanagar",
    "Kasargod": "Kasaragod",
    "Mahabub Nagar": "Mahabubnagar",
    "Yadadri.": "Yadadri Bhuvanagiri",
    "North Twenty Four Parganas": "North 24 Parganas",
    "South Twenty Four Parganas": "South 24 Parganas",
    "Bangalore Rural": "Bengaluru Rural",
    "Bengaluru": "Bengaluru Urban",
    "Bengaluru South": "Bengaluru Urban"
}

# %%
df['district'] = df['district'].replace(final_fixes)
df = df[df['district'].notna()]

# %%
df['district'].nunique()
# Out:
# 869

# %%
df['district'].unique()
# Out:
# array(['East Khasi Hills', 'Bengaluru Urban', 'Kanpur Nagar', 'Aligarh',
#        'Sitamarhi', 'Bahraich', 'Firozabad', 'Purbi Champaran',
#        'Maharajganj', 'Aurangabad', 'Ghaziabad', 'Faridabad', 'Madhubani',
#        'Sikar', 'Bhagalpur', 'Amritsar', 'Gurugram',
#        'Gautam Buddha Nagar', 'West Delhi', 'Bhind', 'Gwalior', 'Katni',
#        'Cooch Behar', 'Lucknow', 'Dinajpur Uttar', 'Marigaon',
#        'Kokrajhar', 'Agra', 'Haridwar', 'Nagaon', 'Parbhani',
#        'West Khasi Hills', 'North West Delhi', 'West Jaintia Hills',
#        'Unnao', 'Saharanpur', 'Dibrugarh', 'Udalguri', 'Chirang',
#        'Kamrup', 'Dhubri', 'Jaunpur', 'Thane', 'Dhemaji', 'Banaskantha',
#        'Tinsukia', 'Sri Potti Sriramulu Nellore', 'Barpeta', 'Sonitpur',
#        'Baksa', 'Ludhiana', 'Patan', 'Kanchipuram', 'Patna', 'Lakhimpur',
#        'Bongaigaon', 'Vadodara', 'Nainital', 'Dehradun', 'Hojai', 'Dohad',
#        'Morbi', 'Raipur', 'Gorakhpur', 'Bulandshahr', 'Mathura',
#        'Pashchim Champaran', 'Bijapur', 'Deoghar', 'Muzaffarpur', 'Banda',
#        'Kachchh', 'Ri Bhoi', 'Darrang', 'Ashok Nagar', 'Darjeeling',
#        'North Cachar Hills', 'Ranchi', 'Surat', 'Nanded', 'Jorhat',
#        'Gir Somnath', 'Kamrup Metro', 'Goalpara', 'Bhavnagar', 'Golaghat',
#        'Nagpur', 'Jalgaon', 'Hingoli', 'Ahilyanagar', 'Gandhinagar',
#        'North 24 Parganas', 'Munger', 'Kohima', 'Jalor', 'Kheda',
#        'Nalbari', 'Palghar', 'Jodhpur', 'Central Delhi', 'Gaya',
#        'Sabarkantha', 'Dimapur', 'Cachar', 'Kheri', 'Rajkot', 'Satara',
#        'Betul', 'West Karbi Anglong', 'South Delhi', 'Raigad',
#        'Uttar Dinajpur', 'Guna', 'Kaimur (Bhabua)', 'Dholpur',
#        'Churachandpur', 'West Champaran', 'Bharuch', 'Jhargram',
#        'Khargone', 'Chhotaudepur', 'Mumbai Suburban', 'Hailakandi',
#        'Panchmahals', 'South Salmara Mankachar', 'Budaun', 'Kanpur Dehat',
#        'Porbandar', 'West Garo Hills', 'Kapurthala', 'South Garo Hills',
#        'Nagaur', 'Mysuru', 'Mahesana', 'Churu', 'Hyderabad',
#        'Kancheepuram', 'Varanasi', 'Lohardaga', 'North Garo Hills',
#        'Chhatarpur', 'Nadia', 'Purnia', 'Gurgaon', 'Charaideo', 'Jaipur',
#        'Saran', 'Morena', 'Dhar', 'Dahod', 'Devbhumi Dwarka',
#        'East Champaran', 'Tapi', 'Baghpat', 'Fatehpur',
#        'South West Khasi Hills', 'Yadgir', 'Nandurbar', 'Etawah',
#        'Jalpaiguri', 'Jabalpur', 'Shamli', 'Sibsagar', 'Barwani', 'Botad',
#        'Junagadh', 'Balrampur', 'Barabanki', 'Shivpuri', 'Beed',
#        'Shahjahanpur', 'Jamnagar', 'Chandrapur', 'Durg', 'Rangareddy',
#        'Sirohi', 'Alipurduar', 'South West Delhi', 'Gonda',
#        'East Jaintia Hills', 'Bareilly', 'Bundi', 'Solapur', 'Sitapur',
#        'Dumka', 'Sultanpur', 'Karbi Anglong', 'Bikaner', 'Phek', 'Raisen',
#        'Shrawasti', 'East Delhi', 'Jhabua', 'Unakoti', 'Indore', 'Bhopal',
#        'Dungarpur', 'Chandauli', 'Bharatpur', 'Mainpuri', 'Godda',
#        'Muzaffarnagar', 'Siddharthnagar', 'Datia', 'West Tripura',
#        'Medchal-Malkajgiri', 'Sagar', 'Sheopur', 'Arvalli',
#        'Surendranagar', 'Malda', 'Amreli', 'Alwar', 'Ambedkar Nagar',
#        'Madurai', 'Pilibhit', 'Champhai', 'Valsad', 'Pakur', 'Vaishali',
#        'Vidisha', 'Karimganj', 'Biswanath', 'Burhanpur', 'Kaushambi',
#        'Pune', 'Punch', 'Jehanabad', 'Jalaun', 'Etah', 'Meerut', 'Baran',
#        'Sangrur', 'Karauli', 'Anand', 'Longleng', 'Chandigarh', 'Jamui',
#        'South Sikkim', 'Panna', 'East Garo Hills', 'Jhalawar', 'Shahdara',
#        'Kalaburagi', 'Thanjavur', 'Peren', 'Tuensang', 'Mahisagar',
#        'Hoshiarpur', 'Noklak', 'Sukma', 'Khandwa', 'Ajmer', 'West Sikkim',
#        'Latur', 'Basti', 'Satna', 'Gurdaspur', 'Hazaribagh', 'Azamgarh',
#        'Udaipur', 'Kolkata', 'Rampur', 'The Dangs', 'East Singhbhum',
#        'Alirajpur', 'S.A.S Nagar (Mohali)', 'South West Garo Hills',
#        'Moradabad', 'Kota', 'Dewas', 'Navsari', 'Chumukedima',
#        'Ahmedabad', 'Nabarangapur', 'Pali', 'Amroha', 'Saiha',
#        'Dakshin Dinajpur', 'Bijnor', 'Pudukkottai', 'Bengaluru Rural',
#        'Kalimpong', 'Deoria', 'Baramula', 'Gopalganj', 'Prayagraj',
#        'Lalitpur', 'Mewat', 'Hapur', 'Jammu', 'Bishnupur', 'Saharsa',
#        'Arwal', 'Hathras', 'Lawngtlai', 'Nashik', 'Yavatmal', 'Cuddalore',
#        'Kollam', 'Patiala', 'Katihar', 'Malappuram', 'Birbhum', 'Siwan',
#        'Dhule', 'Baloda Bazar', 'Washim', 'Coimbatore', 'Lunglei',
#        'Imphal West', 'Kushinagar', 'Thiruvananthapuram', 'Sangli',
#        'Lakhisarai', 'Dima Hasao', 'Banka', 'Salem',
#        'Dadra And Nagar Haveli', 'Dang', 'Kaithal', 'Vellore',
#        'Shravasti', 'Nalanda', 'Jaisalmer', 'Kallakurichi', 'Farrukhabad',
#        'Paschim Medinipur', 'Araria', 'Sonipat', 'Chatra',
#        'Gaurella Pendra Marwahi', 'Visakhapatnam', 'Buldhana', 'Amravati',
#        'Hardoi', 'Dhalai', 'Ernakulam', 'New Delhi', 'Bhilwara',
#        'Ramanathapuram', 'Mon', 'Raichur', 'North Delhi', 'Rohtak',
#        'Gumla', 'Barmer', 'Kurukshetra', 'Nuh', 'Ashoknagar', 'Thrissur',
#        'North East Delhi', 'Purba Bardhaman', 'Ambala', 'Panipat',
#        'Darbhanga', 'Ayodhya', 'Khunti', 'Sivasagar', 'Hisar',
#        'Sivaganga', 'Senapati', 'Tamenglong', 'Ukhrul', 'Mamit', 'Mammit',
#        'Kiphire', 'Zunheboto', 'Angul', 'Balangir', 'Baleshwar',
#        'Baleswar', 'Bargarh', 'Bhadrak', 'Boudh', 'Cuttack', 'Dhenkanal',
#        'Gajapati', 'Ganjam', 'Jajpur', 'Jagatsinghapur', 'Jajapur',
#        'Jharsuguda', 'Kalahandi', 'Kandhamal', 'Kendrapara', 'Kendujhar',
#        'Khorda', 'Khordha', 'Koraput', 'Malkangiri', 'Mayurbhanj',
#        'Nuapada', 'Nayagarh', 'Puri', 'Rayagada', 'Sambalpur', 'Sonapur',
#        'Subarnapur', 'Sundargarh', 'Sundergarh', 'Anugul', 'Karaikal',
#        'Pondicherry', 'Puducherry', 'Barnala', 'Bathinda', 'Faridkot',
#        'Fatehgarh Sahib', 'Fazilka', 'Ferozepur', 'Firozpur', 'Jalandhar',
#        'Malerkotla', 'Mansa', 'Moga', 'Nawanshahr', 'Pathankot',
#        'Rupnagar', 'Shaheed Bhagat Singh Nagar', 'Sri Muktsar Sahib',
#        'Tarn Taran', 'Banswara', 'Chittaurgarh', 'Chittorgarh', 'Dausa',
#        'Ganganagar', 'Hanumangarh', 'Jhunjhunu', 'Jhunjhunun',
#        'Pratapgarh', 'Rajsamand', 'Sawai Madhopur', 'Tonk', 'Ariyalur',
#        'Chengalpattu', 'Chennai', 'Dharmapuri', 'Dindigul', 'Erode',
#        'Kanniyakumari', 'Kanyakumari', 'Karur', 'Krishnagiri',
#        'Mayiladuthurai', 'Nagapattinam', 'Namakkal', 'Perambalur',
#        'Ranipet', 'Tenkasi', 'The Nilgiris', 'Theni', 'Thiruvallur',
#        'Thiruvarur', 'Thoothukkudi', 'Tiruchirappalli', 'Tirunelveli',
#        'Tirupattur', 'Tiruppur', 'Tiruvallur', 'Tiruvannamalai',
#        'Villupuram', 'Viluppuram', 'Virudhunagar', 'Adilabad',
#        'Bhadradri Kothagudem', 'Hanumakonda', 'Jangoan',
#        'Jayashankar Bhupalpally', 'Jogulamba Gadwal', 'Kamareddy',
#        'Karimnagar', 'Khammam', 'Komaram Bheem', 'Mahabubabad',
#        'Mahabubnagar', 'Mancherial', 'Medak', 'Mulugu', 'Nagarkurnool',
#        'Nalgonda', 'Nirmal', 'Nizamabad', 'Chamarajanagar',
#        'Chikkamagaluru', 'Chikkaballapur', 'Chitradurga',
#        'Dakshina Kannada', 'Davanagere', 'Dharwad', 'Gadag', 'Gulbarga',
#        'Hasan', 'Hassan', 'Haveri', 'Kolar', 'Koppal', 'Mandya',
#        'Ramanagar', 'Shivamogga', 'Tumakuru', 'Udupi', 'Uttara Kannada',
#        'Vijayanagara', 'Vijayapura', 'Alappuzha', 'Idukki', 'Kannur',
#        'Kasaragod', 'Kottayam', 'Kozhikode', 'Palakkad', 'Pathanamthitta',
#        'Wayanad', 'Kargil', 'Agar Malwa', 'Anuppur', 'Balaghat',
#        'Chhindwara', 'Damoh', 'East Nimar', 'Harda', 'Narmadapuram',
#        'Mandla', 'Mandsaur', 'Narsimhapur', 'Narsinghpur', 'Neemuch',
#        'Rajgarh', 'Ratlam', 'Rewa', 'Sehore', 'Seoni', 'Shahdol',
#        'Shajapur', 'Sidhi', 'Singrauli', 'Tikamgarh', 'Ujjain',
#        'West Nimar', 'Akola', 'Bhandara', 'Buldana',
#        'Chhatrapati Sambhajinagar', 'Gadchiroli', 'Gondiya', 'Kolhapur',
#        'Mumbai', 'Mumbai City', 'Dharashiv', 'Raigarh', 'Ratnagiri',
#        'Sindhudurg', 'Wardha', 'Buxar', 'Khagaria', 'Kishanganj',
#        'Madhepura', 'Nawada', 'Purba Champaran', 'Rohtas', 'Samastipur',
#        'Sheikhpura', 'Sheohar', 'Supaul', 'Bastar', 'Bemetara',
#        'Bilaspur', 'Dakshin Bastar Dantewada', 'Dhamtari',
#        'Janjgir-Champa', 'Jashpur', 'Kawardha', 'Kondagaon', 'Korba',
#        'Koriya', 'Mahasamund', 'Manendragarh Chirmiri Bharatpur',
#        'Mohalla-Manpur-Ambagarh Chowki', 'Mungeli', 'Rajnandgaon',
#        'Sakti', 'Surajpur', 'Uttar Bastar Kanker', 'North Goa',
#        'South Goa', 'Narmada', 'Bhiwani', 'Charkhi Dadri', 'Fatehabad',
#        'Jhajjar', 'Jind', 'Karnal', 'Mahendragarh', 'Palwal', 'Panchkula',
#        'Rewari', 'Sirsa', 'Yamuna Nagar', 'Yamunanagar', 'Chamba',
#        'Hamirpur', 'Kangra', 'Kullu', 'Mandi', 'Shimla', 'Sirmaur',
#        'Solan', 'Una', 'Anantnag', 'Bandipore', 'Ganderbal', 'Kathua',
#        'Kishtwar', 'Rajouri', 'Ramban', 'Reasi', 'Samba', 'Srinagar',
#        'Udhampur', 'Bokaro', 'Dhanbad', 'Garhwa', 'Giridih', 'Hazaribag',
#        'Jamtara', 'Koderma', 'Latehar', 'Palamau', 'Palamu',
#        'Purbi Singhbhum', 'Ramgarh', 'Sahebganj', 'Seraikela-Kharsawan',
#        'Simdega', 'West Singhbhum', 'Bagalkot', 'Ballari', 'Belagavi',
#        'Bidar', 'South Andaman', 'Alluri Sitharama Raju', 'Anakapalli',
#        'Ananthapuramu', 'Annamayya', 'Bapatla', 'Chittoor',
#        'Y.S.R. Kadapa', 'Dr. B. R. Ambedkar Konaseema', 'East Godavari',
#        'Eluru', 'Guntur', 'Kakinada', 'Krishna', 'Kurnool', 'N. T. R',
#        'Nandyal', 'Palnadu', 'Parvathipuram Manyam', 'Prakasam',
#        'Sri Sathya Sai', 'Srikakulam', 'Tirupati', 'Vizianagaram',
#        'Warangal', 'West Godavari', 'Anjaw', 'Changlang', 'Kra Daadi',
#        'Lohit', 'Lower Subansiri', 'Papum Pare', 'Siang', 'West Kameng',
#        'Begusarai', 'Bhojpur', 'Peddapalli', 'Rajanna Sircilla',
#        'Sangareddy', 'Siddipet', 'Suryapet', 'Vikarabad', 'Wanaparthy',
#        'Warangal Rural', 'Warangal Urban', 'Yadadri Bhuvanagiri',
#        'Gomati', 'North Tripura', 'Sepahijala', 'South Tripura', 'Amethi',
#        'Auraiya', 'Ballia', 'Bhadohi', 'Chitrakoot', 'Faizabad',
#        'Ghazipur', 'Jhansi', 'Kannauj', 'Kasganj', 'Mahoba', 'Mau',
#        'Mirzapur', 'Rae Bareli', 'Sambhal', 'Sant Kabir Nagar',
#        'Sant Ravidas Nagar', 'Sonbhadra', 'Almora', 'Chamoli',
#        'Champawat', 'Pauri Garhwal', 'Pithoragarh', 'Tehri Garhwal',
#        'Udham Singh Nagar', 'Uttarkashi', 'Bankura', 'Bardhaman',
#        'Darjiling', 'Purba Medinipur', 'Howrah', 'Hooghly', 'Koch Bihar',
#        'Maldah', 'Murshidabad', 'North Dinajpur', 'Paschim Bardhaman',
#        'Purulia', 'South 24 Parganas', 'South Dinajpur', 'Surguja',
#        'Budgam', 'Doda', 'Kulgam', 'Kupwara', 'Pulwama', 'Kodarma',
#        'Kodagu', 'Lakshadweep', 'Dindori', 'Umaria', 'Bid', 'Jalna',
#        'Chandel', 'Debagarh', 'Jagatsinghpur', 'Yanam', 'Jagitial',
#        'Narayanpet', 'Sheikpura', 'Balod', 'Gariyaband', 'Kabeerdham',
#        'Kanker', 'Andamans', 'Nicobar', 'East Kameng', 'Kurung Kumey',
#        'Lower Dibang Valley', 'Namsai', 'Tawang', 'West Siang', 'Majuli',
#        'Bhabua', 'Jyotiba Phule Nagar', 'Sant Ravidas Nagar Bhadohi',
#        'Bageshwar', 'Rudraprayag', 'Daman', 'Diu', 'Panch Mahals', 'Leh',
#        'Shupiyan', 'Pakaur', 'Imphal East', 'Jiribam', 'Aizawl',
#        'Kolasib', 'Muktsar', 'East Siang', 'Longding', 'Upper Siang',
#        'Upper Subansiri', 'Dantewada', 'Janjgir - Champa',
#        'Janjgir Champa', 'Mohla-Manpur-Ambagarh Chouki', 'East Sikkim',
#        'North Sikkim', 'Raigarh(Mh)', 'Mokokchung', 'Wokha', 'Baudh',
#        'Khowai', 'Kinnaur', 'Badgam', 'Pashchimi Singhbhum',
#        'North And Middle Andaman', 'Kamle', 'Leparada', 'Shi-Yomi',
#        'Tirap', 'Niwari', 'Dibang Valley', 'Sribhumi',
#        'Gaurela-Pendra-Marwahi', 'Narayanpur', 'Khawzawl', 'Serchhip',
#        'Thoubal', 'Mahrajganj', 'Jangaon', 'Bulandshahar', 'Sahibganj',
#        'Maihar', 'Pakke Kessang', 'Monghyr', 'Samstipur',
#        'Dadra Nagar Haveli', 'Eastern West Khasi Hills', 'Niuland',
#        'Dhaulpur', 'South East Delhi', 'Lahaul And Spiti', 'Mauganj',
#        'Lower Siang', 'Bijapur(Kar)', 'Pandhurna',
#        'Khairagarh Chhuikhadan Gandai', 'Kakching', 'Jaintia Hills',
#        'Saitual', 'Mohali', 'Bagpat', 'Garhwal', 'Najafgarh',
#        'Khairthal-Tijara', 'Hnahthial', 'Tirupathur', 'Tamulpur District',
#        'Sarangarh-Bilaigarh', 'Rajauri', 'Jalore', '24 Paraganas South',
#        'Nabarangpur', 'Ramanagara', 'East Singhbum', 'Dinajpur Dakshin',
#        'Shopian', 'Bajali', 'Meluri', 'Shamator', 'Namchi', 'Nicobars',
#        'Deeg', 'Tseminyu', 'Tiruvarur', 'Bardez', 'Pherzawl',
#        'West Medinipur', 'Bandipur', 'Leh (Ladakh)', 'Anugal', 'Mangan',
#        'Didwana-Kuchaman', 'Salumbar', 'Beawar', 'Balotra',
#        'Kotputli-Behror'], dtype=object)

# %%
# ==========================================
# FINAL DISTRICT NORMALIZATION & DE-DUP
# ==========================================

import re

# -------------------------------
# 1. Canonical district key
# -------------------------------
def district_key(x):
    if pd.isna(x):
        return None
    x = x.lower().strip()
    x = re.sub(r'[^a-z]', '', x)   # only letters
    return x

df['district_key'] = df['district'].apply(district_key)

# -------------------------------
# 2. Authoritative final mapping
# (ONLY real duplicates)
# -------------------------------
FINAL_DISTRICT_MAP = {

    # Odisha
    'khorda': 'Khordha',
    'baleshwar': 'Baleswar',
    'jajapur': 'Jajpur',
    'jagatsinghapur': 'Jagatsinghpur',
    'sonapur': 'Subarnapur',

    # West Bengal
    'dinajpurdakshin': 'Dakshin Dinajpur',
    'dinajpuruttar': 'Uttar Dinajpur',
    'medinipur': 'Paschim Medinipur',
    'westmedinipur': 'Paschim Medinipur',
    'eastmedinipur': 'Purba Medinipur',

    # Tamil Nadu
    'villupuram': 'Viluppuram',
    'kancheepuram': 'Kanchipuram',

    # Madhya Pradesh
    'narsinghpur': 'Narsimhapur',
    'hoshangabad': 'Narmadapuram',

    # Karnataka
    'bijapurkar': 'Vijayapura',
    'gulbarga': 'Kalaburagi',
    'bellary': 'Ballari',
    'tumkur': 'Tumakuru',

    # Maharashtra
    'ahmadnagar': 'Ahilyanagar',
    'osmanabad': 'Dharashiv',

    # Ladakh / J&K
    'lehladakh': 'Leh',
    'leh': 'Leh',

    # Telangana / AP safety
    'ysr': 'Y.S.R. Kadapa',
    'ysrkadapa': 'Y.S.R. Kadapa',

    # Karnataka
    'Hasan': 'Hassan',
    'Gulbarga': 'Kalaburagi',
    'Bijapur': 'Vijayapura',
    'Bid': 'Beed',

    # Odisha
    'Sundergarh': 'Sundargarh',
    'Baleshwar': 'Baleswar',

    # West Bengal
    'East Singhbum': 'East Singhbhum',
    'Medinipur': 'Paschim Medinipur',

    # Bihar
    'Samstipur': 'Samastipur',
    'Monghyr': 'Munger',

    # Rajasthan
    'Jhunjhunun': 'Jhunjhunu',

    # Telangana / AP
    'Warangal Urban': 'Warangal',
    'Warangal Rural': 'Warangal',

    # Ladakh / J&K
    'Leh (Ladakh)': 'Leh',

    # North East
    'Mammit': 'Mamit',

    # Maharashtra
    'Ahmadnagar': 'Ahilyanagar',
    'Osmanabad': 'Dharashiv'
}

# -------------------------------
# 3. Apply final mapping
# -------------------------------
df['district'] = df.apply(
    lambda row: FINAL_DISTRICT_MAP.get(row['district_key'], row['district']),
    axis=1
)

# -------------------------------
# 4. Drop helper column
# -------------------------------
df.drop(columns=['district_key'], inplace=True)

# -------------------------------
# 5. Final validation
# -------------------------------
print("✅ Final unique districts:", df['district'].nunique())
print("✅ Sample districts:", sorted(df['district'].unique())[:20])
# Out:
# ✅ Final unique districts: 855
# ✅ Sample districts: ['24 Paraganas South', 'Adilabad', 'Agar Malwa', 'Agra', 'Ahilyanagar', 'Ahmedabad', 'Aizawl', 'Ajmer', 'Akola', 'Alappuzha', 'Aligarh', 'Alipurduar', 'Alirajpur', 'Alluri Sitharama Raju', 'Almora', 'Alwar', 'Ambala', 'Ambedkar Nagar', 'Amethi', 'Amravati']

# %%
FINAL_DISTRICT_DEDUP = {
    'Hasan': 'Hassan',
    'Jhunjhunun': 'Jhunjhunu',
    'Sundergarh': 'Sundargarh',
    'Baleshwar': 'Baleswar',
    'Chittaurgarh': 'Chittorgarh',
    'Yamuna Nagar': 'Yamunanagar',
    'Dadra Nagar Haveli': 'Dadra And Nagar Haveli',
    'Mammit': 'Mamit',
    'Monghyr': 'Munger',
    'East Singhbum': 'East Singhbhum',
    'Ashok Nagar': 'Ashoknagar',
    'Ashoknagar': 'Ashoknagar',

    'Janjgir Champa': 'Janjgir-Champa',
    'Janjgir - Champa': 'Janjgir-Champa',
    'Janjgir-Champa': 'Janjgir-Champa',

    'Panch Mahals': 'Panchmahals',
    'Panchmahals': 'Panchmahals'
}

df['district'] = df['district'].replace(FINAL_DISTRICT_DEDUP)

print("Final unique districts:", df['district'].nunique())
# Out:
# Final unique districts: 842

# %% [markdown]
# # FINAL ZERO-DUPLICATE PROOF

# %%
import re

def norm_key(x):
    return re.sub(r'[^a-z]', '', x.lower())

dups = (
    df.assign(k=df['district'].apply(norm_key))
      .groupby('k')['district']
      .nunique()
      .loc[lambda x: x > 1]
)

dups
# Out:
# Series([], Name: district, dtype: int64)

# %%
df['district'].unique()
# Out:
# array(['East Khasi Hills', 'Bengaluru Urban', 'Kanpur Nagar', 'Aligarh',
#        'Sitamarhi', 'Bahraich', 'Firozabad', 'Purbi Champaran',
#        'Maharajganj', 'Aurangabad', 'Ghaziabad', 'Faridabad', 'Madhubani',
#        'Sikar', 'Bhagalpur', 'Amritsar', 'Gurugram',
#        'Gautam Buddha Nagar', 'West Delhi', 'Bhind', 'Gwalior', 'Katni',
#        'Cooch Behar', 'Lucknow', 'Uttar Dinajpur', 'Marigaon',
#        'Kokrajhar', 'Agra', 'Haridwar', 'Nagaon', 'Parbhani',
#        'West Khasi Hills', 'North West Delhi', 'West Jaintia Hills',
#        'Unnao', 'Saharanpur', 'Dibrugarh', 'Udalguri', 'Chirang',
#        'Kamrup', 'Dhubri', 'Jaunpur', 'Thane', 'Dhemaji', 'Banaskantha',
#        'Tinsukia', 'Sri Potti Sriramulu Nellore', 'Barpeta', 'Sonitpur',
#        'Baksa', 'Ludhiana', 'Patan', 'Kanchipuram', 'Patna', 'Lakhimpur',
#        'Bongaigaon', 'Vadodara', 'Nainital', 'Dehradun', 'Hojai', 'Dohad',
#        'Morbi', 'Raipur', 'Gorakhpur', 'Bulandshahr', 'Mathura',
#        'Pashchim Champaran', 'Bijapur', 'Deoghar', 'Muzaffarpur', 'Banda',
#        'Kachchh', 'Ri Bhoi', 'Darrang', 'Ashoknagar', 'Darjeeling',
#        'North Cachar Hills', 'Ranchi', 'Surat', 'Nanded', 'Jorhat',
#        'Gir Somnath', 'Kamrup Metro', 'Goalpara', 'Bhavnagar', 'Golaghat',
#        'Nagpur', 'Jalgaon', 'Hingoli', 'Ahilyanagar', 'Gandhinagar',
#        'North 24 Parganas', 'Munger', 'Kohima', 'Jalor', 'Kheda',
#        'Nalbari', 'Palghar', 'Jodhpur', 'Central Delhi', 'Gaya',
#        'Sabarkantha', 'Dimapur', 'Cachar', 'Kheri', 'Rajkot', 'Satara',
#        'Betul', 'West Karbi Anglong', 'South Delhi', 'Raigad', 'Guna',
#        'Kaimur (Bhabua)', 'Dholpur', 'Churachandpur', 'West Champaran',
#        'Bharuch', 'Jhargram', 'Khargone', 'Chhotaudepur',
#        'Mumbai Suburban', 'Hailakandi', 'Panchmahals',
#        'South Salmara Mankachar', 'Budaun', 'Kanpur Dehat', 'Porbandar',
#        'West Garo Hills', 'Kapurthala', 'South Garo Hills', 'Nagaur',
#        'Mysuru', 'Mahesana', 'Churu', 'Hyderabad', 'Varanasi',
#        'Lohardaga', 'North Garo Hills', 'Chhatarpur', 'Nadia', 'Purnia',
#        'Gurgaon', 'Charaideo', 'Jaipur', 'Saran', 'Morena', 'Dhar',
#        'Dahod', 'Devbhumi Dwarka', 'East Champaran', 'Tapi', 'Baghpat',
#        'Fatehpur', 'South West Khasi Hills', 'Yadgir', 'Nandurbar',
#        'Etawah', 'Jalpaiguri', 'Jabalpur', 'Shamli', 'Sibsagar',
#        'Barwani', 'Botad', 'Junagadh', 'Balrampur', 'Barabanki',
#        'Shivpuri', 'Beed', 'Shahjahanpur', 'Jamnagar', 'Chandrapur',
#        'Durg', 'Rangareddy', 'Sirohi', 'Alipurduar', 'South West Delhi',
#        'Gonda', 'East Jaintia Hills', 'Bareilly', 'Bundi', 'Solapur',
#        'Sitapur', 'Dumka', 'Sultanpur', 'Karbi Anglong', 'Bikaner',
#        'Phek', 'Raisen', 'Shrawasti', 'East Delhi', 'Jhabua', 'Unakoti',
#        'Indore', 'Bhopal', 'Dungarpur', 'Chandauli', 'Bharatpur',
#        'Mainpuri', 'Godda', 'Muzaffarnagar', 'Siddharthnagar', 'Datia',
#        'West Tripura', 'Medchal-Malkajgiri', 'Sagar', 'Sheopur',
#        'Arvalli', 'Surendranagar', 'Malda', 'Amreli', 'Alwar',
#        'Ambedkar Nagar', 'Madurai', 'Pilibhit', 'Champhai', 'Valsad',
#        'Pakur', 'Vaishali', 'Vidisha', 'Karimganj', 'Biswanath',
#        'Burhanpur', 'Kaushambi', 'Pune', 'Punch', 'Jehanabad', 'Jalaun',
#        'Etah', 'Meerut', 'Baran', 'Sangrur', 'Karauli', 'Anand',
#        'Longleng', 'Chandigarh', 'Jamui', 'South Sikkim', 'Panna',
#        'East Garo Hills', 'Jhalawar', 'Shahdara', 'Kalaburagi',
#        'Thanjavur', 'Peren', 'Tuensang', 'Mahisagar', 'Hoshiarpur',
#        'Noklak', 'Sukma', 'Khandwa', 'Ajmer', 'West Sikkim', 'Latur',
#        'Basti', 'Satna', 'Gurdaspur', 'Hazaribagh', 'Azamgarh', 'Udaipur',
#        'Kolkata', 'Rampur', 'The Dangs', 'East Singhbhum', 'Alirajpur',
#        'S.A.S Nagar (Mohali)', 'South West Garo Hills', 'Moradabad',
#        'Kota', 'Dewas', 'Navsari', 'Chumukedima', 'Ahmedabad',
#        'Nabarangapur', 'Pali', 'Amroha', 'Saiha', 'Dakshin Dinajpur',
#        'Bijnor', 'Pudukkottai', 'Bengaluru Rural', 'Kalimpong', 'Deoria',
#        'Baramula', 'Gopalganj', 'Prayagraj', 'Lalitpur', 'Mewat', 'Hapur',
#        'Jammu', 'Bishnupur', 'Saharsa', 'Arwal', 'Hathras', 'Lawngtlai',
#        'Nashik', 'Yavatmal', 'Cuddalore', 'Kollam', 'Patiala', 'Katihar',
#        'Malappuram', 'Birbhum', 'Siwan', 'Dhule', 'Baloda Bazar',
#        'Washim', 'Coimbatore', 'Lunglei', 'Imphal West', 'Kushinagar',
#        'Thiruvananthapuram', 'Sangli', 'Lakhisarai', 'Dima Hasao',
#        'Banka', 'Salem', 'Dadra And Nagar Haveli', 'Dang', 'Kaithal',
#        'Vellore', 'Shravasti', 'Nalanda', 'Jaisalmer', 'Kallakurichi',
#        'Farrukhabad', 'Paschim Medinipur', 'Araria', 'Sonipat', 'Chatra',
#        'Gaurella Pendra Marwahi', 'Visakhapatnam', 'Buldhana', 'Amravati',
#        'Hardoi', 'Dhalai', 'Ernakulam', 'New Delhi', 'Bhilwara',
#        'Ramanathapuram', 'Mon', 'Raichur', 'North Delhi', 'Rohtak',
#        'Gumla', 'Barmer', 'Kurukshetra', 'Nuh', 'Thrissur',
#        'North East Delhi', 'Purba Bardhaman', 'Ambala', 'Panipat',
#        'Darbhanga', 'Ayodhya', 'Khunti', 'Sivasagar', 'Hisar',
#        'Sivaganga', 'Senapati', 'Tamenglong', 'Ukhrul', 'Mamit',
#        'Kiphire', 'Zunheboto', 'Angul', 'Balangir', 'Baleswar', 'Bargarh',
#        'Bhadrak', 'Boudh', 'Cuttack', 'Dhenkanal', 'Gajapati', 'Ganjam',
#        'Jajpur', 'Jagatsinghpur', 'Jharsuguda', 'Kalahandi', 'Kandhamal',
#        'Kendrapara', 'Kendujhar', 'Khordha', 'Koraput', 'Malkangiri',
#        'Mayurbhanj', 'Nuapada', 'Nayagarh', 'Puri', 'Rayagada',
#        'Sambalpur', 'Subarnapur', 'Sundargarh', 'Anugul', 'Karaikal',
#        'Pondicherry', 'Puducherry', 'Barnala', 'Bathinda', 'Faridkot',
#        'Fatehgarh Sahib', 'Fazilka', 'Ferozepur', 'Firozpur', 'Jalandhar',
#        'Malerkotla', 'Mansa', 'Moga', 'Nawanshahr', 'Pathankot',
#        'Rupnagar', 'Shaheed Bhagat Singh Nagar', 'Sri Muktsar Sahib',
#        'Tarn Taran', 'Banswara', 'Chittorgarh', 'Dausa', 'Ganganagar',
#        'Hanumangarh', 'Jhunjhunu', 'Pratapgarh', 'Rajsamand',
#        'Sawai Madhopur', 'Tonk', 'Ariyalur', 'Chengalpattu', 'Chennai',
#        'Dharmapuri', 'Dindigul', 'Erode', 'Kanniyakumari', 'Kanyakumari',
#        'Karur', 'Krishnagiri', 'Mayiladuthurai', 'Nagapattinam',
#        'Namakkal', 'Perambalur', 'Ranipet', 'Tenkasi', 'The Nilgiris',
#        'Theni', 'Thiruvallur', 'Thiruvarur', 'Thoothukkudi',
#        'Tiruchirappalli', 'Tirunelveli', 'Tirupattur', 'Tiruppur',
#        'Tiruvallur', 'Tiruvannamalai', 'Viluppuram', 'Virudhunagar',
#        'Adilabad', 'Bhadradri Kothagudem', 'Hanumakonda', 'Jangoan',
#        'Jayashankar Bhupalpally', 'Jogulamba Gadwal', 'Kamareddy',
#        'Karimnagar', 'Khammam', 'Komaram Bheem', 'Mahabubabad',
#        'Mahabubnagar', 'Mancherial', 'Medak', 'Mulugu', 'Nagarkurnool',
#        'Nalgonda', 'Nirmal', 'Nizamabad', 'Chamarajanagar',
#        'Chikkamagaluru', 'Chikkaballapur', 'Chitradurga',
#        'Dakshina Kannada', 'Davanagere', 'Dharwad', 'Gadag', 'Hassan',
#        'Haveri', 'Kolar', 'Koppal', 'Mandya', 'Ramanagar', 'Shivamogga',
#        'Tumakuru', 'Udupi', 'Uttara Kannada', 'Vijayanagara',
#        'Vijayapura', 'Alappuzha', 'Idukki', 'Kannur', 'Kasaragod',
#        'Kottayam', 'Kozhikode', 'Palakkad', 'Pathanamthitta', 'Wayanad',
#        'Kargil', 'Agar Malwa', 'Anuppur', 'Balaghat', 'Chhindwara',
#        'Damoh', 'East Nimar', 'Harda', 'Narmadapuram', 'Mandla',
#        'Mandsaur', 'Narsimhapur', 'Neemuch', 'Rajgarh', 'Ratlam', 'Rewa',
#        'Sehore', 'Seoni', 'Shahdol', 'Shajapur', 'Sidhi', 'Singrauli',
#        'Tikamgarh', 'Ujjain', 'West Nimar', 'Akola', 'Bhandara',
#        'Buldana', 'Chhatrapati Sambhajinagar', 'Gadchiroli', 'Gondiya',
#        'Kolhapur', 'Mumbai', 'Mumbai City', 'Dharashiv', 'Raigarh',
#        'Ratnagiri', 'Sindhudurg', 'Wardha', 'Buxar', 'Khagaria',
#        'Kishanganj', 'Madhepura', 'Nawada', 'Purba Champaran', 'Rohtas',
#        'Samastipur', 'Sheikhpura', 'Sheohar', 'Supaul', 'Bastar',
#        'Bemetara', 'Bilaspur', 'Dakshin Bastar Dantewada', 'Dhamtari',
#        'Janjgir-Champa', 'Jashpur', 'Kawardha', 'Kondagaon', 'Korba',
#        'Koriya', 'Mahasamund', 'Manendragarh Chirmiri Bharatpur',
#        'Mohalla-Manpur-Ambagarh Chowki', 'Mungeli', 'Rajnandgaon',
#        'Sakti', 'Surajpur', 'Uttar Bastar Kanker', 'North Goa',
#        'South Goa', 'Narmada', 'Bhiwani', 'Charkhi Dadri', 'Fatehabad',
#        'Jhajjar', 'Jind', 'Karnal', 'Mahendragarh', 'Palwal', 'Panchkula',
#        'Rewari', 'Sirsa', 'Yamunanagar', 'Chamba', 'Hamirpur', 'Kangra',
#        'Kullu', 'Mandi', 'Shimla', 'Sirmaur', 'Solan', 'Una', 'Anantnag',
#        'Bandipore', 'Ganderbal', 'Kathua', 'Kishtwar', 'Rajouri',
#        'Ramban', 'Reasi', 'Samba', 'Srinagar', 'Udhampur', 'Bokaro',
#        'Dhanbad', 'Garhwa', 'Giridih', 'Hazaribag', 'Jamtara', 'Koderma',
#        'Latehar', 'Palamau', 'Palamu', 'Purbi Singhbhum', 'Ramgarh',
#        'Sahebganj', 'Seraikela-Kharsawan', 'Simdega', 'West Singhbhum',
#        'Bagalkot', 'Ballari', 'Belagavi', 'Bidar', 'South Andaman',
#        'Alluri Sitharama Raju', 'Anakapalli', 'Ananthapuramu',
#        'Annamayya', 'Bapatla', 'Chittoor', 'Y.S.R. Kadapa',
#        'Dr. B. R. Ambedkar Konaseema', 'East Godavari', 'Eluru', 'Guntur',
#        'Kakinada', 'Krishna', 'Kurnool', 'N. T. R', 'Nandyal', 'Palnadu',
#        'Parvathipuram Manyam', 'Prakasam', 'Sri Sathya Sai', 'Srikakulam',
#        'Tirupati', 'Vizianagaram', 'Warangal', 'West Godavari', 'Anjaw',
#        'Changlang', 'Kra Daadi', 'Lohit', 'Lower Subansiri', 'Papum Pare',
#        'Siang', 'West Kameng', 'Begusarai', 'Bhojpur', 'Peddapalli',
#        'Rajanna Sircilla', 'Sangareddy', 'Siddipet', 'Suryapet',
#        'Vikarabad', 'Wanaparthy', 'Warangal Rural', 'Warangal Urban',
#        'Yadadri Bhuvanagiri', 'Gomati', 'North Tripura', 'Sepahijala',
#        'South Tripura', 'Amethi', 'Auraiya', 'Ballia', 'Bhadohi',
#        'Chitrakoot', 'Faizabad', 'Ghazipur', 'Jhansi', 'Kannauj',
#        'Kasganj', 'Mahoba', 'Mau', 'Mirzapur', 'Rae Bareli', 'Sambhal',
#        'Sant Kabir Nagar', 'Sant Ravidas Nagar', 'Sonbhadra', 'Almora',
#        'Chamoli', 'Champawat', 'Pauri Garhwal', 'Pithoragarh',
#        'Tehri Garhwal', 'Udham Singh Nagar', 'Uttarkashi', 'Bankura',
#        'Bardhaman', 'Darjiling', 'Purba Medinipur', 'Howrah', 'Hooghly',
#        'Koch Bihar', 'Maldah', 'Murshidabad', 'North Dinajpur',
#        'Paschim Bardhaman', 'Purulia', 'South 24 Parganas',
#        'South Dinajpur', 'Surguja', 'Budgam', 'Doda', 'Kulgam', 'Kupwara',
#        'Pulwama', 'Kodarma', 'Kodagu', 'Lakshadweep', 'Dindori', 'Umaria',
#        'Bid', 'Jalna', 'Chandel', 'Debagarh', 'Yanam', 'Jagitial',
#        'Narayanpet', 'Sheikpura', 'Balod', 'Gariyaband', 'Kabeerdham',
#        'Kanker', 'Andamans', 'Nicobar', 'East Kameng', 'Kurung Kumey',
#        'Lower Dibang Valley', 'Namsai', 'Tawang', 'West Siang', 'Majuli',
#        'Bhabua', 'Jyotiba Phule Nagar', 'Sant Ravidas Nagar Bhadohi',
#        'Bageshwar', 'Rudraprayag', 'Daman', 'Diu', 'Leh', 'Shupiyan',
#        'Pakaur', 'Imphal East', 'Jiribam', 'Aizawl', 'Kolasib', 'Muktsar',
#        'East Siang', 'Longding', 'Upper Siang', 'Upper Subansiri',
#        'Dantewada', 'Mohla-Manpur-Ambagarh Chouki', 'East Sikkim',
#        'North Sikkim', 'Raigarh(Mh)', 'Mokokchung', 'Wokha', 'Baudh',
#        'Khowai', 'Kinnaur', 'Badgam', 'Pashchimi Singhbhum',
#        'North And Middle Andaman', 'Kamle', 'Leparada', 'Shi-Yomi',
#        'Tirap', 'Niwari', 'Dibang Valley', 'Sribhumi',
#        'Gaurela-Pendra-Marwahi', 'Narayanpur', 'Khawzawl', 'Serchhip',
#        'Thoubal', 'Mahrajganj', 'Jangaon', 'Bulandshahar', 'Sahibganj',
#        'Maihar', 'Pakke Kessang', 'Samstipur', 'Eastern West Khasi Hills',
#        'Niuland', 'Dhaulpur', 'South East Delhi', 'Lahaul And Spiti',
#        'Mauganj', 'Lower Siang', 'Pandhurna',
#        'Khairagarh Chhuikhadan Gandai', 'Kakching', 'Jaintia Hills',
#        'Saitual', 'Mohali', 'Bagpat', 'Garhwal', 'Najafgarh',
#        'Khairthal-Tijara', 'Hnahthial', 'Tirupathur', 'Tamulpur District',
#        'Sarangarh-Bilaigarh', 'Rajauri', 'Jalore', '24 Paraganas South',
#        'Nabarangpur', 'Ramanagara', 'Shopian', 'Bajali', 'Meluri',
#        'Shamator', 'Namchi', 'Nicobars', 'Deeg', 'Tseminyu', 'Tiruvarur',
#        'Bardez', 'Pherzawl', 'Bandipur', 'Anugal', 'Mangan',
#        'Didwana-Kuchaman', 'Salumbar', 'Beawar', 'Balotra',
#        'Kotputli-Behror'], dtype=object)

# %% [markdown]
# ## Strict District-State 1:1 Mapping Validation
# Ensuring each district belongs to exactly one state to prevent double-counting.

# %%
# 1. Identify Districts mapped to multiple States
district_state_counts = df.groupby(['district', 'state']).size().reset_index(name='count')
district_counts = district_state_counts.groupby('district')['state'].nunique()
conflicts = district_counts[district_counts > 1].index.tolist()

print(f"Found {len(conflicts)} districts appearing in multiple states: {conflicts}")
# Out:
# Found 22 districts appearing in multiple states: ['Adilabad', 'Aurangabad', 'Balrampur', 'Bijapur', 'Bilaspur', 'Cuddalore', 'Hamirpur', 'Hyderabad', 'Kamrup', 'Kargil', 'Karimnagar', 'Khammam', 'Leh', 'Mahabubnagar', 'Medak', 'Nalgonda', 'Nizamabad', 'Pratapgarh', 'Raigarh', 'Rangareddy', 'Rupnagar', 'Warangal']

# %%
# ==========================================
# Resolve District–State Conflicts
# Priority:
# 1. Pincode-based truth
# 2. Manual authoritative fixes
# 3. Majority vote fallback
# ==========================================

# -------------------------------
# Manual authoritative overrides
# -------------------------------
MANUAL_STATE_FIXES = {
    'Mahabubnagar': 'Telangana',
    'Adilabad': 'Telangana',
    'Hyderabad': 'Telangana',
    'Rangareddy': 'Telangana',
    'Khammam': 'Telangana',
    'Warangal': 'Telangana',
    'Nalgonda': 'Telangana',
    'Nizamabad': 'Telangana',
    'Medak': 'Telangana',
    'Karimnagar': 'Telangana',
    'Leh (Ladakh)': 'Ladakh',
    'Kargil': 'Ladakh',
    'Aurangabad': 'Maharashtra',
    'Bilaspur': 'Chhattisgarh',
    'Hamirpur': 'Himachal Pradesh',
    'Pratapgarh': 'Uttar Pradesh',
    'Balrampur': 'Uttar Pradesh'
}

# ---------------------------------
# Build PINCODE → STATE reference
# ---------------------------------
pincode_state_map = (
    df.dropna(subset=['pincode', 'state'])
      .groupby('pincode')['state']
      .agg(lambda x: x.value_counts().idxmax())
      .to_dict()
)

# ---------------------------------
# Conflict resolution function
# ---------------------------------
def resolve_conflict(district_name, dist_df):
    """
    Resolves district-state conflict using:
    1. Pincode-based mapping
    2. Manual override
    3. Majority vote
    """

    # 1️⃣ PINCODE-based resolution
    pincodes = (
        df.loc[df['district'] == district_name, 'pincode']
        .dropna()
        .unique()
    )

    pincode_states = [
        pincode_state_map[p]
        for p in pincodes
        if p in pincode_state_map
    ]

    if len(pincode_states) > 0:
        return (
            pd.Series(pincode_states)
              .value_counts()
              .idxmax()
        )

    # 2️⃣ Manual override
    if district_name in MANUAL_STATE_FIXES:
        return MANUAL_STATE_FIXES[district_name]

    # 3️⃣ Majority vote fallback
    return (
        dist_df
        .sort_values(by='count', ascending=False)['state']
        .iloc[0]
    )

# ---------------------------------
# Build final district → state map
# ---------------------------------
valid_mappings = {}

# Non-conflicting districts
non_conflict_df = district_state_counts[
    ~district_state_counts['district'].isin(conflicts)
]

for _, row in non_conflict_df.iterrows():
    valid_mappings[row['district']] = row['state']

# Conflicting districts
for dist in conflicts:
    sub_df = district_state_counts[
        district_state_counts['district'] == dist
    ]
    resolved_state = resolve_conflict(dist, sub_df)
    valid_mappings[dist] = resolved_state
    print(f"Resolved {dist} → {resolved_state}")

# ---------------------------------
# Sanity checks
# ---------------------------------
print("\nTotal districts mapped:", len(valid_mappings))
# Out:
# Resolved Adilabad → Telangana
# Resolved Aurangabad → Maharashtra
# Resolved Balrampur → Uttar Pradesh
# Resolved Bijapur → Karnataka
# Resolved Bilaspur → Himachal Pradesh
# Resolved Cuddalore → Tamil Nadu
# Resolved Hamirpur → Himachal Pradesh
# Resolved Hyderabad → Telangana
# Resolved Kamrup → Assam
# Resolved Kargil → Jammu and Kashmir
# Resolved Karimnagar → Telangana
# Resolved Khammam → Telangana
# Resolved Leh → Jammu and Kashmir
# Resolved Mahabubnagar → Telangana
# Resolved Medak → Telangana
# Resolved Nalgonda → Telangana
# Resolved Nizamabad → Telangana
# Resolved Pratapgarh → Uttar Pradesh
# Resolved Raigarh → Maharashtra
# Resolved Rangareddy → Telangana
# Resolved Rupnagar → Punjab
# Resolved Warangal → Telangana
#
# Total districts mapped: 842

# %%
# ==========================================
# Enforce District-State Consistency (FIX)
# ==========================================

df['state_original'] = df['state']  # keep audit copy

def fix_state(row):
    official = valid_mappings.get(row['district'])
    if official:
        return official
    return row['state']

df['state'] = df.apply(fix_state, axis=1)

# Audit report
corrected_rows = (df['state'] != df['state_original']).sum()

print(f"Corrected state for {corrected_rows} rows")
print(f"Final clean row count: {len(df)}")
# Out:
# Corrected state for 20031 rows
# Final clean row count: 1207829

# %%
# 4. Final Verification
final_check = df.groupby('district')['state'].nunique().max()
assert final_check == 1, "Critical Error: Still have districts in multiple states!"
print("SUCCESS: 1-to-1 District-State mapping strictly enforced.")
# Out:
# SUCCESS: 1-to-1 District-State mapping strictly enforced.

# %% [markdown]
# # Data Cleaning and Feature Engineering

# %%
# Convert date column
df['date'] = pd.to_datetime(df['date'], errors='coerce', format='%d-%m-%Y')


# Extract month
df['month'] = df['date'].dt.month


# Create total enrolment column
df['total_enrolment'] = (
df['age_0_5'] + df['age_5_17'] + df['age_18_greater']
)


# Drop missing values
df = df.dropna()

# %% [markdown]
# ## Data Scope Confirmation

# %%
df['date'].dt.year.unique()
# Out:
# array([2025, 2026], dtype=int32)

# %% [markdown]
# The dataset contains enrolment records only for the year 2025. Therefore, the analysis focuses on intra-year (month-wise) patterns rather than multi-year trends.

# %% [markdown]
# # State-wise Aadhaar Enrolment Analysis

# %%
state_enrolment = (
df.groupby('state')['total_enrolment']
.sum()
.reset_index()
.sort_values(by='total_enrolment', ascending=False)
)

# %%
# Visualization: Top 10 states
top10 = state_enrolment.head(10)

# %%
plt.figure()
plt.bar(top10['state'], top10['total_enrolment'])
plt.xticks(rotation=45)
plt.xlabel("State")
plt.ylabel("Total Aadhaar Enrolments")
plt.title("Top 10 States by Aadhaar Enrolment (2025)")
plt.show()

# %% [markdown]
# Higher enrolment volumes in economically active states suggest population concentration and migration-driven demand for Aadhaar services.

# %% [markdown]
# # Month-wise Aadhaar Enrolment Trend (2025)

# %%
monthly_enrolment = (
df.groupby('month')['total_enrolment']
.sum()
.reset_index()
.sort_values('month')
)


plt.figure()
plt.plot(monthly_enrolment['month'], monthly_enrolment['total_enrolment'], marker='o')
plt.xlabel("Month (2025)")
plt.ylabel("Total Aadhaar Enrolments")
plt.title("Month-wise Aadhaar Enrolment Trend – 2025")
plt.grid(True)
plt.show()

# %% [markdown]
# Seasonal fluctuations in enrolment indicate campaign-driven or administrative demand rather than uniform enrolment throughout the year.

# %% [markdown]
# # Age-group Analysis (Key Societal Indicator)

# %%
age_totals = pd.DataFrame({
'Age Group': ['0–5 years', '5–17 years', '18+ years'],
'Total Enrolment': [
df['age_0_5'].sum(),
df['age_5_17'].sum(),
df['age_18_greater'].sum()
]
})


plt.figure()
plt.bar(age_totals['Age Group'], age_totals['Total Enrolment'])
plt.xlabel("Age Group")
plt.ylabel("Total Aadhaar Enrolments")
plt.title("Age-wise Aadhaar Enrolment Distribution (2025)")
plt.show()

# %% [markdown]
# The majority of Aadhaar enrolments in 2025 are concentrated in the 0–5 and 5–17 age groups, indicating strong early-life and school-age identity inclusion, while relatively low enrolment in the 18+ group suggests that Aadhaar coverage among adults is largely saturated.

# %% [markdown]
# # District-level Enrolment Disparities

# %%
district_enrolment = (
df.groupby(['state', 'district'])['total_enrolment']
.sum()
.reset_index()
)


# Top and bottom districts
top_districts = district_enrolment.sort_values('total_enrolment', ascending=False).head(10)
bottom_districts = district_enrolment.sort_values('total_enrolment').head(10)


top_districts
# Out:
#              state           district  total_enrolment
# 323      Karnataka    Bengaluru Urban            69013
# 462    Maharashtra              Thane            49594
# 132          Bihar          Sitamarhi            46864
# 839    West Bengal  South 24 Parganas            42989
# 841    West Bengal     Uttar Dinajpur            42507
# 726  Uttar Pradesh           Bahraich            41388
# 830    West Bengal        Murshidabad            41337
# 832    West Bengal  North 24 Parganas            40654
# 453    Maharashtra               Pune            38536
# 604      Rajasthan             Jaipur            37634

# %%
 bottom_districts
# Out:
#                            state          district  total_enrolment
# 612                    Rajasthan  Khairthal-Tijara                1
# 585                    Rajasthan           Balotra                1
# 2    Andaman and Nicobar Islands          Nicobars                1
# 589                    Rajasthan            Beawar                1
# 138                   Chandigarh            Mohali                1
# 668                   Tamil Nadu         Tiruvarur                1
# 618                    Rajasthan          Salumbar                1
# 188                          Goa            Bardez                2
# 265            Jammu and Kashmir          Bandipur                2
# 614                    Rajasthan   Kotputli-Behror                2

# %% [markdown]
# Sharp disparities between high- and low-enrolment districts reveal uneven access to Aadhaar enrolment infrastructure, particularly affecting rural and remote regions.

# %% [markdown]
# # Anomaly Detection (Spikes and Dips)

# %%
monthly_enrolment.sort_values('total_enrolment')
# Out:
#    month  total_enrolment
# 1      3            16582
# 3      5           183616
# 0      1           244276
# 2      4           257438
# 5      7           616868
# 9     12           757511
# 7     10           821533
# 4      6           901539
# 8     11          1092275
# 6      9          1474858

# %% [markdown]
# Unusually high or low enrolment months suggest short-term operational factors such as targeted enrolment drives, reporting gaps, or temporary service disruptions.
